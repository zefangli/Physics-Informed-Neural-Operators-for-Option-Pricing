# %%
"""
DeepONet Black-Scholes Solver
Optimized for high-dimensional branch data (u) and continuous trunk coordinates (M, tau)
"""

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
import h5py
import numpy as np
import time
import matplotlib.pyplot as plt  # <-- Added for plotting

# ==========================================
# NETWORK ARCHITECTURE (DeepONet)
# ==========================================

class PINN_MLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim, is_positive=True):
        super().__init__()
        layers = []
        
        layers.append(nn.Linear(input_dim, hidden_dim))
        layers.append(nn.LayerNorm(hidden_dim))
        layers.append(nn.Tanh())
        
        for _ in range(num_layers - 1):
            layers.append(nn.Linear(hidden_dim, hidden_dim))
            layers.append(nn.LayerNorm(hidden_dim))
            layers.append(nn.Tanh())
            
        layers.append(nn.Linear(hidden_dim, output_dim))
        
        if is_positive:
            layers.append(nn.Softplus())
            
        self.net = nn.Sequential(*layers)
        
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight)
                nn.init.zeros_(m.bias)
                
    def forward(self, x):
        return self.net(x)


class DeepONet(nn.Module):
    def __init__(self, u_dim, hidden_dim, num_layers, p_dim):
        super().__init__()
        # Branch network for the high-dimensional function input 'u'
        self.branch = PINN_MLP(
            input_dim=u_dim, 
            hidden_dim=hidden_dim, 
            num_layers=num_layers, 
            output_dim=p_dim, 
            is_positive=False 
        )
        
        # Trunk network for the continuous variables 'M' and 'tau'
        self.trunk = PINN_MLP(
            input_dim=2, 
            hidden_dim=hidden_dim, 
            num_layers=num_layers, 
            output_dim=p_dim, 
            is_positive=False
        )
        
        # Bias term for the final DeepONet output
        self.bias = nn.Parameter(torch.zeros(1))
        
        # Softplus to ensure the resulting volatility is strictly positive
        self.softplus = nn.Softplus()

    def forward(self, u, M, tau):
        branch_out = self.branch(u)
        
        trunk_input = torch.cat([M, tau], dim=1)
        trunk_out = self.trunk(trunk_input)
        
        # Compute the dot product across the basis dimension (p_dim)
        dot_product = torch.sum(branch_out * trunk_out, dim=1, keepdim=True)
        
        # Add bias and enforce positivity for volatility
        sigma = self.softplus(dot_product + self.bias)
        return sigma


class DeepBS_Solver(nn.Module):
    def __init__(self, u_dim=374, hidden_dim=128, num_layers=4, p_dim=128):
        super().__init__()
        
        # Network 1 is now a DeepONet predicting volatility
        self.nn1 = DeepONet(
            u_dim=u_dim, 
            hidden_dim=hidden_dim, 
            num_layers=num_layers, 
            p_dim=p_dim
        )
        
        # Network 2 remains a standard PINN_MLP predicting option price
        self.nn2 = PINN_MLP(
            input_dim=5, 
            hidden_dim=hidden_dim, 
            num_layers=num_layers, 
            output_dim=1, 
            is_positive=True
        )

    def forward(self, M, tau, u, r, q):
        # 1. Predict volatility (sigma) using the DeepONet
        sigma = self.nn1(u, M, tau)
        
        # 2. Predict option price (v_hat) using the MLP
        nn2_input = torch.cat([M, tau, r, q, sigma], dim=1)
        v_hat = self.nn2(nn2_input)
        
        return sigma, v_hat


# ==========================================
# LOSS FUNCTIONS
# ==========================================

def compute_derivatives(v_hat, M, tau):
    dv_dM = torch.autograd.grad(
        outputs=v_hat, inputs=M, 
        grad_outputs=torch.ones_like(v_hat),
        create_graph=True, retain_graph=True
    )[0]
    
    d2v_dM2 = torch.autograd.grad(
        outputs=dv_dM, inputs=M, 
        grad_outputs=torch.ones_like(dv_dM),
        create_graph=True, retain_graph=True
    )[0]
    
    dv_dtau = torch.autograd.grad(
        outputs=v_hat, inputs=tau, 
        grad_outputs=torch.ones_like(v_hat),
        create_graph=True, retain_graph=True
    )[0]
    
    return dv_dM, d2v_dM2, dv_dtau


def generate_boundary_points(batch_size, u, r, q, device, M_max=3.0, tau_max=5.32):
    indices = torch.randint(0, u.size(0), (batch_size,), device=device)

    # Terminal condition at tau = 0, M ∈ [0, M_max]
    M_term = torch.rand(batch_size, 1, device=device) * M_max
    tau_term = torch.zeros(batch_size, 1, device=device)

    # Lower boundary at M = 0, tau ∈ [0, tau_max]
    M_lower = torch.zeros(batch_size, 1, device=device)
    tau_lower = torch.rand(batch_size, 1, device=device) * tau_max

    # Upper boundary at M = M_max, tau ∈ [0, tau_max]
    M_upper = torch.full((batch_size, 1), M_max, device=device)
    tau_upper = torch.rand(batch_size, 1, device=device) * tau_max

    return {
        'terminal': (M_term, tau_term, u[indices], r[indices], q[indices]),
        'lower': (M_lower, tau_lower, u[indices], r[indices], q[indices]),
        'upper': (M_upper, tau_upper, u[indices], r[indices], q[indices]),
    }


def pinn_loss_fn(
    model, M, tau, u, r, q, v_true, mask, lambdas,
    device, num_boundary=256,
    M_max=3.0, tau_max=5.32
):
    sigma_hat, v_hat = model(M, tau, u, r, q)

    # ----------------
    # Data Loss
    # ----------------
    squared_errors = (v_hat - v_true) ** 2
    loss_data = torch.sum(squared_errors * mask) / (torch.sum(mask) + 1e-8)

    # ----------------
    # PDE Loss (tau is in YEARS; no scaling factor needed for time derivative)
    # ----------------
    dv_dM, d2v_dM2, dv_dtau = compute_derivatives(v_hat, M, tau)

    pde_residual = (
        -dv_dtau
        + 0.5 * (sigma_hat ** 2) * (M ** 2) * d2v_dM2
        + (r - q) * M * dv_dM
        - r * v_hat
    )
    loss_pde = torch.mean(pde_residual ** 2)

    # ----------------
    # Arbitrage Loss
    # ----------------
    loss_arb = torch.mean(F.relu(-dv_dM)) + torch.mean(F.relu(-d2v_dM2))

    # ----------------
    # Boundary Conditions (tau in YEARS)
    # ----------------
    boundaries = generate_boundary_points(
        num_boundary, u, r, q, device, M_max=M_max, tau_max=tau_max
    )

    # Terminal: v(M,0) = max(M-1,0)
    M_t, tau_t, u_t, r_t, q_t = boundaries['terminal']
    M_t.requires_grad_(True)
    tau_t.requires_grad_(True)
    _, v_term = model(M_t, tau_t, u_t, r_t, q_t)
    loss_term = F.mse_loss(v_term, F.relu(M_t - 1.0))

    # Lower: v(0,tau)=0
    M_l, tau_l, u_l, r_l, q_l = boundaries['lower']
    M_l.requires_grad_(True)
    tau_l.requires_grad_(True)
    _, v_lower = model(M_l, tau_l, u_l, r_l, q_l)
    loss_lower = F.mse_loss(v_lower, torch.zeros_like(v_lower))

    # Upper: v(M_max,tau) = M_max*e^{-q tau} - e^{-r tau} 
    M_u, tau_u, u_u, r_u, q_u = boundaries['upper']
    M_u.requires_grad_(True)
    tau_u.requires_grad_(True)
    _, v_upper = model(M_u, tau_u, u_u, r_u, q_u)
    v_upper_true = M_u * torch.exp(-q_u * tau_u) - torch.exp(-r_u * tau_u)
    loss_upper = F.mse_loss(v_upper, v_upper_true)

    # ----------------
    # Total
    # ----------------
    loss_total = (
        lambdas.get('data', 1.0) * loss_data +
        lambdas.get('pde', 0.1) * loss_pde +
        lambdas.get('arb', 0.1) * loss_arb +
        lambdas.get('term', 1.0) * loss_term +
        lambdas.get('lower', 1.0) * loss_lower +
        lambdas.get('upper', 1.0) * loss_upper
    )

    loss_dict = {
        'data': loss_data.item(),
        'pde': loss_pde.item(),
        'arb': loss_arb.item(),
        'term': loss_term.item(),
        'lower': loss_lower.item(),
        'upper': loss_upper.item(),
        'total': loss_total.item()
    }

    return loss_total, loss_dict


# ==========================================
# DATASET
# ==========================================

class ChronologicalOptionDataset(Dataset):
    def __init__(self, h5_path, split='train', load_to_memory=True):
        self.h5_path = h5_path
        self.load_to_memory = load_to_memory
        
        with h5py.File(h5_path, 'r') as f:
            total_rows = f['target_v'].shape[0]
            self.u_dim = f['branch_u'].shape[1]
            
            train_end = int(0.80 * total_rows)
            val_end = int(0.90 * total_rows)
            
            if split == 'train':
                self.start_idx, self.end_idx = 0, train_end
            elif split == 'val':
                self.start_idx, self.end_idx = train_end, val_end
            elif split == 'test':
                self.start_idx, self.end_idx = val_end, total_rows
            else:
                raise ValueError("Split must be 'train', 'val', or 'test'.")
            
            self.length = self.end_idx - self.start_idx
            
            if load_to_memory:
                self.branch_u = f['branch_u'][self.start_idx:self.end_idx]
                self.trunk_y = f['trunk_y'][self.start_idx:self.end_idx]
                self.target_v = f['target_v_normalized'][self.start_idx:self.end_idx]
                
        print(f"Loaded {split}: {self.length} samples")

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        return (
            torch.tensor(self.branch_u[idx], dtype=torch.float32),
            torch.tensor(self.trunk_y[idx], dtype=torch.float32),
            torch.tensor(self.target_v[idx], dtype=torch.float32)
        )
    
    def get_u_dim(self):
        return self.u_dim


# ==========================================
# COLLATE FUNCTION (DeepONet Optimized)
# ==========================================

def create_pinn_collate_fn(colloc_ratio=0.2, M_max=3.0, tau_max=5.32, points_per_u=10):
    """
    Pairs a smaller set of unique functional inputs (u) with multiple continuous 
    evaluation coordinates (M, tau) to learn the operator mapping efficiently.
    """
    def collate_fn(batch):
        u_true = torch.stack([item[0] for item in batch])
        y_true = torch.stack([item[1] for item in batch])
        v_true = torch.stack([item[2] for item in batch])

        if v_true.dim() == 1:
            v_true = v_true.unsqueeze(1)

        M_true = y_true[:, 0:1]
        tau_true = y_true[:, 1:2]
        r_true = y_true[:, 2:3]
        q_true = y_true[:, 3:4]

        num_true = len(batch)

        if colloc_ratio > 0.0:
            target_num_colloc = max(1, int(num_true * (colloc_ratio / (1.0 - colloc_ratio))))
            
            # Determine how many unique market states (u) we should sample
            num_unique_u = max(1, target_num_colloc // points_per_u)
            actual_num_colloc = num_unique_u * points_per_u

            # 1. Randomly select a subset of unique 'u' states
            idx = torch.randint(0, num_true, (num_unique_u,))
            u_base = u_true[idx]
            r_base = r_true[idx]
            q_base = q_true[idx]
            
            # 2. Duplicate each selected 'u' (and r, q) 'points_per_u' times
            u_colloc = u_base.repeat_interleave(points_per_u, dim=0)
            r_colloc = r_base.repeat_interleave(points_per_u, dim=0)
            q_colloc = q_base.repeat_interleave(points_per_u, dim=0)
            
            # 3. Generate independent random (M, tau) coordinates for the duplicated states
            M_colloc = torch.rand(actual_num_colloc, 1) * M_max
            tau_colloc = torch.rand(actual_num_colloc, 1) * tau_max
            v_colloc = torch.zeros(actual_num_colloc, 1)

            M_final = torch.cat([M_true, M_colloc])
            tau_final = torch.cat([tau_true, tau_colloc])
            u_final = torch.cat([u_true, u_colloc])
            r_final = torch.cat([r_true, r_colloc])
            q_final = torch.cat([q_true, q_colloc])
            v_final = torch.cat([v_true, v_colloc])
            mask = torch.cat([torch.ones(num_true, 1), torch.zeros(actual_num_colloc, 1)])
            
        else:
            M_final, tau_final, u_final = M_true, tau_true, u_true
            r_final, q_final, v_final = r_true, q_true, v_true
            mask = torch.ones(num_true, 1)

        return M_final, tau_final, u_final, r_final, q_final, v_final, mask

    return collate_fn

# ==========================================
# TRAINING
# ==========================================

def train_model():
    seed = 42
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) 
    np.random.seed(seed)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Device: {device}")
    
    config = {
        'epochs_adam': 100,      
        'epochs_lbfgs': 50, # Fine-tuning with low-LR Adam
        'batch_size': 256, #changed
        'lr': 1e-3,
        'hidden_dim': 64,
        'num_layers': 4,
        'p_dim': 64,             # Basis dimension for DeepONet projection
        'colloc_ratio': 0.2, 
        'points_per_u': 20,      #changed # Number of coordinate points per branch input
        'num_boundary': 128, 
        'grad_clip': 1.0,
        'M_max': 3.0,
        'tau_max': 5.32,
        'patience_adam': 3,     #changed
        'patience_lbfgs': 3,    #changed
    }
    
    #changed
    lambdas = {'data': 1.0, 'pde': 0.0, 'arb': 0.0, 'term': 0.0, 'lower': 0.0, 'upper': 0.0}
    
    print("Loading datasets...")
    train_ds = ChronologicalOptionDataset('../../wrds_data/deeponet_tensors.h5', 'train')
    val_ds = ChronologicalOptionDataset('../../wrds_data/deeponet_tensors.h5', 'val')
    test_ds = ChronologicalOptionDataset('../../wrds_data/deeponet_tensors.h5', 'test') # Added Test Set
    print(f"Train samples: {len(train_ds)}, Val samples: {len(val_ds)}, Test samples: {len(test_ds)}")
    
    train_loader = DataLoader(
        train_ds,
        config['batch_size'],
        shuffle=True,
        collate_fn=create_pinn_collate_fn(
            colloc_ratio=config['colloc_ratio'],
            M_max=config['M_max'],
            tau_max=config['tau_max'],
            points_per_u=config['points_per_u']
        )
    )
    
    val_loader = DataLoader(
        val_ds,
        config['batch_size'] * 2,
        shuffle=False,
        collate_fn=create_pinn_collate_fn(
            colloc_ratio=0.0,
            M_max=config['M_max'],
            tau_max=config['tau_max']
        )
    )

    test_loader = DataLoader(
        test_ds, config['batch_size'] * 2, shuffle=False,
        collate_fn=create_pinn_collate_fn(colloc_ratio=0.0, M_max=config['M_max'], tau_max=config['tau_max'])
    )
    
    print(f"Train batches: {len(train_loader)}, Val batches: {len(val_loader)}")
    
    # Model
    model = DeepBS_Solver(train_ds.get_u_dim(), config['hidden_dim'], config['num_layers'], config['p_dim']).to(device)
    print(f"Model initialized with u_dim={train_ds.get_u_dim()}, hidden_dim={config['hidden_dim']}, num_layers={config['num_layers']}, p_dim={config['p_dim']}")
    
    # ==========================================
    # OPTIMIZER SETTINGS (DeepONet Groups)
    # ==========================================
    base_lr = config['lr']
    
    # Grouped parameters to pace the fast-learning trunk and regularize the branch
    optimizer_adam = optim.Adam([
        {'params': model.nn1.branch.parameters(), 'lr': base_lr, 'weight_decay': 1e-4},
        {'params': model.nn1.trunk.parameters(), 'lr': base_lr * 0.1, 'weight_decay': 0.0},
        {'params': [model.nn1.bias], 'lr': base_lr},
        {'params': model.nn2.parameters(), 'lr': base_lr, 'weight_decay': 1e-5}
    ])

    #changed
    scheduler = ReduceLROnPlateau(optimizer_adam, 'min', factor=0.5, patience=2)
    
    best_val = float('inf')
    
    # --- Lists to track loss history for plotting ---
    all_train_losses = []
    all_val_losses = []
    
    def evaluate_validation():
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch in val_loader:
                M, tau, u, r, q, v_true, _ = [b.to(device) for b in batch]
                _, v_hat = model(M, tau, u, r, q)
                val_loss += F.mse_loss(v_hat, v_true).item() * M.size(0)
        val_loss /= len(val_ds)
        model.train()
        return val_loss
    
    # ==========================================
    # STAGE 1: ADAM TRAINING
    # ==========================================
    print("\n" + "="*60)
    print("PHASE 1: Adam Optimizer (DeepONet Parameter Groups)")
    print("="*60)
    
    epochs_no_improve = 0
    phase1_epochs_completed = 0
    
    for epoch in range(config['epochs_adam']):
        model.train()
        epoch_start = time.time()
        total_loss = 0
        loss_components = {'data': 0, 'pde': 0, 'arb': 0, 'term': 0, 'lower': 0, 'upper': 0}
        
        for batch_idx, batch in enumerate(train_loader):
            M, tau, u, r, q, v_true, mask = [b.to(device) for b in batch]
            M = M.clone().requires_grad_(True)
            tau = tau.clone().requires_grad_(True)
            
            optimizer_adam.zero_grad()
            loss, loss_dict = pinn_loss_fn(
                model, M, tau, u, r, q, v_true, mask,
                lambdas, device,
                num_boundary=config['num_boundary'],
                M_max=config['M_max'],
                tau_max=config['tau_max'],
            )
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), config['grad_clip'])
            optimizer_adam.step()
            
            total_loss += loss_dict['total']
            for key in loss_components:
                loss_components[key] += loss_dict[key]
            
            if (batch_idx + 1) % 100 == 0:
                print(f"  Epoch {epoch+1} | Batch {batch_idx+1}/{len(train_loader)} | Batch Loss: {loss_dict['total']:.6f}")
        
        val_loss = evaluate_validation()
        scheduler.step(val_loss)
        current_lr = optimizer_adam.param_groups[0]['lr'] # Refers to branch LR
        
        epoch_time = time.time() - epoch_start
        avg_loss = total_loss / len(train_loader)
        
        # Save epoch history
        all_train_losses.append(avg_loss)
        all_val_losses.append(val_loss)
        phase1_epochs_completed += 1
        
        for key in loss_components:
            loss_components[key] /= len(train_loader)
        
        improved = ""
        if val_loss < best_val:
            best_val = val_loss
            torch.save(model.state_dict(), f'best_model_phase1.pth')
            improved = " *** New Best ***"
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
        
        print(f"\nAdam Epoch {epoch+1}/{config['epochs_adam']} | Time: {epoch_time:.1f}s | Base LR: {current_lr:.2e}")
        print(f"  Train Loss: {avg_loss:.6f} | Val MSE: {val_loss:.6f}{improved}")
        print(f"  Components - Data: {loss_components['data']:.4f} | PDE: {loss_components['pde']:.4f} | Arb: {loss_components['arb']:.4f}")
        print(f"  Epochs without improvement: {epochs_no_improve}/{config['patience_adam']}")
        print("-" * 60)
        
        if epochs_no_improve >= config['patience_adam']:
            print(f"\n*** Early stopping triggered at epoch {epoch+1} ***")
            break
            
        torch.cuda.empty_cache()
    
    print(f"\n*** Adam Phase Complete. Best Val MSE: {best_val:.6f} ***")
    
    print("Loading best model from Adam phase for fine-tuning...")
    model.load_state_dict(torch.load('best_model_phase1.pth'))
    
    #changed
    torch.save(model.state_dict(), f'best_model.pth')

    # ==========================================
    # STAGE 2: FINE-TUNING WITH LOW LR ADAM
    # ==========================================
    print("\n" + "="*60)
    print("PHASE 2: Fine-tuning with Adam (Low LR, DeepONet Groups)")
    print("="*60)

    # best_val = 0.000815
    finetune_lr = 1e-5
    optimizer_finetune = optim.Adam([
        {'params': model.nn1.branch.parameters(), 'lr': finetune_lr, 'weight_decay': 1e-5},
        {'params': model.nn1.trunk.parameters(), 'lr': finetune_lr * 0.1, 'weight_decay': 0.0},
        {'params': [model.nn1.bias], 'lr': finetune_lr},
        {'params': model.nn2.parameters(), 'lr': finetune_lr, 'weight_decay': 1e-6}
    ])
    
    epochs_no_improve = 0

    for epoch in range(config['epochs_lbfgs']): 
        model.train()
        epoch_start = time.time()
        total_loss = 0
        loss_components = {'data': 0, 'pde': 0, 'arb': 0, 'term': 0, 'lower': 0, 'upper': 0}
        
        for batch_idx, batch in enumerate(train_loader):
            M, tau, u, r, q, v_true, mask = [b.to(device) for b in batch]
            M = M.clone().requires_grad_(True)
            tau = tau.clone().requires_grad_(True)
            
            optimizer_finetune.zero_grad()
            loss, loss_dict = pinn_loss_fn(
                model, M, tau, u, r, q, v_true, mask,
                lambdas, device,
                num_boundary=config['num_boundary'],
                M_max=config['M_max'],
                tau_max=config['tau_max'],
            )
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), config['grad_clip'])
            optimizer_finetune.step()
            
            total_loss += loss_dict['total']
            for key in loss_components:
                loss_components[key] += loss_dict[key]
            
            if (batch_idx + 1) % 100 == 0:
                print(f"  Epoch {epoch+1} | Batch {batch_idx+1}/{len(train_loader)} | Batch Loss: {loss_dict['total']:.6f}")
        
        val_loss = evaluate_validation()
        epoch_time = time.time() - epoch_start
        avg_loss = total_loss / len(train_loader)
        
        # Save epoch history
        all_train_losses.append(avg_loss)
        all_val_losses.append(val_loss)
        
        for key in loss_components:
            loss_components[key] /= len(train_loader)
        
        improved = ""
        if val_loss < best_val:
            best_val = val_loss
            torch.save(model.state_dict(), 'best_model.pth')
            improved = " *** New Best ***"
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
        
        print(f"\nFine-tune Epoch {epoch+1}/{config['epochs_lbfgs']} | Time: {epoch_time:.1f}s")
        print(f"  Train Loss: {avg_loss:.6f} | Val MSE: {val_loss:.6f}{improved}")
        print("-" * 60)
        
        torch.cuda.empty_cache()
        
        # we allow it to run for at least 10 epochs to give the fine-tuning a chance to improve, then we check for early stopping
        if epoch >= 10 and epochs_no_improve >= config['patience_lbfgs']:
            print(f"\n*** Early stopping triggered at epoch {epoch+1} ***")
            break

    print("\n" + "="*60)
    print("TRAINING COMPLETE!")
    print(f"Best Validation MSE: {best_val:.6f}")
    print("="*60)
    
    torch.save(model.state_dict(), 'final_model.pth')
    print("Models saved: 'best_model.pth' and 'final_model.pth'")
    

    # ==========================================
    # FINAL TEST EVALUATION
    # ==========================================
    print("\n" + "="*60)
    print("RUNNING FINAL TEST SET EVALUATION")
    print("="*60)
    
    # Load the best overall model weights
    model.load_state_dict(torch.load('best_model.pth'))
    model.eval()
    test_loss = 0
    
    with torch.no_grad():
        for batch in test_loader:
            M, tau, u, r, q, v_true, _ = [b.to(device) for b in batch]
            _, v_hat = model(M, tau, u, r, q)
            test_loss += F.mse_loss(v_hat, v_true).item() * M.size(0)
            
    test_loss /= len(test_ds)
    print(f"Final Test MSE: {test_loss:.6f}")
    
    # ==========================================
    # EXPORTING LOGS & PLOTTING
    # ==========================================
    print("\nSaving loss history to 'loss_history.txt'...")
    with open('loss_history.txt', 'w') as f:
        f.write("Epoch\tTrain_Loss\tVal_Loss\n")
        for i, (t_loss, v_loss) in enumerate(zip(all_train_losses, all_val_losses)):
            f.write(f"{i+1}\t{t_loss:.6f}\t{v_loss:.6f}\n")
        f.write(f"\nFinal Test Loss: {test_loss:.6f}\n")

    print("Generating loss curve plot 'loss_plot.png'...")
    plt.figure(figsize=(10, 6))
    plt.plot(all_train_losses, label='Train Loss (Total PINN Loss)')
    plt.plot(all_val_losses, label='Validation Loss (MSE)')
    
    # Indicate where Phase 2 started
    if phase1_epochs_completed < len(all_train_losses):
        plt.axvline(x=phase1_epochs_completed - 1, color='r', linestyle='--', label='Start Phase 2 (Fine-tuning)')
        
    plt.yscale('log')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Training & Validation Loss (Test MSE: {test_loss:.6f})')
    plt.legend()
    plt.grid(True, which="both", ls="--", alpha=0.5)
    plt.tight_layout()
    plt.savefig('loss_plot.png')
    plt.close()
    
    print("Execution Finished.")
    
    return model

if __name__ == "__main__":
    train_model()
# Out:
# Device: cuda
# Loading datasets...
# Loaded train: 640582 samples
# Loaded val: 80073 samples
# Loaded test: 80073 samples
# Train samples: 640582, Val samples: 80073, Test samples: 80073
# Train batches: 2503, Val batches: 157
# Model initialized with u_dim=374, hidden_dim=64, num_layers=4, p_dim=64
#
# ============================================================
# PHASE 1: Adam Optimizer (DeepONet Parameter Groups)
# ============================================================
#   Epoch 1 | Batch 100/2503 | Batch Loss: 0.017310
#   Epoch 1 | Batch 200/2503 | Batch Loss: 0.001565
#   Epoch 1 | Batch 300/2503 | Batch Loss: 0.003617
#   Epoch 1 | Batch 400/2503 | Batch Loss: 0.000828
#   Epoch 1 | Batch 500/2503 | Batch Loss: 0.001134
#   Epoch 1 | Batch 600/2503 | Batch Loss: 0.159432
#   Epoch 1 | Batch 700/2503 | Batch Loss: 0.001663
#   Epoch 1 | Batch 800/2503 | Batch Loss: 0.001355
#   Epoch 1 | Batch 900/2503 | Batch Loss: 0.002487
#   Epoch 1 | Batch 1000/2503 | Batch Loss: 0.023414
#   Epoch 1 | Batch 1100/2503 | Batch Loss: 0.001052
#   Epoch 1 | Batch 1200/2503 | Batch Loss: 0.000686
#   Epoch 1 | Batch 1300/2503 | Batch Loss: 0.004514
#   Epoch 1 | Batch 1400/2503 | Batch Loss: 0.006049
#   Epoch 1 | Batch 1500/2503 | Batch Loss: 0.012273
#   Epoch 1 | Batch 1600/2503 | Batch Loss: 0.000399
#   Epoch 1 | Batch 1700/2503 | Batch Loss: 0.000793
#   Epoch 1 | Batch 1800/2503 | Batch Loss: 0.000332
#   Epoch 1 | Batch 1900/2503 | Batch Loss: 0.004094
#   Epoch 1 | Batch 2000/2503 | Batch Loss: 0.000594
#   Epoch 1 | Batch 2100/2503 | Batch Loss: 0.000234
#   Epoch 1 | Batch 2200/2503 | Batch Loss: 0.000907
#   Epoch 1 | Batch 2300/2503 | Batch Loss: 0.002326
#   Epoch 1 | Batch 2400/2503 | Batch Loss: 0.005026
#   Epoch 1 | Batch 2500/2503 | Batch Loss: 0.000222
#
# Adam Epoch 1/100 | Time: 158.6s | Base LR: 1.00e-03
#   Train Loss: 0.047875 | Val MSE: 0.005651 *** New Best ***
#   Components - Data: 0.0479 | PDE: 9375.1156 | Arb: 0.0129
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 2 | Batch 100/2503 | Batch Loss: 0.000180
#   Epoch 2 | Batch 200/2503 | Batch Loss: 0.000295
#   Epoch 2 | Batch 300/2503 | Batch Loss: 0.000283
#   Epoch 2 | Batch 400/2503 | Batch Loss: 0.003311
#   Epoch 2 | Batch 500/2503 | Batch Loss: 0.000634
#   Epoch 2 | Batch 600/2503 | Batch Loss: 0.001353
#   Epoch 2 | Batch 700/2503 | Batch Loss: 0.001459
#   Epoch 2 | Batch 800/2503 | Batch Loss: 0.025043
#   Epoch 2 | Batch 900/2503 | Batch Loss: 0.000186
#   Epoch 2 | Batch 1000/2503 | Batch Loss: 0.000163
#   Epoch 2 | Batch 1100/2503 | Batch Loss: 0.000152
#   Epoch 2 | Batch 1200/2503 | Batch Loss: 0.002026
#   Epoch 2 | Batch 1300/2503 | Batch Loss: 0.000519
#   Epoch 2 | Batch 1400/2503 | Batch Loss: 0.001259
#   Epoch 2 | Batch 1500/2503 | Batch Loss: 0.001752
#   Epoch 2 | Batch 1600/2503 | Batch Loss: 0.000334
#   Epoch 2 | Batch 1700/2503 | Batch Loss: 0.000513
#   Epoch 2 | Batch 1800/2503 | Batch Loss: 0.001687
#   Epoch 2 | Batch 1900/2503 | Batch Loss: 0.000224
#   Epoch 2 | Batch 2000/2503 | Batch Loss: 0.000571
#   Epoch 2 | Batch 2100/2503 | Batch Loss: 0.001755
#   Epoch 2 | Batch 2200/2503 | Batch Loss: 0.000097
#   Epoch 2 | Batch 2300/2503 | Batch Loss: 0.000446
#   Epoch 2 | Batch 2400/2503 | Batch Loss: 0.000121
#   Epoch 2 | Batch 2500/2503 | Batch Loss: 0.000464
#
# Adam Epoch 2/100 | Time: 158.4s | Base LR: 1.00e-03
#   Train Loss: 0.002618 | Val MSE: 0.003471 *** New Best ***
#   Components - Data: 0.0026 | PDE: 25227.2061 | Arb: 0.0070
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 3 | Batch 100/2503 | Batch Loss: 0.000351
#   Epoch 3 | Batch 200/2503 | Batch Loss: 0.000281
#   Epoch 3 | Batch 300/2503 | Batch Loss: 0.000181
#   Epoch 3 | Batch 400/2503 | Batch Loss: 0.000253
#   Epoch 3 | Batch 500/2503 | Batch Loss: 0.000158
#   Epoch 3 | Batch 600/2503 | Batch Loss: 0.000354
#   Epoch 3 | Batch 700/2503 | Batch Loss: 0.001888
#   Epoch 3 | Batch 800/2503 | Batch Loss: 0.001774
#   Epoch 3 | Batch 900/2503 | Batch Loss: 0.001385
#   Epoch 3 | Batch 1000/2503 | Batch Loss: 0.002097
#   Epoch 3 | Batch 1100/2503 | Batch Loss: 0.000094
#   Epoch 3 | Batch 1200/2503 | Batch Loss: 0.000873
#   Epoch 3 | Batch 1300/2503 | Batch Loss: 0.002835
#   Epoch 3 | Batch 1400/2503 | Batch Loss: 0.001042
#   Epoch 3 | Batch 1500/2503 | Batch Loss: 0.000145
#   Epoch 3 | Batch 1600/2503 | Batch Loss: 0.000902
#   Epoch 3 | Batch 1700/2503 | Batch Loss: 0.000172
#   Epoch 3 | Batch 1800/2503 | Batch Loss: 0.000104
#   Epoch 3 | Batch 1900/2503 | Batch Loss: 0.000369
#   Epoch 3 | Batch 2000/2503 | Batch Loss: 0.000876
#   Epoch 3 | Batch 2100/2503 | Batch Loss: 0.003564
#   Epoch 3 | Batch 2200/2503 | Batch Loss: 0.000118
#   Epoch 3 | Batch 2300/2503 | Batch Loss: 0.001212
#   Epoch 3 | Batch 2400/2503 | Batch Loss: 0.000118
#   Epoch 3 | Batch 2500/2503 | Batch Loss: 0.001990
#
# Adam Epoch 3/100 | Time: 158.7s | Base LR: 1.00e-03
#   Train Loss: 0.002702 | Val MSE: 0.003409 *** New Best ***
#   Components - Data: 0.0027 | PDE: 28243.0122 | Arb: 0.0071
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 4 | Batch 100/2503 | Batch Loss: 0.008393
#   Epoch 4 | Batch 200/2503 | Batch Loss: 0.000249
#   Epoch 4 | Batch 300/2503 | Batch Loss: 0.000085
#   Epoch 4 | Batch 400/2503 | Batch Loss: 0.000091
#   Epoch 4 | Batch 500/2503 | Batch Loss: 0.000348
#   Epoch 4 | Batch 600/2503 | Batch Loss: 0.012686
#   Epoch 4 | Batch 700/2503 | Batch Loss: 0.001318
#   Epoch 4 | Batch 800/2503 | Batch Loss: 0.001913
#   Epoch 4 | Batch 900/2503 | Batch Loss: 0.000109
#   Epoch 4 | Batch 1000/2503 | Batch Loss: 0.000390
#   Epoch 4 | Batch 1100/2503 | Batch Loss: 0.002212
#   Epoch 4 | Batch 1200/2503 | Batch Loss: 0.000221
#   Epoch 4 | Batch 1300/2503 | Batch Loss: 0.000065
#   Epoch 4 | Batch 1400/2503 | Batch Loss: 0.000332
#   Epoch 4 | Batch 1500/2503 | Batch Loss: 0.000684
#   Epoch 4 | Batch 1600/2503 | Batch Loss: 0.001362
#   Epoch 4 | Batch 1700/2503 | Batch Loss: 0.000914
#   Epoch 4 | Batch 1800/2503 | Batch Loss: 0.000105
#   Epoch 4 | Batch 1900/2503 | Batch Loss: 0.067216
#   Epoch 4 | Batch 2000/2503 | Batch Loss: 0.000694
#   Epoch 4 | Batch 2100/2503 | Batch Loss: 0.000886
#   Epoch 4 | Batch 2200/2503 | Batch Loss: 0.000122
#   Epoch 4 | Batch 2300/2503 | Batch Loss: 0.000338
#   Epoch 4 | Batch 2400/2503 | Batch Loss: 0.000369
#   Epoch 4 | Batch 2500/2503 | Batch Loss: 0.000100
#
# Adam Epoch 4/100 | Time: 158.4s | Base LR: 1.00e-03
#   Train Loss: 0.001888 | Val MSE: 0.002803 *** New Best ***
#   Components - Data: 0.0019 | PDE: 43901.1772 | Arb: 0.0067
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 5 | Batch 100/2503 | Batch Loss: 0.001892
#   Epoch 5 | Batch 200/2503 | Batch Loss: 0.000160
#   Epoch 5 | Batch 300/2503 | Batch Loss: 0.000499
#   Epoch 5 | Batch 400/2503 | Batch Loss: 0.000190
#   Epoch 5 | Batch 500/2503 | Batch Loss: 0.000129
#   Epoch 5 | Batch 600/2503 | Batch Loss: 0.000411
#   Epoch 5 | Batch 700/2503 | Batch Loss: 0.000485
#   Epoch 5 | Batch 800/2503 | Batch Loss: 0.000110
#   Epoch 5 | Batch 900/2503 | Batch Loss: 0.001203
#   Epoch 5 | Batch 1000/2503 | Batch Loss: 0.000117
#   Epoch 5 | Batch 1100/2503 | Batch Loss: 0.005833
#   Epoch 5 | Batch 1200/2503 | Batch Loss: 0.000329
#   Epoch 5 | Batch 1300/2503 | Batch Loss: 0.000143
#   Epoch 5 | Batch 1400/2503 | Batch Loss: 0.000925
#   Epoch 5 | Batch 1500/2503 | Batch Loss: 0.000661
#   Epoch 5 | Batch 1600/2503 | Batch Loss: 0.000417
#   Epoch 5 | Batch 1700/2503 | Batch Loss: 0.003298
#   Epoch 5 | Batch 1800/2503 | Batch Loss: 0.000859
#   Epoch 5 | Batch 1900/2503 | Batch Loss: 0.004659
#   Epoch 5 | Batch 2000/2503 | Batch Loss: 0.001572
#   Epoch 5 | Batch 2100/2503 | Batch Loss: 0.000955
#   Epoch 5 | Batch 2200/2503 | Batch Loss: 0.000156
#   Epoch 5 | Batch 2300/2503 | Batch Loss: 0.000074
#   Epoch 5 | Batch 2400/2503 | Batch Loss: 0.002119
#   Epoch 5 | Batch 2500/2503 | Batch Loss: 0.000157
#
# Adam Epoch 5/100 | Time: 158.5s | Base LR: 1.00e-03
#   Train Loss: 0.001780 | Val MSE: 0.002682 *** New Best ***
#   Components - Data: 0.0018 | PDE: 62046.1145 | Arb: 0.0087
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 6 | Batch 100/2503 | Batch Loss: 0.000194
#   Epoch 6 | Batch 200/2503 | Batch Loss: 0.000949
#   Epoch 6 | Batch 300/2503 | Batch Loss: 0.000469
#   Epoch 6 | Batch 400/2503 | Batch Loss: 0.000185
#   Epoch 6 | Batch 500/2503 | Batch Loss: 0.004438
#   Epoch 6 | Batch 600/2503 | Batch Loss: 0.000072
#   Epoch 6 | Batch 700/2503 | Batch Loss: 0.000128
#   Epoch 6 | Batch 800/2503 | Batch Loss: 0.000221
#   Epoch 6 | Batch 900/2503 | Batch Loss: 0.000096
#   Epoch 6 | Batch 1000/2503 | Batch Loss: 0.000118
#   Epoch 6 | Batch 1100/2503 | Batch Loss: 0.000282
#   Epoch 6 | Batch 1200/2503 | Batch Loss: 0.000105
#   Epoch 6 | Batch 1300/2503 | Batch Loss: 0.000213
#   Epoch 6 | Batch 1400/2503 | Batch Loss: 0.001385
#   Epoch 6 | Batch 1500/2503 | Batch Loss: 0.006314
#   Epoch 6 | Batch 1600/2503 | Batch Loss: 0.000449
#   Epoch 6 | Batch 1700/2503 | Batch Loss: 0.000360
#   Epoch 6 | Batch 1800/2503 | Batch Loss: 0.004220
#   Epoch 6 | Batch 1900/2503 | Batch Loss: 0.000771
#   Epoch 6 | Batch 2000/2503 | Batch Loss: 0.000565
#   Epoch 6 | Batch 2100/2503 | Batch Loss: 0.000291
#   Epoch 6 | Batch 2200/2503 | Batch Loss: 0.000077
#   Epoch 6 | Batch 2300/2503 | Batch Loss: 0.003035
#   Epoch 6 | Batch 2400/2503 | Batch Loss: 0.000238
#   Epoch 6 | Batch 2500/2503 | Batch Loss: 0.000220
#
# Adam Epoch 6/100 | Time: 158.2s | Base LR: 1.00e-03
#   Train Loss: 0.001528 | Val MSE: 0.002791
#   Components - Data: 0.0015 | PDE: 70218.5988 | Arb: 0.0113
#   Epochs without improvement: 1/3
# ------------------------------------------------------------
#   Epoch 7 | Batch 100/2503 | Batch Loss: 0.005766
#   Epoch 7 | Batch 200/2503 | Batch Loss: 0.004142
#   Epoch 7 | Batch 300/2503 | Batch Loss: 0.000097
#   Epoch 7 | Batch 400/2503 | Batch Loss: 0.000861
#   Epoch 7 | Batch 500/2503 | Batch Loss: 0.016205
#   Epoch 7 | Batch 600/2503 | Batch Loss: 0.000067
#   Epoch 7 | Batch 700/2503 | Batch Loss: 0.000117
#   Epoch 7 | Batch 800/2503 | Batch Loss: 0.000057
#   Epoch 7 | Batch 900/2503 | Batch Loss: 0.000790
#   Epoch 7 | Batch 1000/2503 | Batch Loss: 0.000066
#   Epoch 7 | Batch 1100/2503 | Batch Loss: 0.000298
#   Epoch 7 | Batch 1200/2503 | Batch Loss: 0.001949
#   Epoch 7 | Batch 1300/2503 | Batch Loss: 0.000377
#   Epoch 7 | Batch 1400/2503 | Batch Loss: 0.000471
#   Epoch 7 | Batch 1500/2503 | Batch Loss: 0.000161
#   Epoch 7 | Batch 1600/2503 | Batch Loss: 0.000209
#   Epoch 7 | Batch 1700/2503 | Batch Loss: 0.001325
#   Epoch 7 | Batch 1800/2503 | Batch Loss: 0.000290
#   Epoch 7 | Batch 1900/2503 | Batch Loss: 0.000195
#   Epoch 7 | Batch 2000/2503 | Batch Loss: 0.000263
#   Epoch 7 | Batch 2100/2503 | Batch Loss: 0.000075
#   Epoch 7 | Batch 2200/2503 | Batch Loss: 0.000189
#   Epoch 7 | Batch 2300/2503 | Batch Loss: 0.000505
#   Epoch 7 | Batch 2400/2503 | Batch Loss: 0.000432
#   Epoch 7 | Batch 2500/2503 | Batch Loss: 0.000187
#
# Adam Epoch 7/100 | Time: 158.3s | Base LR: 1.00e-03
#   Train Loss: 0.001359 | Val MSE: 0.001764 *** New Best ***
#   Components - Data: 0.0014 | PDE: 86787.6194 | Arb: 0.0131
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 8 | Batch 100/2503 | Batch Loss: 0.000125
#   Epoch 8 | Batch 200/2503 | Batch Loss: 0.015826
#   Epoch 8 | Batch 300/2503 | Batch Loss: 0.000058
#   Epoch 8 | Batch 400/2503 | Batch Loss: 0.000662
#   Epoch 8 | Batch 500/2503 | Batch Loss: 0.000108
#   Epoch 8 | Batch 600/2503 | Batch Loss: 0.000115
#   Epoch 8 | Batch 700/2503 | Batch Loss: 0.000084
#   Epoch 8 | Batch 800/2503 | Batch Loss: 0.000186
#   Epoch 8 | Batch 900/2503 | Batch Loss: 0.000129
#   Epoch 8 | Batch 1000/2503 | Batch Loss: 0.000070
#   Epoch 8 | Batch 1100/2503 | Batch Loss: 0.000327
#   Epoch 8 | Batch 1200/2503 | Batch Loss: 0.000095
#   Epoch 8 | Batch 1300/2503 | Batch Loss: 0.001413
#   Epoch 8 | Batch 1400/2503 | Batch Loss: 0.000875
#   Epoch 8 | Batch 1500/2503 | Batch Loss: 0.005028
#   Epoch 8 | Batch 1600/2503 | Batch Loss: 0.001314
#   Epoch 8 | Batch 1700/2503 | Batch Loss: 0.000104
#   Epoch 8 | Batch 1800/2503 | Batch Loss: 0.000070
#   Epoch 8 | Batch 1900/2503 | Batch Loss: 0.000357
#   Epoch 8 | Batch 2000/2503 | Batch Loss: 0.004648
#   Epoch 8 | Batch 2100/2503 | Batch Loss: 0.004959
#   Epoch 8 | Batch 2200/2503 | Batch Loss: 0.000313
#   Epoch 8 | Batch 2300/2503 | Batch Loss: 0.000235
#   Epoch 8 | Batch 2400/2503 | Batch Loss: 0.000273
#   Epoch 8 | Batch 2500/2503 | Batch Loss: 0.000377
#
# Adam Epoch 8/100 | Time: 158.3s | Base LR: 1.00e-03
#   Train Loss: 0.001458 | Val MSE: 0.002230
#   Components - Data: 0.0015 | PDE: 98603.1257 | Arb: 0.0153
#   Epochs without improvement: 1/3
# ------------------------------------------------------------
#   Epoch 9 | Batch 100/2503 | Batch Loss: 0.000299
#   Epoch 9 | Batch 200/2503 | Batch Loss: 0.001127
#   Epoch 9 | Batch 300/2503 | Batch Loss: 0.000268
#   Epoch 9 | Batch 400/2503 | Batch Loss: 0.000274
#   Epoch 9 | Batch 500/2503 | Batch Loss: 0.000064
#   Epoch 9 | Batch 600/2503 | Batch Loss: 0.000149
#   Epoch 9 | Batch 700/2503 | Batch Loss: 0.001766
#   Epoch 9 | Batch 800/2503 | Batch Loss: 0.000065
#   Epoch 9 | Batch 900/2503 | Batch Loss: 0.004109
#   Epoch 9 | Batch 1000/2503 | Batch Loss: 0.000361
#   Epoch 9 | Batch 1100/2503 | Batch Loss: 0.000641
#   Epoch 9 | Batch 1200/2503 | Batch Loss: 0.000414
#   Epoch 9 | Batch 1300/2503 | Batch Loss: 0.000174
#   Epoch 9 | Batch 1400/2503 | Batch Loss: 0.000080
#   Epoch 9 | Batch 1500/2503 | Batch Loss: 0.001989
#   Epoch 9 | Batch 1600/2503 | Batch Loss: 0.000337
#   Epoch 9 | Batch 1700/2503 | Batch Loss: 0.000123
#   Epoch 9 | Batch 1800/2503 | Batch Loss: 0.000087
#   Epoch 9 | Batch 1900/2503 | Batch Loss: 0.000089
#   Epoch 9 | Batch 2000/2503 | Batch Loss: 0.000908
#   Epoch 9 | Batch 2100/2503 | Batch Loss: 0.004449
#   Epoch 9 | Batch 2200/2503 | Batch Loss: 0.000077
#   Epoch 9 | Batch 2300/2503 | Batch Loss: 0.000245
#   Epoch 9 | Batch 2400/2503 | Batch Loss: 0.012321
#   Epoch 9 | Batch 2500/2503 | Batch Loss: 0.000777
#
# Adam Epoch 9/100 | Time: 158.0s | Base LR: 1.00e-03
#   Train Loss: 0.001140 | Val MSE: 0.001516 *** New Best ***
#   Components - Data: 0.0011 | PDE: 127884.0241 | Arb: 0.0158
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 10 | Batch 100/2503 | Batch Loss: 0.002639
#   Epoch 10 | Batch 200/2503 | Batch Loss: 0.000150
#   Epoch 10 | Batch 300/2503 | Batch Loss: 0.000119
#   Epoch 10 | Batch 400/2503 | Batch Loss: 0.000280
#   Epoch 10 | Batch 500/2503 | Batch Loss: 0.002594
#   Epoch 10 | Batch 600/2503 | Batch Loss: 0.000129
#   Epoch 10 | Batch 700/2503 | Batch Loss: 0.000757
#   Epoch 10 | Batch 800/2503 | Batch Loss: 0.000062
#   Epoch 10 | Batch 900/2503 | Batch Loss: 0.001570
#   Epoch 10 | Batch 1000/2503 | Batch Loss: 0.000085
#   Epoch 10 | Batch 1100/2503 | Batch Loss: 0.000136
#   Epoch 10 | Batch 1200/2503 | Batch Loss: 0.000203
#   Epoch 10 | Batch 1300/2503 | Batch Loss: 0.000060
#   Epoch 10 | Batch 1400/2503 | Batch Loss: 0.000170
#   Epoch 10 | Batch 1500/2503 | Batch Loss: 0.000914
#   Epoch 10 | Batch 1600/2503 | Batch Loss: 0.015373
#   Epoch 10 | Batch 1700/2503 | Batch Loss: 0.000207
#   Epoch 10 | Batch 1800/2503 | Batch Loss: 0.001062
#   Epoch 10 | Batch 1900/2503 | Batch Loss: 0.000137
#   Epoch 10 | Batch 2000/2503 | Batch Loss: 0.000239
#   Epoch 10 | Batch 2100/2503 | Batch Loss: 0.001797
#   Epoch 10 | Batch 2200/2503 | Batch Loss: 0.000384
#   Epoch 10 | Batch 2300/2503 | Batch Loss: 0.000088
#   Epoch 10 | Batch 2400/2503 | Batch Loss: 0.000229
#   Epoch 10 | Batch 2500/2503 | Batch Loss: 0.000623
#
# Adam Epoch 10/100 | Time: 158.3s | Base LR: 1.00e-03
#   Train Loss: 0.001041 | Val MSE: 0.002297
#   Components - Data: 0.0010 | PDE: 176950.7964 | Arb: 0.0168
#   Epochs without improvement: 1/3
# ------------------------------------------------------------
#   Epoch 11 | Batch 100/2503 | Batch Loss: 0.000871
#   Epoch 11 | Batch 200/2503 | Batch Loss: 0.000212
#   Epoch 11 | Batch 300/2503 | Batch Loss: 0.000106
#   Epoch 11 | Batch 400/2503 | Batch Loss: 0.000268
#   Epoch 11 | Batch 500/2503 | Batch Loss: 0.000093
#   Epoch 11 | Batch 600/2503 | Batch Loss: 0.000117
#   Epoch 11 | Batch 700/2503 | Batch Loss: 0.000072
#   Epoch 11 | Batch 800/2503 | Batch Loss: 0.000291
#   Epoch 11 | Batch 900/2503 | Batch Loss: 0.000183
#   Epoch 11 | Batch 1000/2503 | Batch Loss: 0.000176
#   Epoch 11 | Batch 1100/2503 | Batch Loss: 0.000244
#   Epoch 11 | Batch 1200/2503 | Batch Loss: 0.000304
#   Epoch 11 | Batch 1300/2503 | Batch Loss: 0.000142
#   Epoch 11 | Batch 1400/2503 | Batch Loss: 0.000220
#   Epoch 11 | Batch 1500/2503 | Batch Loss: 0.000246
#   Epoch 11 | Batch 1600/2503 | Batch Loss: 0.000086
#   Epoch 11 | Batch 1700/2503 | Batch Loss: 0.000123
#   Epoch 11 | Batch 1800/2503 | Batch Loss: 0.000052
#   Epoch 11 | Batch 1900/2503 | Batch Loss: 0.000170
#   Epoch 11 | Batch 2000/2503 | Batch Loss: 0.000310
#   Epoch 11 | Batch 2100/2503 | Batch Loss: 0.000118
#   Epoch 11 | Batch 2200/2503 | Batch Loss: 0.000222
#   Epoch 11 | Batch 2300/2503 | Batch Loss: 0.000078
#   Epoch 11 | Batch 2400/2503 | Batch Loss: 0.014104
#   Epoch 11 | Batch 2500/2503 | Batch Loss: 0.000330
#
# Adam Epoch 11/100 | Time: 158.5s | Base LR: 1.00e-03
#   Train Loss: 0.001021 | Val MSE: 0.003000
#   Components - Data: 0.0010 | PDE: 176856.4960 | Arb: 0.0171
#   Epochs without improvement: 2/3
# ------------------------------------------------------------
#   Epoch 12 | Batch 100/2503 | Batch Loss: 0.000138
#   Epoch 12 | Batch 200/2503 | Batch Loss: 0.000180
#   Epoch 12 | Batch 300/2503 | Batch Loss: 0.000628
#   Epoch 12 | Batch 400/2503 | Batch Loss: 0.000067
#   Epoch 12 | Batch 500/2503 | Batch Loss: 0.000115
#   Epoch 12 | Batch 600/2503 | Batch Loss: 0.015958
#   Epoch 12 | Batch 700/2503 | Batch Loss: 0.000175
#   Epoch 12 | Batch 800/2503 | Batch Loss: 0.000049
#   Epoch 12 | Batch 900/2503 | Batch Loss: 0.000693
#   Epoch 12 | Batch 1000/2503 | Batch Loss: 0.000082
#   Epoch 12 | Batch 1100/2503 | Batch Loss: 0.000126
#   Epoch 12 | Batch 1200/2503 | Batch Loss: 0.000078
#   Epoch 12 | Batch 1300/2503 | Batch Loss: 0.000113
#   Epoch 12 | Batch 1400/2503 | Batch Loss: 0.003412
#   Epoch 12 | Batch 1500/2503 | Batch Loss: 0.000126
#   Epoch 12 | Batch 1600/2503 | Batch Loss: 0.000275
#   Epoch 12 | Batch 1700/2503 | Batch Loss: 0.000156
#   Epoch 12 | Batch 1800/2503 | Batch Loss: 0.000723
#   Epoch 12 | Batch 1900/2503 | Batch Loss: 0.000221
#   Epoch 12 | Batch 2000/2503 | Batch Loss: 0.000156
#   Epoch 12 | Batch 2100/2503 | Batch Loss: 0.000362
#   Epoch 12 | Batch 2200/2503 | Batch Loss: 0.000068
#   Epoch 12 | Batch 2300/2503 | Batch Loss: 0.000234
#   Epoch 12 | Batch 2400/2503 | Batch Loss: 0.002391
#   Epoch 12 | Batch 2500/2503 | Batch Loss: 0.000242
#
# Adam Epoch 12/100 | Time: 158.3s | Base LR: 5.00e-04
#   Train Loss: 0.001072 | Val MSE: 0.002404
#   Components - Data: 0.0011 | PDE: 179085.6526 | Arb: 0.0320
#   Epochs without improvement: 3/3
# ------------------------------------------------------------
#
# *** Early stopping triggered at epoch 12 ***
#
# *** Adam Phase Complete. Best Val MSE: 0.001516 ***
# Loading best model from Adam phase for fine-tuning...
#
# ============================================================
# PHASE 2: Fine-tuning with Adam (Low LR, DeepONet Groups)
# ============================================================
#   Epoch 1 | Batch 100/2503 | Batch Loss: 0.000077
#   Epoch 1 | Batch 200/2503 | Batch Loss: 0.000087
#   Epoch 1 | Batch 300/2503 | Batch Loss: 0.000750
#   Epoch 1 | Batch 400/2503 | Batch Loss: 0.001454
#   Epoch 1 | Batch 500/2503 | Batch Loss: 0.000052
#   Epoch 1 | Batch 600/2503 | Batch Loss: 0.000065
#   Epoch 1 | Batch 700/2503 | Batch Loss: 0.000056
#   Epoch 1 | Batch 800/2503 | Batch Loss: 0.004108
#   Epoch 1 | Batch 900/2503 | Batch Loss: 0.000049
#   Epoch 1 | Batch 1000/2503 | Batch Loss: 0.000060
#   Epoch 1 | Batch 1100/2503 | Batch Loss: 0.000053
#   Epoch 1 | Batch 1200/2503 | Batch Loss: 0.000147
#   Epoch 1 | Batch 1300/2503 | Batch Loss: 0.001378
#   Epoch 1 | Batch 1400/2503 | Batch Loss: 0.000160
#   Epoch 1 | Batch 1500/2503 | Batch Loss: 0.000052
#   Epoch 1 | Batch 1600/2503 | Batch Loss: 0.000072
#   Epoch 1 | Batch 1700/2503 | Batch Loss: 0.000048
#   Epoch 1 | Batch 1800/2503 | Batch Loss: 0.000052
#   Epoch 1 | Batch 1900/2503 | Batch Loss: 0.000056
#   Epoch 1 | Batch 2000/2503 | Batch Loss: 0.000051
#   Epoch 1 | Batch 2100/2503 | Batch Loss: 0.000072
#   Epoch 1 | Batch 2200/2503 | Batch Loss: 0.000081
#   Epoch 1 | Batch 2300/2503 | Batch Loss: 0.000050
#   Epoch 1 | Batch 2400/2503 | Batch Loss: 0.000061
#   Epoch 1 | Batch 2500/2503 | Batch Loss: 0.000086
#
# Fine-tune Epoch 1/50 | Time: 158.2s
#   Train Loss: 0.000345 | Val MSE: 0.001484 *** New Best ***
# ------------------------------------------------------------
#   Epoch 2 | Batch 100/2503 | Batch Loss: 0.000056
#   Epoch 2 | Batch 200/2503 | Batch Loss: 0.000055
#   Epoch 2 | Batch 300/2503 | Batch Loss: 0.000055
#   Epoch 2 | Batch 400/2503 | Batch Loss: 0.000052
#   Epoch 2 | Batch 500/2503 | Batch Loss: 0.000058
#   Epoch 2 | Batch 600/2503 | Batch Loss: 0.000049
#   Epoch 2 | Batch 700/2503 | Batch Loss: 0.000049
#   Epoch 2 | Batch 800/2503 | Batch Loss: 0.000043
#   Epoch 2 | Batch 900/2503 | Batch Loss: 0.000636
#   Epoch 2 | Batch 1000/2503 | Batch Loss: 0.003382
#   Epoch 2 | Batch 1100/2503 | Batch Loss: 0.000061
#   Epoch 2 | Batch 1200/2503 | Batch Loss: 0.000063
#   Epoch 2 | Batch 1300/2503 | Batch Loss: 0.001800
#   Epoch 2 | Batch 1400/2503 | Batch Loss: 0.000070
#   Epoch 2 | Batch 1500/2503 | Batch Loss: 0.000857
#   Epoch 2 | Batch 1600/2503 | Batch Loss: 0.000064
#   Epoch 2 | Batch 1700/2503 | Batch Loss: 0.000071
#   Epoch 2 | Batch 1800/2503 | Batch Loss: 0.000059
#   Epoch 2 | Batch 1900/2503 | Batch Loss: 0.000044
#   Epoch 2 | Batch 2000/2503 | Batch Loss: 0.000052
#   Epoch 2 | Batch 2100/2503 | Batch Loss: 0.000055
#   Epoch 2 | Batch 2200/2503 | Batch Loss: 0.000051
#   Epoch 2 | Batch 2300/2503 | Batch Loss: 0.000050
#   Epoch 2 | Batch 2400/2503 | Batch Loss: 0.000067
#   Epoch 2 | Batch 2500/2503 | Batch Loss: 0.000052
#
# Fine-tune Epoch 2/50 | Time: 158.2s
#   Train Loss: 0.000202 | Val MSE: 0.001173 *** New Best ***
# ------------------------------------------------------------
#   Epoch 3 | Batch 100/2503 | Batch Loss: 0.000061
#   Epoch 3 | Batch 200/2503 | Batch Loss: 0.000067
#   Epoch 3 | Batch 300/2503 | Batch Loss: 0.000247
#   Epoch 3 | Batch 400/2503 | Batch Loss: 0.000060
#   Epoch 3 | Batch 500/2503 | Batch Loss: 0.000080
#   Epoch 3 | Batch 600/2503 | Batch Loss: 0.000051
#   Epoch 3 | Batch 700/2503 | Batch Loss: 0.000045
#   Epoch 3 | Batch 800/2503 | Batch Loss: 0.000071
#   Epoch 3 | Batch 900/2503 | Batch Loss: 0.000979
#   Epoch 3 | Batch 1000/2503 | Batch Loss: 0.000058
#   Epoch 3 | Batch 1100/2503 | Batch Loss: 0.000063
#   Epoch 3 | Batch 1200/2503 | Batch Loss: 0.000635
#   Epoch 3 | Batch 1300/2503 | Batch Loss: 0.000059
#   Epoch 3 | Batch 1400/2503 | Batch Loss: 0.000047
#   Epoch 3 | Batch 1500/2503 | Batch Loss: 0.000055
#   Epoch 3 | Batch 1600/2503 | Batch Loss: 0.000050
#   Epoch 3 | Batch 1700/2503 | Batch Loss: 0.000061
#   Epoch 3 | Batch 1800/2503 | Batch Loss: 0.000046
#   Epoch 3 | Batch 1900/2503 | Batch Loss: 0.000046
#   Epoch 3 | Batch 2000/2503 | Batch Loss: 0.000064
#   Epoch 3 | Batch 2100/2503 | Batch Loss: 0.000062
#   Epoch 3 | Batch 2200/2503 | Batch Loss: 0.000048
#   Epoch 3 | Batch 2300/2503 | Batch Loss: 0.000048
#   Epoch 3 | Batch 2400/2503 | Batch Loss: 0.000042
#   Epoch 3 | Batch 2500/2503 | Batch Loss: 0.000068
#
# Fine-tune Epoch 3/50 | Time: 158.6s
#   Train Loss: 0.000162 | Val MSE: 0.000935 *** New Best ***
# ------------------------------------------------------------
#   Epoch 4 | Batch 100/2503 | Batch Loss: 0.000053
#   Epoch 4 | Batch 200/2503 | Batch Loss: 0.000056
#   Epoch 4 | Batch 300/2503 | Batch Loss: 0.000075
#   Epoch 4 | Batch 400/2503 | Batch Loss: 0.000056
#   Epoch 4 | Batch 500/2503 | Batch Loss: 0.000051
#   Epoch 4 | Batch 600/2503 | Batch Loss: 0.000047
#   Epoch 4 | Batch 700/2503 | Batch Loss: 0.000054
#   Epoch 4 | Batch 800/2503 | Batch Loss: 0.000043
#   Epoch 4 | Batch 900/2503 | Batch Loss: 0.000058
#   Epoch 4 | Batch 1000/2503 | Batch Loss: 0.000050
#   Epoch 4 | Batch 1100/2503 | Batch Loss: 0.000053
#   Epoch 4 | Batch 1200/2503 | Batch Loss: 0.000050
#   Epoch 4 | Batch 1300/2503 | Batch Loss: 0.000058
#   Epoch 4 | Batch 1400/2503 | Batch Loss: 0.000050
#   Epoch 4 | Batch 1500/2503 | Batch Loss: 0.000054
#   Epoch 4 | Batch 1600/2503 | Batch Loss: 0.000061
#   Epoch 4 | Batch 1700/2503 | Batch Loss: 0.000149
#   Epoch 4 | Batch 1800/2503 | Batch Loss: 0.000067
#   Epoch 4 | Batch 1900/2503 | Batch Loss: 0.000076
#   Epoch 4 | Batch 2000/2503 | Batch Loss: 0.000048
#   Epoch 4 | Batch 2100/2503 | Batch Loss: 0.000056
#   Epoch 4 | Batch 2200/2503 | Batch Loss: 0.000054
#   Epoch 4 | Batch 2300/2503 | Batch Loss: 0.000048
#   Epoch 4 | Batch 2400/2503 | Batch Loss: 0.000062
#   Epoch 4 | Batch 2500/2503 | Batch Loss: 0.003800
#
# Fine-tune Epoch 4/50 | Time: 158.6s
#   Train Loss: 0.000139 | Val MSE: 0.000791 *** New Best ***
# ------------------------------------------------------------
#   Epoch 5 | Batch 100/2503 | Batch Loss: 0.000057
#   Epoch 5 | Batch 200/2503 | Batch Loss: 0.000053
#   Epoch 5 | Batch 300/2503 | Batch Loss: 0.000049
#   Epoch 5 | Batch 400/2503 | Batch Loss: 0.000094
#   Epoch 5 | Batch 500/2503 | Batch Loss: 0.000053
#   Epoch 5 | Batch 600/2503 | Batch Loss: 0.000288
#   Epoch 5 | Batch 700/2503 | Batch Loss: 0.000053
#   Epoch 5 | Batch 800/2503 | Batch Loss: 0.000053
#   Epoch 5 | Batch 900/2503 | Batch Loss: 0.000055
#   Epoch 5 | Batch 1000/2503 | Batch Loss: 0.000050
#   Epoch 5 | Batch 1100/2503 | Batch Loss: 0.000070
#   Epoch 5 | Batch 1200/2503 | Batch Loss: 0.000044
#   Epoch 5 | Batch 1300/2503 | Batch Loss: 0.000051
#   Epoch 5 | Batch 1400/2503 | Batch Loss: 0.000039
#   Epoch 5 | Batch 1500/2503 | Batch Loss: 0.000065
#   Epoch 5 | Batch 1600/2503 | Batch Loss: 0.000050
#   Epoch 5 | Batch 1700/2503 | Batch Loss: 0.000053
#   Epoch 5 | Batch 1800/2503 | Batch Loss: 0.000047
#   Epoch 5 | Batch 1900/2503 | Batch Loss: 0.000068
#   Epoch 5 | Batch 2000/2503 | Batch Loss: 0.000049
#   Epoch 5 | Batch 2100/2503 | Batch Loss: 0.000046
#   Epoch 5 | Batch 2200/2503 | Batch Loss: 0.000049
#   Epoch 5 | Batch 2300/2503 | Batch Loss: 0.000048
#   Epoch 5 | Batch 2400/2503 | Batch Loss: 0.000073
#   Epoch 5 | Batch 2500/2503 | Batch Loss: 0.000046
#
# Fine-tune Epoch 5/50 | Time: 158.3s
#   Train Loss: 0.000125 | Val MSE: 0.000686 *** New Best ***
# ------------------------------------------------------------
#   Epoch 6 | Batch 100/2503 | Batch Loss: 0.000044
#   Epoch 6 | Batch 200/2503 | Batch Loss: 0.000040
#   Epoch 6 | Batch 300/2503 | Batch Loss: 0.000038
#   Epoch 6 | Batch 400/2503 | Batch Loss: 0.000043
#   Epoch 6 | Batch 500/2503 | Batch Loss: 0.000051
#   Epoch 6 | Batch 600/2503 | Batch Loss: 0.000041
#   Epoch 6 | Batch 700/2503 | Batch Loss: 0.000084
#   Epoch 6 | Batch 800/2503 | Batch Loss: 0.000053
#   Epoch 6 | Batch 900/2503 | Batch Loss: 0.000042
#   Epoch 6 | Batch 1000/2503 | Batch Loss: 0.000168
#   Epoch 6 | Batch 1100/2503 | Batch Loss: 0.000047
#   Epoch 6 | Batch 1200/2503 | Batch Loss: 0.000056
#   Epoch 6 | Batch 1300/2503 | Batch Loss: 0.000048
#   Epoch 6 | Batch 1400/2503 | Batch Loss: 0.000051
#   Epoch 6 | Batch 1500/2503 | Batch Loss: 0.000035
#   Epoch 6 | Batch 1600/2503 | Batch Loss: 0.000038
#   Epoch 6 | Batch 1700/2503 | Batch Loss: 0.000048
#   Epoch 6 | Batch 1800/2503 | Batch Loss: 0.000064
#   Epoch 6 | Batch 1900/2503 | Batch Loss: 0.000049
#   Epoch 6 | Batch 2000/2503 | Batch Loss: 0.000044
#   Epoch 6 | Batch 2100/2503 | Batch Loss: 0.000047
#   Epoch 6 | Batch 2200/2503 | Batch Loss: 0.000044
#   Epoch 6 | Batch 2300/2503 | Batch Loss: 0.000040
#   Epoch 6 | Batch 2400/2503 | Batch Loss: 0.000042
#   Epoch 6 | Batch 2500/2503 | Batch Loss: 0.000038
#
# Fine-tune Epoch 6/50 | Time: 158.2s
#   Train Loss: 0.000114 | Val MSE: 0.000581 *** New Best ***
# ------------------------------------------------------------
#   Epoch 7 | Batch 100/2503 | Batch Loss: 0.000103
#   Epoch 7 | Batch 200/2503 | Batch Loss: 0.000049
#   Epoch 7 | Batch 300/2503 | Batch Loss: 0.000201
#   Epoch 7 | Batch 400/2503 | Batch Loss: 0.000530
#   Epoch 7 | Batch 500/2503 | Batch Loss: 0.000071
#   Epoch 7 | Batch 600/2503 | Batch Loss: 0.000099
#   Epoch 7 | Batch 700/2503 | Batch Loss: 0.000048
#   Epoch 7 | Batch 800/2503 | Batch Loss: 0.000060
#   Epoch 7 | Batch 900/2503 | Batch Loss: 0.000074
#   Epoch 7 | Batch 1000/2503 | Batch Loss: 0.000042
#   Epoch 7 | Batch 1100/2503 | Batch Loss: 0.000044
#   Epoch 7 | Batch 1200/2503 | Batch Loss: 0.000042
#   Epoch 7 | Batch 1300/2503 | Batch Loss: 0.000080
#   Epoch 7 | Batch 1400/2503 | Batch Loss: 0.000053
#   Epoch 7 | Batch 1500/2503 | Batch Loss: 0.000040
#   Epoch 7 | Batch 1600/2503 | Batch Loss: 0.000055
#   Epoch 7 | Batch 1700/2503 | Batch Loss: 0.000058
#   Epoch 7 | Batch 1800/2503 | Batch Loss: 0.000048
#   Epoch 7 | Batch 1900/2503 | Batch Loss: 0.000641
#   Epoch 7 | Batch 2000/2503 | Batch Loss: 0.000084
#   Epoch 7 | Batch 2100/2503 | Batch Loss: 0.000046
#   Epoch 7 | Batch 2200/2503 | Batch Loss: 0.000054
#   Epoch 7 | Batch 2300/2503 | Batch Loss: 0.000058
#   Epoch 7 | Batch 2400/2503 | Batch Loss: 0.000038
#   Epoch 7 | Batch 2500/2503 | Batch Loss: 0.000037
#
# Fine-tune Epoch 7/50 | Time: 158.2s
#   Train Loss: 0.000107 | Val MSE: 0.000550 *** New Best ***
# ------------------------------------------------------------
#   Epoch 8 | Batch 100/2503 | Batch Loss: 0.000043
#   Epoch 8 | Batch 200/2503 | Batch Loss: 0.000049
#   Epoch 8 | Batch 300/2503 | Batch Loss: 0.000039
#   Epoch 8 | Batch 400/2503 | Batch Loss: 0.000040
#   Epoch 8 | Batch 500/2503 | Batch Loss: 0.000039
#   Epoch 8 | Batch 600/2503 | Batch Loss: 0.000052
#   Epoch 8 | Batch 700/2503 | Batch Loss: 0.000065
#   Epoch 8 | Batch 800/2503 | Batch Loss: 0.000159
#   Epoch 8 | Batch 900/2503 | Batch Loss: 0.000040
#   Epoch 8 | Batch 1000/2503 | Batch Loss: 0.000045
#   Epoch 8 | Batch 1100/2503 | Batch Loss: 0.000050
#   Epoch 8 | Batch 1200/2503 | Batch Loss: 0.000181
#   Epoch 8 | Batch 1300/2503 | Batch Loss: 0.000044
#   Epoch 8 | Batch 1400/2503 | Batch Loss: 0.000045
#   Epoch 8 | Batch 1500/2503 | Batch Loss: 0.000041
#   Epoch 8 | Batch 1600/2503 | Batch Loss: 0.000051
#   Epoch 8 | Batch 1700/2503 | Batch Loss: 0.000050
#   Epoch 8 | Batch 1800/2503 | Batch Loss: 0.000037
#   Epoch 8 | Batch 1900/2503 | Batch Loss: 0.000054
#   Epoch 8 | Batch 2000/2503 | Batch Loss: 0.000039
#   Epoch 8 | Batch 2100/2503 | Batch Loss: 0.000045
#   Epoch 8 | Batch 2200/2503 | Batch Loss: 0.000048
#   Epoch 8 | Batch 2300/2503 | Batch Loss: 0.001018
#   Epoch 8 | Batch 2400/2503 | Batch Loss: 0.000049
#   Epoch 8 | Batch 2500/2503 | Batch Loss: 0.000051
#
# Fine-tune Epoch 8/50 | Time: 158.4s
#   Train Loss: 0.000100 | Val MSE: 0.000517 *** New Best ***
# ------------------------------------------------------------
#   Epoch 9 | Batch 100/2503 | Batch Loss: 0.000044
#   Epoch 9 | Batch 200/2503 | Batch Loss: 0.000044
#   Epoch 9 | Batch 300/2503 | Batch Loss: 0.000042
#   Epoch 9 | Batch 400/2503 | Batch Loss: 0.000038
#   Epoch 9 | Batch 500/2503 | Batch Loss: 0.000046
#   Epoch 9 | Batch 600/2503 | Batch Loss: 0.000045
#   Epoch 9 | Batch 700/2503 | Batch Loss: 0.001196
#   Epoch 9 | Batch 800/2503 | Batch Loss: 0.000041
#   Epoch 9 | Batch 900/2503 | Batch Loss: 0.000041
#   Epoch 9 | Batch 1000/2503 | Batch Loss: 0.000044
#   Epoch 9 | Batch 1100/2503 | Batch Loss: 0.000047
#   Epoch 9 | Batch 1200/2503 | Batch Loss: 0.003464
#   Epoch 9 | Batch 1300/2503 | Batch Loss: 0.000043
#   Epoch 9 | Batch 1400/2503 | Batch Loss: 0.000046
#   Epoch 9 | Batch 1500/2503 | Batch Loss: 0.000059
#   Epoch 9 | Batch 1600/2503 | Batch Loss: 0.000046
#   Epoch 9 | Batch 1700/2503 | Batch Loss: 0.000060
#   Epoch 9 | Batch 1800/2503 | Batch Loss: 0.000043
#   Epoch 9 | Batch 1900/2503 | Batch Loss: 0.000050
#   Epoch 9 | Batch 2000/2503 | Batch Loss: 0.000037
#   Epoch 9 | Batch 2100/2503 | Batch Loss: 0.000045
#   Epoch 9 | Batch 2200/2503 | Batch Loss: 0.000093
#   Epoch 9 | Batch 2300/2503 | Batch Loss: 0.000040
#   Epoch 9 | Batch 2400/2503 | Batch Loss: 0.000047
#   Epoch 9 | Batch 2500/2503 | Batch Loss: 0.000064
#
# Fine-tune Epoch 9/50 | Time: 158.1s
#   Train Loss: 0.000095 | Val MSE: 0.000465 *** New Best ***
# ------------------------------------------------------------
#   Epoch 10 | Batch 100/2503 | Batch Loss: 0.000043
#   Epoch 10 | Batch 200/2503 | Batch Loss: 0.000038
#   Epoch 10 | Batch 300/2503 | Batch Loss: 0.000263
#   Epoch 10 | Batch 400/2503 | Batch Loss: 0.000038
#   Epoch 10 | Batch 500/2503 | Batch Loss: 0.000036
#   Epoch 10 | Batch 600/2503 | Batch Loss: 0.000038
#   Epoch 10 | Batch 700/2503 | Batch Loss: 0.000047
#   Epoch 10 | Batch 800/2503 | Batch Loss: 0.000039
#   Epoch 10 | Batch 900/2503 | Batch Loss: 0.000041
#   Epoch 10 | Batch 1000/2503 | Batch Loss: 0.000043
#   Epoch 10 | Batch 1100/2503 | Batch Loss: 0.000048
#   Epoch 10 | Batch 1200/2503 | Batch Loss: 0.000056
#   Epoch 10 | Batch 1300/2503 | Batch Loss: 0.000035
#   Epoch 10 | Batch 1400/2503 | Batch Loss: 0.000037
#   Epoch 10 | Batch 1500/2503 | Batch Loss: 0.000192
#   Epoch 10 | Batch 1600/2503 | Batch Loss: 0.000048
#   Epoch 10 | Batch 1700/2503 | Batch Loss: 0.000176
#   Epoch 10 | Batch 1800/2503 | Batch Loss: 0.000039
#   Epoch 10 | Batch 1900/2503 | Batch Loss: 0.000068
#   Epoch 10 | Batch 2000/2503 | Batch Loss: 0.000036
#   Epoch 10 | Batch 2100/2503 | Batch Loss: 0.000036
#   Epoch 10 | Batch 2200/2503 | Batch Loss: 0.000047
#   Epoch 10 | Batch 2300/2503 | Batch Loss: 0.000052
#   Epoch 10 | Batch 2400/2503 | Batch Loss: 0.000046
#   Epoch 10 | Batch 2500/2503 | Batch Loss: 0.000041
#
# Fine-tune Epoch 10/50 | Time: 158.2s
#   Train Loss: 0.000092 | Val MSE: 0.000446 *** New Best ***
# ------------------------------------------------------------
#   Epoch 11 | Batch 100/2503 | Batch Loss: 0.000116
#   Epoch 11 | Batch 200/2503 | Batch Loss: 0.000042
#   Epoch 11 | Batch 300/2503 | Batch Loss: 0.000041
#   Epoch 11 | Batch 400/2503 | Batch Loss: 0.000050
#   Epoch 11 | Batch 500/2503 | Batch Loss: 0.000038
#   Epoch 11 | Batch 600/2503 | Batch Loss: 0.001008
#   Epoch 11 | Batch 700/2503 | Batch Loss: 0.000041
#   Epoch 11 | Batch 800/2503 | Batch Loss: 0.000116
#   Epoch 11 | Batch 900/2503 | Batch Loss: 0.000045
#   Epoch 11 | Batch 1000/2503 | Batch Loss: 0.000123
#   Epoch 11 | Batch 1100/2503 | Batch Loss: 0.000107
#   Epoch 11 | Batch 1200/2503 | Batch Loss: 0.000041
#   Epoch 11 | Batch 1300/2503 | Batch Loss: 0.000045
#   Epoch 11 | Batch 1400/2503 | Batch Loss: 0.000034
#   Epoch 11 | Batch 1500/2503 | Batch Loss: 0.000227
#   Epoch 11 | Batch 1600/2503 | Batch Loss: 0.000035
#   Epoch 11 | Batch 1700/2503 | Batch Loss: 0.000038
#   Epoch 11 | Batch 1800/2503 | Batch Loss: 0.000039
#   Epoch 11 | Batch 1900/2503 | Batch Loss: 0.000042
#   Epoch 11 | Batch 2000/2503 | Batch Loss: 0.000039
#   Epoch 11 | Batch 2100/2503 | Batch Loss: 0.000049
#   Epoch 11 | Batch 2200/2503 | Batch Loss: 0.000039
#   Epoch 11 | Batch 2300/2503 | Batch Loss: 0.000045
#   Epoch 11 | Batch 2400/2503 | Batch Loss: 0.000108
#   Epoch 11 | Batch 2500/2503 | Batch Loss: 0.000039
#
# Fine-tune Epoch 11/50 | Time: 158.2s
#   Train Loss: 0.000088 | Val MSE: 0.000430 *** New Best ***
# ------------------------------------------------------------
#   Epoch 12 | Batch 100/2503 | Batch Loss: 0.000040
#   Epoch 12 | Batch 200/2503 | Batch Loss: 0.000042
#   Epoch 12 | Batch 300/2503 | Batch Loss: 0.000055
#   Epoch 12 | Batch 400/2503 | Batch Loss: 0.000040
#   Epoch 12 | Batch 500/2503 | Batch Loss: 0.000044
#   Epoch 12 | Batch 600/2503 | Batch Loss: 0.000050
#   Epoch 12 | Batch 700/2503 | Batch Loss: 0.000465
#   Epoch 12 | Batch 800/2503 | Batch Loss: 0.000031
#   Epoch 12 | Batch 900/2503 | Batch Loss: 0.000050
#   Epoch 12 | Batch 1000/2503 | Batch Loss: 0.000038
#   Epoch 12 | Batch 1100/2503 | Batch Loss: 0.000049
#   Epoch 12 | Batch 1200/2503 | Batch Loss: 0.000040
#   Epoch 12 | Batch 1300/2503 | Batch Loss: 0.000059
#   Epoch 12 | Batch 1400/2503 | Batch Loss: 0.000042
#   Epoch 12 | Batch 1500/2503 | Batch Loss: 0.000055
#   Epoch 12 | Batch 1600/2503 | Batch Loss: 0.000417
#   Epoch 12 | Batch 1700/2503 | Batch Loss: 0.000054
#   Epoch 12 | Batch 1800/2503 | Batch Loss: 0.000043
#   Epoch 12 | Batch 1900/2503 | Batch Loss: 0.000042
#   Epoch 12 | Batch 2000/2503 | Batch Loss: 0.000175
#   Epoch 12 | Batch 2100/2503 | Batch Loss: 0.000036
#   Epoch 12 | Batch 2200/2503 | Batch Loss: 0.000036
#   Epoch 12 | Batch 2300/2503 | Batch Loss: 0.000034
#   Epoch 12 | Batch 2400/2503 | Batch Loss: 0.000113
#   Epoch 12 | Batch 2500/2503 | Batch Loss: 0.000210
#
# Fine-tune Epoch 12/50 | Time: 158.4s
#   Train Loss: 0.000085 | Val MSE: 0.000418 *** New Best ***
# ------------------------------------------------------------
#   Epoch 13 | Batch 100/2503 | Batch Loss: 0.000041
#   Epoch 13 | Batch 200/2503 | Batch Loss: 0.000052
#   Epoch 13 | Batch 300/2503 | Batch Loss: 0.000036
#   Epoch 13 | Batch 400/2503 | Batch Loss: 0.000035
#   Epoch 13 | Batch 500/2503 | Batch Loss: 0.000044
#   Epoch 13 | Batch 600/2503 | Batch Loss: 0.000040
#   Epoch 13 | Batch 700/2503 | Batch Loss: 0.000042
#   Epoch 13 | Batch 800/2503 | Batch Loss: 0.000037
#   Epoch 13 | Batch 900/2503 | Batch Loss: 0.000044
#   Epoch 13 | Batch 1000/2503 | Batch Loss: 0.000033
#   Epoch 13 | Batch 1100/2503 | Batch Loss: 0.000052
#   Epoch 13 | Batch 1200/2503 | Batch Loss: 0.000035
#   Epoch 13 | Batch 1300/2503 | Batch Loss: 0.000042
#   Epoch 13 | Batch 1400/2503 | Batch Loss: 0.000045
#   Epoch 13 | Batch 1500/2503 | Batch Loss: 0.000033
#   Epoch 13 | Batch 1600/2503 | Batch Loss: 0.000030
#   Epoch 13 | Batch 1700/2503 | Batch Loss: 0.000037
#   Epoch 13 | Batch 1800/2503 | Batch Loss: 0.000032
#   Epoch 13 | Batch 1900/2503 | Batch Loss: 0.000037
#   Epoch 13 | Batch 2000/2503 | Batch Loss: 0.000058
#   Epoch 13 | Batch 2100/2503 | Batch Loss: 0.000033
#   Epoch 13 | Batch 2200/2503 | Batch Loss: 0.000041
#   Epoch 13 | Batch 2300/2503 | Batch Loss: 0.000048
#   Epoch 13 | Batch 2400/2503 | Batch Loss: 0.000039
#   Epoch 13 | Batch 2500/2503 | Batch Loss: 0.000043
#
# Fine-tune Epoch 13/50 | Time: 158.3s
#   Train Loss: 0.000082 | Val MSE: 0.000363 *** New Best ***
# ------------------------------------------------------------
#   Epoch 14 | Batch 100/2503 | Batch Loss: 0.000036
#   Epoch 14 | Batch 200/2503 | Batch Loss: 0.000114
#   Epoch 14 | Batch 300/2503 | Batch Loss: 0.000041
#   Epoch 14 | Batch 400/2503 | Batch Loss: 0.000053
#   Epoch 14 | Batch 500/2503 | Batch Loss: 0.000069
#   Epoch 14 | Batch 600/2503 | Batch Loss: 0.000048
#   Epoch 14 | Batch 700/2503 | Batch Loss: 0.000033
#   Epoch 14 | Batch 800/2503 | Batch Loss: 0.000038
#   Epoch 14 | Batch 900/2503 | Batch Loss: 0.000036
#   Epoch 14 | Batch 1000/2503 | Batch Loss: 0.000042
#   Epoch 14 | Batch 1100/2503 | Batch Loss: 0.000137
#   Epoch 14 | Batch 1200/2503 | Batch Loss: 0.000046
#   Epoch 14 | Batch 1300/2503 | Batch Loss: 0.000032
#   Epoch 14 | Batch 1400/2503 | Batch Loss: 0.000052
#   Epoch 14 | Batch 1500/2503 | Batch Loss: 0.000113
#   Epoch 14 | Batch 1600/2503 | Batch Loss: 0.000036
#   Epoch 14 | Batch 1700/2503 | Batch Loss: 0.000044
#   Epoch 14 | Batch 1800/2503 | Batch Loss: 0.000031
#   Epoch 14 | Batch 1900/2503 | Batch Loss: 0.000039
#   Epoch 14 | Batch 2000/2503 | Batch Loss: 0.000033
#   Epoch 14 | Batch 2100/2503 | Batch Loss: 0.000035
#   Epoch 14 | Batch 2200/2503 | Batch Loss: 0.000048
#   Epoch 14 | Batch 2300/2503 | Batch Loss: 0.000044
#   Epoch 14 | Batch 2400/2503 | Batch Loss: 0.000047
#   Epoch 14 | Batch 2500/2503 | Batch Loss: 0.000035
#
# Fine-tune Epoch 14/50 | Time: 158.3s
#   Train Loss: 0.000080 | Val MSE: 0.000366
# ------------------------------------------------------------
#   Epoch 15 | Batch 100/2503 | Batch Loss: 0.000036
#   Epoch 15 | Batch 200/2503 | Batch Loss: 0.000032
#   Epoch 15 | Batch 300/2503 | Batch Loss: 0.000036
#   Epoch 15 | Batch 400/2503 | Batch Loss: 0.000036
#   Epoch 15 | Batch 500/2503 | Batch Loss: 0.000040
#   Epoch 15 | Batch 600/2503 | Batch Loss: 0.000039
#   Epoch 15 | Batch 700/2503 | Batch Loss: 0.000312
#   Epoch 15 | Batch 800/2503 | Batch Loss: 0.000035
#   Epoch 15 | Batch 900/2503 | Batch Loss: 0.000044
#   Epoch 15 | Batch 1000/2503 | Batch Loss: 0.000038
#   Epoch 15 | Batch 1100/2503 | Batch Loss: 0.000144
#   Epoch 15 | Batch 1200/2503 | Batch Loss: 0.000033
#   Epoch 15 | Batch 1300/2503 | Batch Loss: 0.000032
#   Epoch 15 | Batch 1400/2503 | Batch Loss: 0.000030
#   Epoch 15 | Batch 1500/2503 | Batch Loss: 0.000041
#   Epoch 15 | Batch 1600/2503 | Batch Loss: 0.000028
#   Epoch 15 | Batch 1700/2503 | Batch Loss: 0.000107
#   Epoch 15 | Batch 1800/2503 | Batch Loss: 0.000034
#   Epoch 15 | Batch 1900/2503 | Batch Loss: 0.000035
#   Epoch 15 | Batch 2000/2503 | Batch Loss: 0.000029
#   Epoch 15 | Batch 2100/2503 | Batch Loss: 0.000043
#   Epoch 15 | Batch 2200/2503 | Batch Loss: 0.000039
#   Epoch 15 | Batch 2300/2503 | Batch Loss: 0.000038
#   Epoch 15 | Batch 2400/2503 | Batch Loss: 0.000038
#   Epoch 15 | Batch 2500/2503 | Batch Loss: 0.000036
#
# Fine-tune Epoch 15/50 | Time: 158.3s
#   Train Loss: 0.000078 | Val MSE: 0.000346 *** New Best ***
# ------------------------------------------------------------
#   Epoch 16 | Batch 100/2503 | Batch Loss: 0.000031
#   Epoch 16 | Batch 200/2503 | Batch Loss: 0.000054
#   Epoch 16 | Batch 300/2503 | Batch Loss: 0.000029
#   Epoch 16 | Batch 400/2503 | Batch Loss: 0.000041
#   Epoch 16 | Batch 500/2503 | Batch Loss: 0.000039
#   Epoch 16 | Batch 600/2503 | Batch Loss: 0.000039
#   Epoch 16 | Batch 700/2503 | Batch Loss: 0.000043
#   Epoch 16 | Batch 800/2503 | Batch Loss: 0.000132
#   Epoch 16 | Batch 900/2503 | Batch Loss: 0.000039
#   Epoch 16 | Batch 1000/2503 | Batch Loss: 0.000040
#   Epoch 16 | Batch 1100/2503 | Batch Loss: 0.000183
#   Epoch 16 | Batch 1200/2503 | Batch Loss: 0.000042
#   Epoch 16 | Batch 1300/2503 | Batch Loss: 0.000044
#   Epoch 16 | Batch 1400/2503 | Batch Loss: 0.000040
#   Epoch 16 | Batch 1500/2503 | Batch Loss: 0.000029
#   Epoch 16 | Batch 1600/2503 | Batch Loss: 0.000035
#   Epoch 16 | Batch 1700/2503 | Batch Loss: 0.000039
#   Epoch 16 | Batch 1800/2503 | Batch Loss: 0.000033
#   Epoch 16 | Batch 1900/2503 | Batch Loss: 0.000042
#   Epoch 16 | Batch 2000/2503 | Batch Loss: 0.000036
#   Epoch 16 | Batch 2100/2503 | Batch Loss: 0.000032
#   Epoch 16 | Batch 2200/2503 | Batch Loss: 0.000036
#   Epoch 16 | Batch 2300/2503 | Batch Loss: 0.000034
#   Epoch 16 | Batch 2400/2503 | Batch Loss: 0.000036
#   Epoch 16 | Batch 2500/2503 | Batch Loss: 0.000032
#
# Fine-tune Epoch 16/50 | Time: 158.4s
#   Train Loss: 0.000075 | Val MSE: 0.000350
# ------------------------------------------------------------
#   Epoch 17 | Batch 100/2503 | Batch Loss: 0.000032
#   Epoch 17 | Batch 200/2503 | Batch Loss: 0.000056
#   Epoch 17 | Batch 300/2503 | Batch Loss: 0.000033
#   Epoch 17 | Batch 400/2503 | Batch Loss: 0.000045
#   Epoch 17 | Batch 500/2503 | Batch Loss: 0.000058
#   Epoch 17 | Batch 600/2503 | Batch Loss: 0.000059
#   Epoch 17 | Batch 700/2503 | Batch Loss: 0.000077
#   Epoch 17 | Batch 800/2503 | Batch Loss: 0.000039
#   Epoch 17 | Batch 900/2503 | Batch Loss: 0.000033
#   Epoch 17 | Batch 1000/2503 | Batch Loss: 0.000329
#   Epoch 17 | Batch 1100/2503 | Batch Loss: 0.000043
#   Epoch 17 | Batch 1200/2503 | Batch Loss: 0.000119
#   Epoch 17 | Batch 1300/2503 | Batch Loss: 0.000031
#   Epoch 17 | Batch 1400/2503 | Batch Loss: 0.000044
#   Epoch 17 | Batch 1500/2503 | Batch Loss: 0.000031
#   Epoch 17 | Batch 1600/2503 | Batch Loss: 0.000034
#   Epoch 17 | Batch 1700/2503 | Batch Loss: 0.000037
#   Epoch 17 | Batch 1800/2503 | Batch Loss: 0.000032
#   Epoch 17 | Batch 1900/2503 | Batch Loss: 0.000037
#   Epoch 17 | Batch 2000/2503 | Batch Loss: 0.000034
#   Epoch 17 | Batch 2100/2503 | Batch Loss: 0.000033
#   Epoch 17 | Batch 2200/2503 | Batch Loss: 0.000038
#   Epoch 17 | Batch 2300/2503 | Batch Loss: 0.000030
#   Epoch 17 | Batch 2400/2503 | Batch Loss: 0.000041
#   Epoch 17 | Batch 2500/2503 | Batch Loss: 0.000041
#
# Fine-tune Epoch 17/50 | Time: 158.4s
#   Train Loss: 0.000074 | Val MSE: 0.000326 *** New Best ***
# ------------------------------------------------------------
#   Epoch 18 | Batch 100/2503 | Batch Loss: 0.000036
#   Epoch 18 | Batch 200/2503 | Batch Loss: 0.000040
#   Epoch 18 | Batch 300/2503 | Batch Loss: 0.000036
#   Epoch 18 | Batch 400/2503 | Batch Loss: 0.000037
#   Epoch 18 | Batch 500/2503 | Batch Loss: 0.000038
#   Epoch 18 | Batch 600/2503 | Batch Loss: 0.000034
#   Epoch 18 | Batch 700/2503 | Batch Loss: 0.000481
#   Epoch 18 | Batch 800/2503 | Batch Loss: 0.000030
#   Epoch 18 | Batch 900/2503 | Batch Loss: 0.000029
#   Epoch 18 | Batch 1000/2503 | Batch Loss: 0.000036
#   Epoch 18 | Batch 1100/2503 | Batch Loss: 0.000033
#   Epoch 18 | Batch 1200/2503 | Batch Loss: 0.000037
#   Epoch 18 | Batch 1300/2503 | Batch Loss: 0.000042
#   Epoch 18 | Batch 1400/2503 | Batch Loss: 0.000084
#   Epoch 18 | Batch 1500/2503 | Batch Loss: 0.000144
#   Epoch 18 | Batch 1600/2503 | Batch Loss: 0.000052
#   Epoch 18 | Batch 1700/2503 | Batch Loss: 0.000082
#   Epoch 18 | Batch 1800/2503 | Batch Loss: 0.000032
#   Epoch 18 | Batch 1900/2503 | Batch Loss: 0.000036
#   Epoch 18 | Batch 2000/2503 | Batch Loss: 0.000038
#   Epoch 18 | Batch 2100/2503 | Batch Loss: 0.000034
#   Epoch 18 | Batch 2200/2503 | Batch Loss: 0.000042
#   Epoch 18 | Batch 2300/2503 | Batch Loss: 0.000030
#   Epoch 18 | Batch 2400/2503 | Batch Loss: 0.000065
#   Epoch 18 | Batch 2500/2503 | Batch Loss: 0.000033
#
# Fine-tune Epoch 18/50 | Time: 158.5s
#   Train Loss: 0.000072 | Val MSE: 0.000290 *** New Best ***
# ------------------------------------------------------------
#   Epoch 19 | Batch 100/2503 | Batch Loss: 0.000044
#   Epoch 19 | Batch 200/2503 | Batch Loss: 0.000029
#   Epoch 19 | Batch 300/2503 | Batch Loss: 0.000037
#   Epoch 19 | Batch 400/2503 | Batch Loss: 0.000030
#   Epoch 19 | Batch 500/2503 | Batch Loss: 0.000130
#   Epoch 19 | Batch 600/2503 | Batch Loss: 0.000040
#   Epoch 19 | Batch 700/2503 | Batch Loss: 0.000198
#   Epoch 19 | Batch 800/2503 | Batch Loss: 0.000029
#   Epoch 19 | Batch 900/2503 | Batch Loss: 0.000854
#   Epoch 19 | Batch 1000/2503 | Batch Loss: 0.000041
#   Epoch 19 | Batch 1100/2503 | Batch Loss: 0.000031
#   Epoch 19 | Batch 1200/2503 | Batch Loss: 0.000029
#   Epoch 19 | Batch 1300/2503 | Batch Loss: 0.000031
#   Epoch 19 | Batch 1400/2503 | Batch Loss: 0.000033
#   Epoch 19 | Batch 1500/2503 | Batch Loss: 0.000044
#   Epoch 19 | Batch 1600/2503 | Batch Loss: 0.000042
#   Epoch 19 | Batch 1700/2503 | Batch Loss: 0.000096
#   Epoch 19 | Batch 1800/2503 | Batch Loss: 0.000035
#   Epoch 19 | Batch 1900/2503 | Batch Loss: 0.000034
#   Epoch 19 | Batch 2000/2503 | Batch Loss: 0.000029
#   Epoch 19 | Batch 2100/2503 | Batch Loss: 0.000032
#   Epoch 19 | Batch 2200/2503 | Batch Loss: 0.000027
#   Epoch 19 | Batch 2300/2503 | Batch Loss: 0.000039
#   Epoch 19 | Batch 2400/2503 | Batch Loss: 0.000040
#   Epoch 19 | Batch 2500/2503 | Batch Loss: 0.000031
#
# Fine-tune Epoch 19/50 | Time: 158.3s
#   Train Loss: 0.000071 | Val MSE: 0.000295
# ------------------------------------------------------------
#   Epoch 20 | Batch 100/2503 | Batch Loss: 0.000044
#   Epoch 20 | Batch 200/2503 | Batch Loss: 0.000028
#   Epoch 20 | Batch 300/2503 | Batch Loss: 0.000031
#   Epoch 20 | Batch 400/2503 | Batch Loss: 0.000033
#   Epoch 20 | Batch 500/2503 | Batch Loss: 0.000024
#   Epoch 20 | Batch 600/2503 | Batch Loss: 0.000030
#   Epoch 20 | Batch 700/2503 | Batch Loss: 0.000028
#   Epoch 20 | Batch 800/2503 | Batch Loss: 0.000036
#   Epoch 20 | Batch 900/2503 | Batch Loss: 0.000036
#   Epoch 20 | Batch 1000/2503 | Batch Loss: 0.000033
#   Epoch 20 | Batch 1100/2503 | Batch Loss: 0.000034
#   Epoch 20 | Batch 1200/2503 | Batch Loss: 0.000168
#   Epoch 20 | Batch 1300/2503 | Batch Loss: 0.000029
#   Epoch 20 | Batch 1400/2503 | Batch Loss: 0.000035
#   Epoch 20 | Batch 1500/2503 | Batch Loss: 0.000030
#   Epoch 20 | Batch 1600/2503 | Batch Loss: 0.000050
#   Epoch 20 | Batch 1700/2503 | Batch Loss: 0.000034
#   Epoch 20 | Batch 1800/2503 | Batch Loss: 0.000034
#   Epoch 20 | Batch 1900/2503 | Batch Loss: 0.000044
#   Epoch 20 | Batch 2000/2503 | Batch Loss: 0.000037
#   Epoch 20 | Batch 2100/2503 | Batch Loss: 0.000082
#   Epoch 20 | Batch 2200/2503 | Batch Loss: 0.000036
#   Epoch 20 | Batch 2300/2503 | Batch Loss: 0.000063
#   Epoch 20 | Batch 2400/2503 | Batch Loss: 0.000047
#   Epoch 20 | Batch 2500/2503 | Batch Loss: 0.000040
#
# Fine-tune Epoch 20/50 | Time: 158.6s
#   Train Loss: 0.000070 | Val MSE: 0.000289 *** New Best ***
# ------------------------------------------------------------
#   Epoch 21 | Batch 100/2503 | Batch Loss: 0.001033
# ...
#   Epoch 21 | Batch 1000/2503 | Batch Loss: 0.000045
#   Epoch 21 | Batch 1100/2503 | Batch Loss: 0.000039
#   Epoch 21 | Batch 1200/2503 | Batch Loss: 0.000030
#   Epoch 21 | Batch 1300/2503 | Batch Loss: 0.000133
#   Epoch 21 | Batch 1400/2503 | Batch Loss: 0.000038
#   Epoch 21 | Batch 1500/2503 | Batch Loss: 0.000031
#   Epoch 21 | Batch 1600/2503 | Batch Loss: 0.000093
#   Epoch 21 | Batch 1700/2503 | Batch Loss: 0.000032
#   Epoch 21 | Batch 1800/2503 | Batch Loss: 0.000036
#   Epoch 21 | Batch 1900/2503 | Batch Loss: 0.000036
#   Epoch 21 | Batch 2000/2503 | Batch Loss: 0.000546
#   Epoch 21 | Batch 2100/2503 | Batch Loss: 0.000034
#   Epoch 21 | Batch 2200/2503 | Batch Loss: 0.000070
#   Epoch 21 | Batch 2300/2503 | Batch Loss: 0.000029
#   Epoch 21 | Batch 2400/2503 | Batch Loss: 0.000029
#   Epoch 21 | Batch 2500/2503 | Batch Loss: 0.000132
#
# Fine-tune Epoch 21/50 | Time: 158.3s
#   Train Loss: 0.000068 | Val MSE: 0.000269 *** New Best ***
# ------------------------------------------------------------
#   Epoch 22 | Batch 100/2503 | Batch Loss: 0.000031
#   Epoch 22 | Batch 200/2503 | Batch Loss: 0.000033
#   Epoch 22 | Batch 300/2503 | Batch Loss: 0.000037
#   Epoch 22 | Batch 400/2503 | Batch Loss: 0.000030
#   Epoch 22 | Batch 500/2503 | Batch Loss: 0.000032
#   Epoch 22 | Batch 600/2503 | Batch Loss: 0.000046
#   Epoch 22 | Batch 700/2503 | Batch Loss: 0.000029
#   Epoch 22 | Batch 800/2503 | Batch Loss: 0.000030
#   Epoch 22 | Batch 900/2503 | Batch Loss: 0.000033
#   Epoch 22 | Batch 1000/2503 | Batch Loss: 0.000038
#   Epoch 22 | Batch 1100/2503 | Batch Loss: 0.000025
#   Epoch 22 | Batch 1200/2503 | Batch Loss: 0.000037
#   Epoch 22 | Batch 1300/2503 | Batch Loss: 0.000034
#   Epoch 22 | Batch 1400/2503 | Batch Loss: 0.000030
#   Epoch 22 | Batch 1500/2503 | Batch Loss: 0.000031
#   Epoch 22 | Batch 1600/2503 | Batch Loss: 0.000036
#   Epoch 22 | Batch 1700/2503 | Batch Loss: 0.000036
#   Epoch 22 | Batch 1800/2503 | Batch Loss: 0.000024
#   Epoch 22 | Batch 1900/2503 | Batch Loss: 0.000119
#   Epoch 22 | Batch 2000/2503 | Batch Loss: 0.000032
#   Epoch 22 | Batch 2100/2503 | Batch Loss: 0.000033
#   Epoch 22 | Batch 2200/2503 | Batch Loss: 0.000032
#   Epoch 22 | Batch 2300/2503 | Batch Loss: 0.000043
#   Epoch 22 | Batch 2400/2503 | Batch Loss: 0.000040
#   Epoch 22 | Batch 2500/2503 | Batch Loss: 0.000128
#
# Fine-tune Epoch 22/50 | Time: 158.5s
#   Train Loss: 0.000067 | Val MSE: 0.000246 *** New Best ***
# ------------------------------------------------------------
#   Epoch 23 | Batch 100/2503 | Batch Loss: 0.000102
#   Epoch 23 | Batch 200/2503 | Batch Loss: 0.000049
#   Epoch 23 | Batch 300/2503 | Batch Loss: 0.000033
#   Epoch 23 | Batch 400/2503 | Batch Loss: 0.000029
#   Epoch 23 | Batch 500/2503 | Batch Loss: 0.000056
#   Epoch 23 | Batch 600/2503 | Batch Loss: 0.000028
#   Epoch 23 | Batch 700/2503 | Batch Loss: 0.000027
#   Epoch 23 | Batch 800/2503 | Batch Loss: 0.000025
#   Epoch 23 | Batch 900/2503 | Batch Loss: 0.000037
#   Epoch 23 | Batch 1000/2503 | Batch Loss: 0.000033
#   Epoch 23 | Batch 1100/2503 | Batch Loss: 0.000035
#   Epoch 23 | Batch 1200/2503 | Batch Loss: 0.000026
#   Epoch 23 | Batch 1300/2503 | Batch Loss: 0.000026
#   Epoch 23 | Batch 1400/2503 | Batch Loss: 0.000029
#   Epoch 23 | Batch 1500/2503 | Batch Loss: 0.000034
#   Epoch 23 | Batch 1600/2503 | Batch Loss: 0.000032
#   Epoch 23 | Batch 1700/2503 | Batch Loss: 0.000034
#   Epoch 23 | Batch 1800/2503 | Batch Loss: 0.000032
#   Epoch 23 | Batch 1900/2503 | Batch Loss: 0.000027
#   Epoch 23 | Batch 2000/2503 | Batch Loss: 0.000037
#   Epoch 23 | Batch 2100/2503 | Batch Loss: 0.000024
#   Epoch 23 | Batch 2200/2503 | Batch Loss: 0.000027
#   Epoch 23 | Batch 2300/2503 | Batch Loss: 0.000044
#   Epoch 23 | Batch 2400/2503 | Batch Loss: 0.000026
#   Epoch 23 | Batch 2500/2503 | Batch Loss: 0.000034
#
# Fine-tune Epoch 23/50 | Time: 158.2s
#   Train Loss: 0.000066 | Val MSE: 0.000253
# ------------------------------------------------------------
#   Epoch 24 | Batch 100/2503 | Batch Loss: 0.000154
#   Epoch 24 | Batch 200/2503 | Batch Loss: 0.000038
#   Epoch 24 | Batch 300/2503 | Batch Loss: 0.000042
#   Epoch 24 | Batch 400/2503 | Batch Loss: 0.000037
#   Epoch 24 | Batch 500/2503 | Batch Loss: 0.000031
#   Epoch 24 | Batch 600/2503 | Batch Loss: 0.000059
#   Epoch 24 | Batch 700/2503 | Batch Loss: 0.000330
#   Epoch 24 | Batch 800/2503 | Batch Loss: 0.000026
#   Epoch 24 | Batch 900/2503 | Batch Loss: 0.000039
#   Epoch 24 | Batch 1000/2503 | Batch Loss: 0.000027
#   Epoch 24 | Batch 1100/2503 | Batch Loss: 0.000026
#   Epoch 24 | Batch 1200/2503 | Batch Loss: 0.000071
#   Epoch 24 | Batch 1300/2503 | Batch Loss: 0.000110
#   Epoch 24 | Batch 1400/2503 | Batch Loss: 0.000052
#   Epoch 24 | Batch 1500/2503 | Batch Loss: 0.000032
#   Epoch 24 | Batch 1600/2503 | Batch Loss: 0.000034
#   Epoch 24 | Batch 1700/2503 | Batch Loss: 0.000026
#   Epoch 24 | Batch 1800/2503 | Batch Loss: 0.000035
#   Epoch 24 | Batch 1900/2503 | Batch Loss: 0.000033
#   Epoch 24 | Batch 2000/2503 | Batch Loss: 0.000038
#   Epoch 24 | Batch 2100/2503 | Batch Loss: 0.000027
#   Epoch 24 | Batch 2200/2503 | Batch Loss: 0.000024
#   Epoch 24 | Batch 2300/2503 | Batch Loss: 0.000034
#   Epoch 24 | Batch 2400/2503 | Batch Loss: 0.000032
#   Epoch 24 | Batch 2500/2503 | Batch Loss: 0.000024
#
# Fine-tune Epoch 24/50 | Time: 158.2s
#   Train Loss: 0.000066 | Val MSE: 0.000267
# ------------------------------------------------------------
#   Epoch 25 | Batch 100/2503 | Batch Loss: 0.000027
#   Epoch 25 | Batch 200/2503 | Batch Loss: 0.000035
#   Epoch 25 | Batch 300/2503 | Batch Loss: 0.000040
#   Epoch 25 | Batch 400/2503 | Batch Loss: 0.000033
#   Epoch 25 | Batch 500/2503 | Batch Loss: 0.000033
#   Epoch 25 | Batch 600/2503 | Batch Loss: 0.000031
#   Epoch 25 | Batch 700/2503 | Batch Loss: 0.000027
#   Epoch 25 | Batch 800/2503 | Batch Loss: 0.000031
#   Epoch 25 | Batch 900/2503 | Batch Loss: 0.000032
#   Epoch 25 | Batch 1000/2503 | Batch Loss: 0.000025
#   Epoch 25 | Batch 1100/2503 | Batch Loss: 0.000036
#   Epoch 25 | Batch 1200/2503 | Batch Loss: 0.000150
#   Epoch 25 | Batch 1300/2503 | Batch Loss: 0.000038
#   Epoch 25 | Batch 1400/2503 | Batch Loss: 0.000022
#   Epoch 25 | Batch 1500/2503 | Batch Loss: 0.000035
#   Epoch 25 | Batch 1600/2503 | Batch Loss: 0.000040
#   Epoch 25 | Batch 1700/2503 | Batch Loss: 0.000030
#   Epoch 25 | Batch 1800/2503 | Batch Loss: 0.000031
#   Epoch 25 | Batch 1900/2503 | Batch Loss: 0.000029
#   Epoch 25 | Batch 2000/2503 | Batch Loss: 0.000026
#   Epoch 25 | Batch 2100/2503 | Batch Loss: 0.000033
#   Epoch 25 | Batch 2200/2503 | Batch Loss: 0.000028
#   Epoch 25 | Batch 2300/2503 | Batch Loss: 0.000027
#   Epoch 25 | Batch 2400/2503 | Batch Loss: 0.000025
#   Epoch 25 | Batch 2500/2503 | Batch Loss: 0.000032
#
# Fine-tune Epoch 25/50 | Time: 157.9s
#   Train Loss: 0.000065 | Val MSE: 0.000242 *** New Best ***
# ------------------------------------------------------------
#   Epoch 26 | Batch 100/2503 | Batch Loss: 0.000032
#   Epoch 26 | Batch 200/2503 | Batch Loss: 0.000025
#   Epoch 26 | Batch 300/2503 | Batch Loss: 0.000024
#   Epoch 26 | Batch 400/2503 | Batch Loss: 0.000055
#   Epoch 26 | Batch 500/2503 | Batch Loss: 0.000039
#   Epoch 26 | Batch 600/2503 | Batch Loss: 0.000029
#   Epoch 26 | Batch 700/2503 | Batch Loss: 0.000042
#   Epoch 26 | Batch 800/2503 | Batch Loss: 0.000032
#   Epoch 26 | Batch 900/2503 | Batch Loss: 0.000025
#   Epoch 26 | Batch 1000/2503 | Batch Loss: 0.000042
#   Epoch 26 | Batch 1100/2503 | Batch Loss: 0.000038
#   Epoch 26 | Batch 1200/2503 | Batch Loss: 0.000357
#   Epoch 26 | Batch 1300/2503 | Batch Loss: 0.000025
#   Epoch 26 | Batch 1400/2503 | Batch Loss: 0.000037
#   Epoch 26 | Batch 1500/2503 | Batch Loss: 0.000038
#   Epoch 26 | Batch 1600/2503 | Batch Loss: 0.000031
#   Epoch 26 | Batch 1700/2503 | Batch Loss: 0.000034
#   Epoch 26 | Batch 1800/2503 | Batch Loss: 0.000030
#   Epoch 26 | Batch 1900/2503 | Batch Loss: 0.000042
#   Epoch 26 | Batch 2000/2503 | Batch Loss: 0.000081
#   Epoch 26 | Batch 2100/2503 | Batch Loss: 0.000035
#   Epoch 26 | Batch 2200/2503 | Batch Loss: 0.000030
#   Epoch 26 | Batch 2300/2503 | Batch Loss: 0.000031
#   Epoch 26 | Batch 2400/2503 | Batch Loss: 0.000158
#   Epoch 26 | Batch 2500/2503 | Batch Loss: 0.000038
#
# Fine-tune Epoch 26/50 | Time: 157.3s
#   Train Loss: 0.000064 | Val MSE: 0.000225 *** New Best ***
# ------------------------------------------------------------
#   Epoch 27 | Batch 100/2503 | Batch Loss: 0.000035
#   Epoch 27 | Batch 200/2503 | Batch Loss: 0.000070
#   Epoch 27 | Batch 300/2503 | Batch Loss: 0.000038
#   Epoch 27 | Batch 400/2503 | Batch Loss: 0.000031
#   Epoch 27 | Batch 500/2503 | Batch Loss: 0.000027
#   Epoch 27 | Batch 600/2503 | Batch Loss: 0.000027
#   Epoch 27 | Batch 700/2503 | Batch Loss: 0.000059
#   Epoch 27 | Batch 800/2503 | Batch Loss: 0.000031
#   Epoch 27 | Batch 900/2503 | Batch Loss: 0.000025
#   Epoch 27 | Batch 1000/2503 | Batch Loss: 0.000029
#   Epoch 27 | Batch 1100/2503 | Batch Loss: 0.000033
#   Epoch 27 | Batch 1200/2503 | Batch Loss: 0.000025
#   Epoch 27 | Batch 1300/2503 | Batch Loss: 0.000031
#   Epoch 27 | Batch 1400/2503 | Batch Loss: 0.000039
#   Epoch 27 | Batch 1500/2503 | Batch Loss: 0.000195
#   Epoch 27 | Batch 1600/2503 | Batch Loss: 0.000036
#   Epoch 27 | Batch 1700/2503 | Batch Loss: 0.000048
#   Epoch 27 | Batch 1800/2503 | Batch Loss: 0.000039
#   Epoch 27 | Batch 1900/2503 | Batch Loss: 0.000026
#   Epoch 27 | Batch 2000/2503 | Batch Loss: 0.000029
#   Epoch 27 | Batch 2100/2503 | Batch Loss: 0.000028
#   Epoch 27 | Batch 2200/2503 | Batch Loss: 0.000029
#   Epoch 27 | Batch 2300/2503 | Batch Loss: 0.000033
#   Epoch 27 | Batch 2400/2503 | Batch Loss: 0.000036
#   Epoch 27 | Batch 2500/2503 | Batch Loss: 0.000033
#
# Fine-tune Epoch 27/50 | Time: 157.0s
#   Train Loss: 0.000064 | Val MSE: 0.000234
# ------------------------------------------------------------
#   Epoch 28 | Batch 100/2503 | Batch Loss: 0.000035
#   Epoch 28 | Batch 200/2503 | Batch Loss: 0.000027
#   Epoch 28 | Batch 300/2503 | Batch Loss: 0.000029
#   Epoch 28 | Batch 400/2503 | Batch Loss: 0.000031
#   Epoch 28 | Batch 500/2503 | Batch Loss: 0.000030
#   Epoch 28 | Batch 600/2503 | Batch Loss: 0.000038
#   Epoch 28 | Batch 700/2503 | Batch Loss: 0.000024
#   Epoch 28 | Batch 800/2503 | Batch Loss: 0.000031
#   Epoch 28 | Batch 900/2503 | Batch Loss: 0.000047
#   Epoch 28 | Batch 1000/2503 | Batch Loss: 0.000031
#   Epoch 28 | Batch 1100/2503 | Batch Loss: 0.000039
#   Epoch 28 | Batch 1200/2503 | Batch Loss: 0.000025
#   Epoch 28 | Batch 1300/2503 | Batch Loss: 0.000034
#   Epoch 28 | Batch 1400/2503 | Batch Loss: 0.000028
#   Epoch 28 | Batch 1500/2503 | Batch Loss: 0.000047
#   Epoch 28 | Batch 1600/2503 | Batch Loss: 0.000025
#   Epoch 28 | Batch 1700/2503 | Batch Loss: 0.000026
#   Epoch 28 | Batch 1800/2503 | Batch Loss: 0.000031
#   Epoch 28 | Batch 1900/2503 | Batch Loss: 0.000031
#   Epoch 28 | Batch 2000/2503 | Batch Loss: 0.000027
#   Epoch 28 | Batch 2100/2503 | Batch Loss: 0.000028
#   Epoch 28 | Batch 2200/2503 | Batch Loss: 0.000030
#   Epoch 28 | Batch 2300/2503 | Batch Loss: 0.000026
#   Epoch 28 | Batch 2400/2503 | Batch Loss: 0.000028
#   Epoch 28 | Batch 2500/2503 | Batch Loss: 0.000038
#
# Fine-tune Epoch 28/50 | Time: 156.3s
#   Train Loss: 0.000063 | Val MSE: 0.000219 *** New Best ***
# ------------------------------------------------------------
#   Epoch 29 | Batch 100/2503 | Batch Loss: 0.000042
#   Epoch 29 | Batch 200/2503 | Batch Loss: 0.000030
#   Epoch 29 | Batch 300/2503 | Batch Loss: 0.000026
#   Epoch 29 | Batch 400/2503 | Batch Loss: 0.000047
#   Epoch 29 | Batch 500/2503 | Batch Loss: 0.000030
#   Epoch 29 | Batch 600/2503 | Batch Loss: 0.000027
#   Epoch 29 | Batch 700/2503 | Batch Loss: 0.000027
#   Epoch 29 | Batch 800/2503 | Batch Loss: 0.000036
#   Epoch 29 | Batch 900/2503 | Batch Loss: 0.000027
#   Epoch 29 | Batch 1000/2503 | Batch Loss: 0.000025
#   Epoch 29 | Batch 1100/2503 | Batch Loss: 0.000038
#   Epoch 29 | Batch 1200/2503 | Batch Loss: 0.000032
#   Epoch 29 | Batch 1300/2503 | Batch Loss: 0.001023
#   Epoch 29 | Batch 1400/2503 | Batch Loss: 0.000032
#   Epoch 29 | Batch 1500/2503 | Batch Loss: 0.000031
#   Epoch 29 | Batch 1600/2503 | Batch Loss: 0.000029
#   Epoch 29 | Batch 1700/2503 | Batch Loss: 0.000035
#   Epoch 29 | Batch 1800/2503 | Batch Loss: 0.000031
#   Epoch 29 | Batch 1900/2503 | Batch Loss: 0.000028
#   Epoch 29 | Batch 2000/2503 | Batch Loss: 0.000030
#   Epoch 29 | Batch 2100/2503 | Batch Loss: 0.000033
#   Epoch 29 | Batch 2200/2503 | Batch Loss: 0.000031
#   Epoch 29 | Batch 2300/2503 | Batch Loss: 0.000034
#   Epoch 29 | Batch 2400/2503 | Batch Loss: 0.000048
#   Epoch 29 | Batch 2500/2503 | Batch Loss: 0.000035
#
# Fine-tune Epoch 29/50 | Time: 156.1s
#   Train Loss: 0.000062 | Val MSE: 0.000221
# ------------------------------------------------------------
#   Epoch 30 | Batch 100/2503 | Batch Loss: 0.000029
#   Epoch 30 | Batch 200/2503 | Batch Loss: 0.000032
#   Epoch 30 | Batch 300/2503 | Batch Loss: 0.000035
#   Epoch 30 | Batch 400/2503 | Batch Loss: 0.000027
#   Epoch 30 | Batch 500/2503 | Batch Loss: 0.000030
#   Epoch 30 | Batch 600/2503 | Batch Loss: 0.000030
#   Epoch 30 | Batch 700/2503 | Batch Loss: 0.000029
#   Epoch 30 | Batch 800/2503 | Batch Loss: 0.000061
#   Epoch 30 | Batch 900/2503 | Batch Loss: 0.000345
#   Epoch 30 | Batch 1000/2503 | Batch Loss: 0.000026
#   Epoch 30 | Batch 1100/2503 | Batch Loss: 0.000030
#   Epoch 30 | Batch 1200/2503 | Batch Loss: 0.000025
#   Epoch 30 | Batch 1300/2503 | Batch Loss: 0.000052
#   Epoch 30 | Batch 1400/2503 | Batch Loss: 0.000033
#   Epoch 30 | Batch 1500/2503 | Batch Loss: 0.000028
#   Epoch 30 | Batch 1600/2503 | Batch Loss: 0.000037
#   Epoch 30 | Batch 1700/2503 | Batch Loss: 0.000034
#   Epoch 30 | Batch 1800/2503 | Batch Loss: 0.000039
#   Epoch 30 | Batch 1900/2503 | Batch Loss: 0.000029
#   Epoch 30 | Batch 2000/2503 | Batch Loss: 0.000030
#   Epoch 30 | Batch 2100/2503 | Batch Loss: 0.000037
#   Epoch 30 | Batch 2200/2503 | Batch Loss: 0.000067
#   Epoch 30 | Batch 2300/2503 | Batch Loss: 0.000032
#   Epoch 30 | Batch 2400/2503 | Batch Loss: 0.000033
#   Epoch 30 | Batch 2500/2503 | Batch Loss: 0.000035
#
# Fine-tune Epoch 30/50 | Time: 156.0s
#   Train Loss: 0.000062 | Val MSE: 0.000222
# ------------------------------------------------------------
#   Epoch 31 | Batch 100/2503 | Batch Loss: 0.000035
#   Epoch 31 | Batch 200/2503 | Batch Loss: 0.000029
#   Epoch 31 | Batch 300/2503 | Batch Loss: 0.000083
#   Epoch 31 | Batch 400/2503 | Batch Loss: 0.000034
#   Epoch 31 | Batch 500/2503 | Batch Loss: 0.000033
#   Epoch 31 | Batch 600/2503 | Batch Loss: 0.000029
#   Epoch 31 | Batch 700/2503 | Batch Loss: 0.000028
#   Epoch 31 | Batch 800/2503 | Batch Loss: 0.000039
#   Epoch 31 | Batch 900/2503 | Batch Loss: 0.000039
#   Epoch 31 | Batch 1000/2503 | Batch Loss: 0.000028
#   Epoch 31 | Batch 1100/2503 | Batch Loss: 0.000025
#   Epoch 31 | Batch 1200/2503 | Batch Loss: 0.000025
#   Epoch 31 | Batch 1300/2503 | Batch Loss: 0.000024
#   Epoch 31 | Batch 1400/2503 | Batch Loss: 0.000027
#   Epoch 31 | Batch 1500/2503 | Batch Loss: 0.000026
#   Epoch 31 | Batch 1600/2503 | Batch Loss: 0.000038
#   Epoch 31 | Batch 1700/2503 | Batch Loss: 0.000023
#   Epoch 31 | Batch 1800/2503 | Batch Loss: 0.000037
#   Epoch 31 | Batch 1900/2503 | Batch Loss: 0.000046
#   Epoch 31 | Batch 2000/2503 | Batch Loss: 0.000026
#   Epoch 31 | Batch 2100/2503 | Batch Loss: 0.000031
#   Epoch 31 | Batch 2200/2503 | Batch Loss: 0.000035
#   Epoch 31 | Batch 2300/2503 | Batch Loss: 0.000025
#   Epoch 31 | Batch 2400/2503 | Batch Loss: 0.000034
#   Epoch 31 | Batch 2500/2503 | Batch Loss: 0.000026
#
# Fine-tune Epoch 31/50 | Time: 156.1s
#   Train Loss: 0.000061 | Val MSE: 0.000220
# ------------------------------------------------------------
#
# *** Early stopping triggered at epoch 31 ***
#
# ============================================================
# TRAINING COMPLETE!
# Best Validation MSE: 0.000219
# ============================================================
# Models saved: 'best_model.pth' and 'final_model.pth'
#
# ============================================================
# RUNNING FINAL TEST SET EVALUATION
# ============================================================
# Final Test MSE: 0.000812
#
# Saving loss history to 'loss_history.txt'...
# Generating loss curve plot 'loss_plot.png'...
# Execution Finished.
