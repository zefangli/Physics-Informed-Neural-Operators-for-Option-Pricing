# %%
"""
DeepONet Black-Scholes Solver
Optimized for high-dimensional branch data (u) and continuous trunk coordinates (M, tau)
"""

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
import h5py
import numpy as np
import time
import matplotlib.pyplot as plt  # <-- Added for plotting

# ==========================================
# NETWORK ARCHITECTURE (DeepONet)
# ==========================================

class PINN_MLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim, is_positive=True):
        super().__init__()
        layers = []
        
        layers.append(nn.Linear(input_dim, hidden_dim))
        layers.append(nn.LayerNorm(hidden_dim))
        layers.append(nn.Tanh())
        
        for _ in range(num_layers - 1):
            layers.append(nn.Linear(hidden_dim, hidden_dim))
            layers.append(nn.LayerNorm(hidden_dim))
            layers.append(nn.Tanh())
            
        layers.append(nn.Linear(hidden_dim, output_dim))
        
        if is_positive:
            layers.append(nn.Softplus())
            
        self.net = nn.Sequential(*layers)
        
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight)
                nn.init.zeros_(m.bias)
                
    def forward(self, x):
        return self.net(x)


class DeepONet(nn.Module):
    def __init__(self, u_dim, hidden_dim, num_layers, p_dim):
        super().__init__()
        # Branch network for the high-dimensional function input 'u'
        self.branch = PINN_MLP(
            input_dim=u_dim, 
            hidden_dim=hidden_dim, 
            num_layers=num_layers, 
            output_dim=p_dim, 
            is_positive=False 
        )
        
        # Trunk network for the continuous variables 'M' and 'tau'
        self.trunk = PINN_MLP(
            input_dim=2, 
            hidden_dim=hidden_dim, 
            num_layers=num_layers, 
            output_dim=p_dim, 
            is_positive=False
        )
        
        # Bias term for the final DeepONet output
        self.bias = nn.Parameter(torch.zeros(1))
        
        # Softplus to ensure the resulting volatility is strictly positive
        self.softplus = nn.Softplus()

    def forward(self, u, M, tau):
        branch_out = self.branch(u)
        
        trunk_input = torch.cat([M, tau], dim=1)
        trunk_out = self.trunk(trunk_input)
        
        # Compute the dot product across the basis dimension (p_dim)
        dot_product = torch.sum(branch_out * trunk_out, dim=1, keepdim=True)
        
        # Add bias and enforce positivity for volatility
        sigma = self.softplus(dot_product + self.bias)
        return sigma


class DeepBS_Solver(nn.Module):
    def __init__(self, u_dim=374, hidden_dim=128, num_layers=4, p_dim=128):
        super().__init__()
        
        # Network 1 is now a DeepONet predicting volatility
        self.nn1 = DeepONet(
            u_dim=u_dim, 
            hidden_dim=hidden_dim, 
            num_layers=num_layers, 
            p_dim=p_dim
        )
        
        # Network 2 remains a standard PINN_MLP predicting option price
        self.nn2 = PINN_MLP(
            input_dim=5, 
            hidden_dim=hidden_dim, 
            num_layers=num_layers, 
            output_dim=1, 
            is_positive=True
        )

    def forward(self, M, tau, u, r, q):
        # 1. Predict volatility (sigma) using the DeepONet
        sigma = self.nn1(u, M, tau)
        
        # 2. Predict option price (v_hat) using the MLP
        nn2_input = torch.cat([M, tau, r, q, sigma], dim=1)
        v_hat = self.nn2(nn2_input)
        
        return sigma, v_hat


# ==========================================
# LOSS FUNCTIONS
# ==========================================

def compute_derivatives(v_hat, M, tau):
    dv_dM = torch.autograd.grad(
        outputs=v_hat, inputs=M, 
        grad_outputs=torch.ones_like(v_hat),
        create_graph=True, retain_graph=True
    )[0]
    
    d2v_dM2 = torch.autograd.grad(
        outputs=dv_dM, inputs=M, 
        grad_outputs=torch.ones_like(dv_dM),
        create_graph=True, retain_graph=True
    )[0]
    
    dv_dtau = torch.autograd.grad(
        outputs=v_hat, inputs=tau, 
        grad_outputs=torch.ones_like(v_hat),
        create_graph=True, retain_graph=True
    )[0]
    
    return dv_dM, d2v_dM2, dv_dtau


def generate_boundary_points(batch_size, u, r, q, device, M_max=3.0, tau_max=5.32):
    indices = torch.randint(0, u.size(0), (batch_size,), device=device)

    # Terminal condition at tau = 0, M ∈ [0, M_max]
    M_term = torch.rand(batch_size, 1, device=device) * M_max
    tau_term = torch.zeros(batch_size, 1, device=device)

    # Lower boundary at M = 0, tau ∈ [0, tau_max]
    M_lower = torch.zeros(batch_size, 1, device=device)
    tau_lower = torch.rand(batch_size, 1, device=device) * tau_max

    # Upper boundary at M = M_max, tau ∈ [0, tau_max]
    M_upper = torch.full((batch_size, 1), M_max, device=device)
    tau_upper = torch.rand(batch_size, 1, device=device) * tau_max

    return {
        'terminal': (M_term, tau_term, u[indices], r[indices], q[indices]),
        'lower': (M_lower, tau_lower, u[indices], r[indices], q[indices]),
        'upper': (M_upper, tau_upper, u[indices], r[indices], q[indices]),
    }


def pinn_loss_fn(
    model, M, tau, u, r, q, v_true, mask, lambdas,
    device, num_boundary=256,
    M_max=3.0, tau_max=5.32
):
    sigma_hat, v_hat = model(M, tau, u, r, q)

    # ----------------
    # Data Loss
    # ----------------
    squared_errors = (v_hat - v_true) ** 2
    loss_data = torch.sum(squared_errors * mask) / (torch.sum(mask) + 1e-8)

    # ----------------
    # PDE Loss (tau is in YEARS; no scaling factor needed for time derivative)
    # ----------------
    dv_dM, d2v_dM2, dv_dtau = compute_derivatives(v_hat, M, tau)

    pde_residual = (
        -dv_dtau
        + 0.5 * (sigma_hat ** 2) * (M ** 2) * d2v_dM2
        + (r - q) * M * dv_dM
        - r * v_hat
    )
    loss_pde = torch.mean(pde_residual ** 2)

    # ----------------
    # Arbitrage Loss
    # ----------------
    loss_arb = torch.mean(F.relu(-dv_dM)) + torch.mean(F.relu(-d2v_dM2))

    # ----------------
    # Boundary Conditions (tau in YEARS)
    # ----------------
    boundaries = generate_boundary_points(
        num_boundary, u, r, q, device, M_max=M_max, tau_max=tau_max
    )

    # Terminal: v(M,0) = max(M-1,0)
    M_t, tau_t, u_t, r_t, q_t = boundaries['terminal']
    M_t.requires_grad_(True)
    tau_t.requires_grad_(True)
    _, v_term = model(M_t, tau_t, u_t, r_t, q_t)
    loss_term = F.mse_loss(v_term, F.relu(M_t - 1.0))

    # Lower: v(0,tau)=0
    M_l, tau_l, u_l, r_l, q_l = boundaries['lower']
    M_l.requires_grad_(True)
    tau_l.requires_grad_(True)
    _, v_lower = model(M_l, tau_l, u_l, r_l, q_l)
    loss_lower = F.mse_loss(v_lower, torch.zeros_like(v_lower))

    # Upper: v(M_max,tau) = M_max*e^{-q tau} - e^{-r tau} 
    M_u, tau_u, u_u, r_u, q_u = boundaries['upper']
    M_u.requires_grad_(True)
    tau_u.requires_grad_(True)
    _, v_upper = model(M_u, tau_u, u_u, r_u, q_u)
    v_upper_true = M_u * torch.exp(-q_u * tau_u) - torch.exp(-r_u * tau_u)
    loss_upper = F.mse_loss(v_upper, v_upper_true)

    # ----------------
    # Total
    # ----------------
    loss_total = (
        lambdas.get('data', 1.0) * loss_data +
        lambdas.get('pde', 0.1) * loss_pde +
        lambdas.get('arb', 0.1) * loss_arb +
        lambdas.get('term', 1.0) * loss_term +
        lambdas.get('lower', 1.0) * loss_lower +
        lambdas.get('upper', 1.0) * loss_upper
    )

    loss_dict = {
        'data': loss_data.item(),
        'pde': loss_pde.item(),
        'arb': loss_arb.item(),
        'term': loss_term.item(),
        'lower': loss_lower.item(),
        'upper': loss_upper.item(),
        'total': loss_total.item()
    }

    return loss_total, loss_dict


# ==========================================
# DATASET
# ==========================================

class ChronologicalOptionDataset(Dataset):
    def __init__(self, h5_path, split='train', load_to_memory=True):
        self.h5_path = h5_path
        self.load_to_memory = load_to_memory
        
        with h5py.File(h5_path, 'r') as f:
            total_rows = f['target_v'].shape[0]
            self.u_dim = f['branch_u'].shape[1]
            
            train_end = int(0.80 * total_rows)
            val_end = int(0.90 * total_rows)
            
            if split == 'train':
                self.start_idx, self.end_idx = 0, train_end
            elif split == 'val':
                self.start_idx, self.end_idx = train_end, val_end
            elif split == 'test':
                self.start_idx, self.end_idx = val_end, total_rows
            else:
                raise ValueError("Split must be 'train', 'val', or 'test'.")
            
            self.length = self.end_idx - self.start_idx
            
            if load_to_memory:
                self.branch_u = f['branch_u'][self.start_idx:self.end_idx]
                self.trunk_y = f['trunk_y'][self.start_idx:self.end_idx]
                self.target_v = f['target_v_normalized'][self.start_idx:self.end_idx]
                
        print(f"Loaded {split}: {self.length} samples")

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        return (
            torch.tensor(self.branch_u[idx], dtype=torch.float32),
            torch.tensor(self.trunk_y[idx], dtype=torch.float32),
            torch.tensor(self.target_v[idx], dtype=torch.float32)
        )
    
    def get_u_dim(self):
        return self.u_dim


# ==========================================
# COLLATE FUNCTION (DeepONet Optimized)
# ==========================================

def create_pinn_collate_fn(colloc_ratio=0.2, M_max=3.0, tau_max=5.32, points_per_u=10):
    """
    Pairs a smaller set of unique functional inputs (u) with multiple continuous 
    evaluation coordinates (M, tau) to learn the operator mapping efficiently.
    """
    def collate_fn(batch):
        u_true = torch.stack([item[0] for item in batch])
        y_true = torch.stack([item[1] for item in batch])
        v_true = torch.stack([item[2] for item in batch])

        if v_true.dim() == 1:
            v_true = v_true.unsqueeze(1)

        M_true = y_true[:, 0:1]
        tau_true = y_true[:, 1:2]
        r_true = y_true[:, 2:3]
        q_true = y_true[:, 3:4]

        num_true = len(batch)

        if colloc_ratio > 0.0:
            target_num_colloc = max(1, int(num_true * (colloc_ratio / (1.0 - colloc_ratio))))
            
            # Determine how many unique market states (u) we should sample
            num_unique_u = max(1, target_num_colloc // points_per_u)
            actual_num_colloc = num_unique_u * points_per_u

            # 1. Randomly select a subset of unique 'u' states
            idx = torch.randint(0, num_true, (num_unique_u,))
            u_base = u_true[idx]
            r_base = r_true[idx]
            q_base = q_true[idx]
            
            # 2. Duplicate each selected 'u' (and r, q) 'points_per_u' times
            u_colloc = u_base.repeat_interleave(points_per_u, dim=0)
            r_colloc = r_base.repeat_interleave(points_per_u, dim=0)
            q_colloc = q_base.repeat_interleave(points_per_u, dim=0)
            
            # 3. Generate independent random (M, tau) coordinates for the duplicated states
            M_colloc = torch.rand(actual_num_colloc, 1) * M_max
            tau_colloc = torch.rand(actual_num_colloc, 1) * tau_max
            v_colloc = torch.zeros(actual_num_colloc, 1)

            M_final = torch.cat([M_true, M_colloc])
            tau_final = torch.cat([tau_true, tau_colloc])
            u_final = torch.cat([u_true, u_colloc])
            r_final = torch.cat([r_true, r_colloc])
            q_final = torch.cat([q_true, q_colloc])
            v_final = torch.cat([v_true, v_colloc])
            mask = torch.cat([torch.ones(num_true, 1), torch.zeros(actual_num_colloc, 1)])
            
        else:
            M_final, tau_final, u_final = M_true, tau_true, u_true
            r_final, q_final, v_final = r_true, q_true, v_true
            mask = torch.ones(num_true, 1)

        return M_final, tau_final, u_final, r_final, q_final, v_final, mask

    return collate_fn

# ==========================================
# TRAINING
# ==========================================

def train_model():
    seed = 42
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) 
    np.random.seed(seed)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Device: {device}")
    
    config = {
        'epochs_adam': 100,      
        'epochs_lbfgs': 50, # Fine-tuning with low-LR Adam
        'batch_size': 256, #changed
        'lr': 1e-3,
        'hidden_dim': 64,
        'num_layers': 4,
        'p_dim': 64,             # Basis dimension for DeepONet projection
        'colloc_ratio': 0.2, 
        'points_per_u': 20,      #changed # Number of coordinate points per branch input
        'num_boundary': 128, 
        'grad_clip': 1.0,
        'M_max': 3.0,
        'tau_max': 5.32,
        'patience_adam': 3,     #changed
        'patience_lbfgs': 3,    #changed
    }
    
    #changed
    lambdas = {'data': 1.0, 'pde': 0.5, 'arb': 0.0, 'term': 0.5, 'lower': 0.5, 'upper': 0.5}
    
    print("Loading datasets...")
    train_ds = ChronologicalOptionDataset('../../wrds_data/deeponet_tensors.h5', 'train')
    val_ds = ChronologicalOptionDataset('../../wrds_data/deeponet_tensors.h5', 'val')
    test_ds = ChronologicalOptionDataset('../../wrds_data/deeponet_tensors.h5', 'test') # Added Test Set
    print(f"Train samples: {len(train_ds)}, Val samples: {len(val_ds)}, Test samples: {len(test_ds)}")
    
    train_loader = DataLoader(
        train_ds,
        config['batch_size'],
        shuffle=True,
        collate_fn=create_pinn_collate_fn(
            colloc_ratio=config['colloc_ratio'],
            M_max=config['M_max'],
            tau_max=config['tau_max'],
            points_per_u=config['points_per_u']
        )
    )
    
    val_loader = DataLoader(
        val_ds,
        config['batch_size'] * 2,
        shuffle=False,
        collate_fn=create_pinn_collate_fn(
            colloc_ratio=0.0,
            M_max=config['M_max'],
            tau_max=config['tau_max']
        )
    )

    test_loader = DataLoader(
        test_ds, config['batch_size'] * 2, shuffle=False,
        collate_fn=create_pinn_collate_fn(colloc_ratio=0.0, M_max=config['M_max'], tau_max=config['tau_max'])
    )
    
    print(f"Train batches: {len(train_loader)}, Val batches: {len(val_loader)}")
    
    # Model
    model = DeepBS_Solver(train_ds.get_u_dim(), config['hidden_dim'], config['num_layers'], config['p_dim']).to(device)
    print(f"Model initialized with u_dim={train_ds.get_u_dim()}, hidden_dim={config['hidden_dim']}, num_layers={config['num_layers']}, p_dim={config['p_dim']}")
    
    # ==========================================
    # OPTIMIZER SETTINGS (DeepONet Groups)
    # ==========================================
    base_lr = config['lr']
    
    # Grouped parameters to pace the fast-learning trunk and regularize the branch
    optimizer_adam = optim.Adam([
        {'params': model.nn1.branch.parameters(), 'lr': base_lr, 'weight_decay': 1e-4},
        {'params': model.nn1.trunk.parameters(), 'lr': base_lr * 0.1, 'weight_decay': 0.0},
        {'params': [model.nn1.bias], 'lr': base_lr},
        {'params': model.nn2.parameters(), 'lr': base_lr, 'weight_decay': 1e-5}
    ])

    #changed
    scheduler = ReduceLROnPlateau(optimizer_adam, 'min', factor=0.5, patience=2)
    
    best_val = float('inf')
    
    # --- Lists to track loss history for plotting ---
    all_train_losses = []
    all_val_losses = []
    
    def evaluate_validation():
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch in val_loader:
                M, tau, u, r, q, v_true, _ = [b.to(device) for b in batch]
                _, v_hat = model(M, tau, u, r, q)
                val_loss += F.mse_loss(v_hat, v_true).item() * M.size(0)
        val_loss /= len(val_ds)
        model.train()
        return val_loss
    
    # ==========================================
    # STAGE 1: ADAM TRAINING
    # ==========================================
    print("\n" + "="*60)
    print("PHASE 1: Adam Optimizer (DeepONet Parameter Groups)")
    print("="*60)
    
    epochs_no_improve = 0
    phase1_epochs_completed = 0
    
    for epoch in range(config['epochs_adam']):
        model.train()
        epoch_start = time.time()
        total_loss = 0
        loss_components = {'data': 0, 'pde': 0, 'arb': 0, 'term': 0, 'lower': 0, 'upper': 0}
        
        for batch_idx, batch in enumerate(train_loader):
            M, tau, u, r, q, v_true, mask = [b.to(device) for b in batch]
            M = M.clone().requires_grad_(True)
            tau = tau.clone().requires_grad_(True)
            
            optimizer_adam.zero_grad()
            loss, loss_dict = pinn_loss_fn(
                model, M, tau, u, r, q, v_true, mask,
                lambdas, device,
                num_boundary=config['num_boundary'],
                M_max=config['M_max'],
                tau_max=config['tau_max'],
            )
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), config['grad_clip'])
            optimizer_adam.step()
            
            total_loss += loss_dict['total']
            for key in loss_components:
                loss_components[key] += loss_dict[key]
            
            if (batch_idx + 1) % 100 == 0:
                print(f"  Epoch {epoch+1} | Batch {batch_idx+1}/{len(train_loader)} | Batch Loss: {loss_dict['total']:.6f}")
        
        val_loss = evaluate_validation()
        scheduler.step(val_loss)
        current_lr = optimizer_adam.param_groups[0]['lr'] # Refers to branch LR
        
        epoch_time = time.time() - epoch_start
        avg_loss = total_loss / len(train_loader)
        
        # Save epoch history
        all_train_losses.append(avg_loss)
        all_val_losses.append(val_loss)
        phase1_epochs_completed += 1
        
        for key in loss_components:
            loss_components[key] /= len(train_loader)
        
        improved = ""
        if val_loss < best_val:
            best_val = val_loss
            torch.save(model.state_dict(), f'best_model_phase1.pth')
            improved = " *** New Best ***"
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
        
        print(f"\nAdam Epoch {epoch+1}/{config['epochs_adam']} | Time: {epoch_time:.1f}s | Base LR: {current_lr:.2e}")
        print(f"  Train Loss: {avg_loss:.6f} | Val MSE: {val_loss:.6f}{improved}")
        print(f"  Components - Data: {loss_components['data']:.4f} | PDE: {loss_components['pde']:.4f} | Arb: {loss_components['arb']:.4f}")
        print(f"  Epochs without improvement: {epochs_no_improve}/{config['patience_adam']}")
        print("-" * 60)
        
        if epochs_no_improve >= config['patience_adam']:
            print(f"\n*** Early stopping triggered at epoch {epoch+1} ***")
            break
            
        torch.cuda.empty_cache()
    
    print(f"\n*** Adam Phase Complete. Best Val MSE: {best_val:.6f} ***")
    
    print("Loading best model from Adam phase for fine-tuning...")
    model.load_state_dict(torch.load('best_model_phase1.pth'))
    
    #changed
    torch.save(model.state_dict(), f'best_model.pth')

    # ==========================================
    # STAGE 2: FINE-TUNING WITH LOW LR ADAM
    # ==========================================
    print("\n" + "="*60)
    print("PHASE 2: Fine-tuning with Adam (Low LR, DeepONet Groups)")
    print("="*60)

    # best_val = 0.000815
    finetune_lr = 1e-5
    optimizer_finetune = optim.Adam([
        {'params': model.nn1.branch.parameters(), 'lr': finetune_lr, 'weight_decay': 1e-5},
        {'params': model.nn1.trunk.parameters(), 'lr': finetune_lr * 0.1, 'weight_decay': 0.0},
        {'params': [model.nn1.bias], 'lr': finetune_lr},
        {'params': model.nn2.parameters(), 'lr': finetune_lr, 'weight_decay': 1e-6}
    ])
    
    epochs_no_improve = 0

    for epoch in range(config['epochs_lbfgs']): 
        model.train()
        epoch_start = time.time()
        total_loss = 0
        loss_components = {'data': 0, 'pde': 0, 'arb': 0, 'term': 0, 'lower': 0, 'upper': 0}
        
        for batch_idx, batch in enumerate(train_loader):
            M, tau, u, r, q, v_true, mask = [b.to(device) for b in batch]
            M = M.clone().requires_grad_(True)
            tau = tau.clone().requires_grad_(True)
            
            optimizer_finetune.zero_grad()
            loss, loss_dict = pinn_loss_fn(
                model, M, tau, u, r, q, v_true, mask,
                lambdas, device,
                num_boundary=config['num_boundary'],
                M_max=config['M_max'],
                tau_max=config['tau_max'],
            )
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), config['grad_clip'])
            optimizer_finetune.step()
            
            total_loss += loss_dict['total']
            for key in loss_components:
                loss_components[key] += loss_dict[key]
            
            if (batch_idx + 1) % 100 == 0:
                print(f"  Epoch {epoch+1} | Batch {batch_idx+1}/{len(train_loader)} | Batch Loss: {loss_dict['total']:.6f}")
        
        val_loss = evaluate_validation()
        epoch_time = time.time() - epoch_start
        avg_loss = total_loss / len(train_loader)
        
        # Save epoch history
        all_train_losses.append(avg_loss)
        all_val_losses.append(val_loss)
        
        for key in loss_components:
            loss_components[key] /= len(train_loader)
        
        improved = ""
        if val_loss < best_val:
            best_val = val_loss
            torch.save(model.state_dict(), 'best_model.pth')
            improved = " *** New Best ***"
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
        
        print(f"\nFine-tune Epoch {epoch+1}/{config['epochs_lbfgs']} | Time: {epoch_time:.1f}s")
        print(f"  Train Loss: {avg_loss:.6f} | Val MSE: {val_loss:.6f}{improved}")
        print("-" * 60)
        
        torch.cuda.empty_cache()
        
        # we allow it to run for at least 10 epochs to give the fine-tuning a chance to improve, then we check for early stopping
        if epoch >= 10 and epochs_no_improve >= config['patience_lbfgs']:
            print(f"\n*** Early stopping triggered at epoch {epoch+1} ***")
            break

    print("\n" + "="*60)
    print("TRAINING COMPLETE!")
    print(f"Best Validation MSE: {best_val:.6f}")
    print("="*60)
    
    torch.save(model.state_dict(), 'final_model.pth')
    print("Models saved: 'best_model.pth' and 'final_model.pth'")
    

    # ==========================================
    # FINAL TEST EVALUATION
    # ==========================================
    print("\n" + "="*60)
    print("RUNNING FINAL TEST SET EVALUATION")
    print("="*60)
    
    # Load the best overall model weights
    model.load_state_dict(torch.load('best_model.pth'))
    model.eval()
    test_loss = 0
    
    with torch.no_grad():
        for batch in test_loader:
            M, tau, u, r, q, v_true, _ = [b.to(device) for b in batch]
            _, v_hat = model(M, tau, u, r, q)
            test_loss += F.mse_loss(v_hat, v_true).item() * M.size(0)
            
    test_loss /= len(test_ds)
    print(f"Final Test MSE: {test_loss:.6f}")
    
    # ==========================================
    # EXPORTING LOGS & PLOTTING
    # ==========================================
    print("\nSaving loss history to 'loss_history.txt'...")
    with open('loss_history.txt', 'w') as f:
        f.write("Epoch\tTrain_Loss\tVal_Loss\n")
        for i, (t_loss, v_loss) in enumerate(zip(all_train_losses, all_val_losses)):
            f.write(f"{i+1}\t{t_loss:.6f}\t{v_loss:.6f}\n")
        f.write(f"\nFinal Test Loss: {test_loss:.6f}\n")

    print("Generating loss curve plot 'loss_plot.png'...")
    plt.figure(figsize=(10, 6))
    plt.plot(all_train_losses, label='Train Loss (Total PINN Loss)')
    plt.plot(all_val_losses, label='Validation Loss (MSE)')
    
    # Indicate where Phase 2 started
    if phase1_epochs_completed < len(all_train_losses):
        plt.axvline(x=phase1_epochs_completed - 1, color='r', linestyle='--', label='Start Phase 2 (Fine-tuning)')
        
    plt.yscale('log')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Training & Validation Loss (Test MSE: {test_loss:.6f})')
    plt.legend()
    plt.grid(True, which="both", ls="--", alpha=0.5)
    plt.tight_layout()
    plt.savefig('loss_plot.png')
    plt.close()
    
    print("Execution Finished.")
    
    return model

if __name__ == "__main__":
    train_model()
# Out:
# Device: cuda
# Loading datasets...
# Loaded train: 640582 samples
# Loaded val: 80073 samples
# Loaded test: 80073 samples
# Train samples: 640582, Val samples: 80073, Test samples: 80073
# Train batches: 2503, Val batches: 157
# Model initialized with u_dim=374, hidden_dim=64, num_layers=4, p_dim=64
#
# ============================================================
# PHASE 1: Adam Optimizer (DeepONet Parameter Groups)
# ============================================================
#   Epoch 1 | Batch 100/2503 | Batch Loss: 0.063327
#   Epoch 1 | Batch 200/2503 | Batch Loss: 0.039402
#   Epoch 1 | Batch 300/2503 | Batch Loss: 0.030900
#   Epoch 1 | Batch 400/2503 | Batch Loss: 0.039263
#   Epoch 1 | Batch 500/2503 | Batch Loss: 0.007332
#   Epoch 1 | Batch 600/2503 | Batch Loss: 0.729930
#   Epoch 1 | Batch 700/2503 | Batch Loss: 0.008374
#   Epoch 1 | Batch 800/2503 | Batch Loss: 0.050098
#   Epoch 1 | Batch 900/2503 | Batch Loss: 0.007005
#   Epoch 1 | Batch 1000/2503 | Batch Loss: 0.437664
#   Epoch 1 | Batch 1100/2503 | Batch Loss: 0.003913
#   Epoch 1 | Batch 1200/2503 | Batch Loss: 0.004168
#   Epoch 1 | Batch 1300/2503 | Batch Loss: 0.306482
#   Epoch 1 | Batch 1400/2503 | Batch Loss: 0.304982
#   Epoch 1 | Batch 1500/2503 | Batch Loss: 0.275742
#   Epoch 1 | Batch 1600/2503 | Batch Loss: 0.006131
#   Epoch 1 | Batch 1700/2503 | Batch Loss: 0.002661
#   Epoch 1 | Batch 1800/2503 | Batch Loss: 0.009083
#   Epoch 1 | Batch 1900/2503 | Batch Loss: 0.003848
#   Epoch 1 | Batch 2000/2503 | Batch Loss: 0.002186
#   Epoch 1 | Batch 2100/2503 | Batch Loss: 0.002821
#   Epoch 1 | Batch 2200/2503 | Batch Loss: 0.001812
#   Epoch 1 | Batch 2300/2503 | Batch Loss: 0.001502
#   Epoch 1 | Batch 2400/2503 | Batch Loss: 0.045058
#   Epoch 1 | Batch 2500/2503 | Batch Loss: 0.005123
#
# Adam Epoch 1/100 | Time: 151.6s | Base LR: 1.00e-03
#   Train Loss: 0.144511 | Val MSE: 0.009639 *** New Best ***
#   Components - Data: 0.1224 | PDE: 0.0052 | Arb: 0.0468
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 2 | Batch 100/2503 | Batch Loss: 0.013051
#   Epoch 2 | Batch 200/2503 | Batch Loss: 0.001860
#   Epoch 2 | Batch 300/2503 | Batch Loss: 0.001359
#   Epoch 2 | Batch 400/2503 | Batch Loss: 0.006012
#   Epoch 2 | Batch 500/2503 | Batch Loss: 0.001825
#   Epoch 2 | Batch 600/2503 | Batch Loss: 0.002553
#   Epoch 2 | Batch 700/2503 | Batch Loss: 0.009689
#   Epoch 2 | Batch 800/2503 | Batch Loss: 0.002136
#   Epoch 2 | Batch 900/2503 | Batch Loss: 0.001434
#   Epoch 2 | Batch 1000/2503 | Batch Loss: 0.001215
#   Epoch 2 | Batch 1100/2503 | Batch Loss: 0.001170
#   Epoch 2 | Batch 1200/2503 | Batch Loss: 0.012074
#   Epoch 2 | Batch 1300/2503 | Batch Loss: 0.000674
#   Epoch 2 | Batch 1400/2503 | Batch Loss: 0.002551
#   Epoch 2 | Batch 1500/2503 | Batch Loss: 0.002552
#   Epoch 2 | Batch 1600/2503 | Batch Loss: 0.002679
#   Epoch 2 | Batch 1700/2503 | Batch Loss: 0.005467
#   Epoch 2 | Batch 1800/2503 | Batch Loss: 0.099805
#   Epoch 2 | Batch 1900/2503 | Batch Loss: 0.001015
#   Epoch 2 | Batch 2000/2503 | Batch Loss: 0.001955
#   Epoch 2 | Batch 2100/2503 | Batch Loss: 0.549800
#   Epoch 2 | Batch 2200/2503 | Batch Loss: 0.000417
#   Epoch 2 | Batch 2300/2503 | Batch Loss: 0.000397
#   Epoch 2 | Batch 2400/2503 | Batch Loss: 0.000594
#   Epoch 2 | Batch 2500/2503 | Batch Loss: 0.012114
#
# Adam Epoch 2/100 | Time: 150.6s | Base LR: 1.00e-03
#   Train Loss: 0.014472 | Val MSE: 0.004354 *** New Best ***
#   Components - Data: 0.0109 | PDE: 0.0010 | Arb: 0.0214
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 3 | Batch 100/2503 | Batch Loss: 0.001608
#   Epoch 3 | Batch 200/2503 | Batch Loss: 0.001090
#   Epoch 3 | Batch 300/2503 | Batch Loss: 0.000492
#   Epoch 3 | Batch 400/2503 | Batch Loss: 0.008732
#   Epoch 3 | Batch 500/2503 | Batch Loss: 0.000453
#   Epoch 3 | Batch 600/2503 | Batch Loss: 0.000475
#   Epoch 3 | Batch 700/2503 | Batch Loss: 0.001463
#   Epoch 3 | Batch 800/2503 | Batch Loss: 0.000692
#   Epoch 3 | Batch 900/2503 | Batch Loss: 0.009402
#   Epoch 3 | Batch 1000/2503 | Batch Loss: 0.000895
#   Epoch 3 | Batch 1100/2503 | Batch Loss: 0.001060
#   Epoch 3 | Batch 1200/2503 | Batch Loss: 0.000403
#   Epoch 3 | Batch 1300/2503 | Batch Loss: 0.002862
#   Epoch 3 | Batch 1400/2503 | Batch Loss: 0.001206
#   Epoch 3 | Batch 1500/2503 | Batch Loss: 0.000378
#   Epoch 3 | Batch 1600/2503 | Batch Loss: 0.000575
#   Epoch 3 | Batch 1700/2503 | Batch Loss: 0.000354
#   Epoch 3 | Batch 1800/2503 | Batch Loss: 0.002161
#   Epoch 3 | Batch 1900/2503 | Batch Loss: 0.001159
#   Epoch 3 | Batch 2000/2503 | Batch Loss: 0.000686
#   Epoch 3 | Batch 2100/2503 | Batch Loss: 0.005955
#   Epoch 3 | Batch 2200/2503 | Batch Loss: 0.000806
#   Epoch 3 | Batch 2300/2503 | Batch Loss: 0.008813
#   Epoch 3 | Batch 2400/2503 | Batch Loss: 0.000390
#   Epoch 3 | Batch 2500/2503 | Batch Loss: 0.000616
#
# Adam Epoch 3/100 | Time: 149.8s | Base LR: 1.00e-03
#   Train Loss: 0.012843 | Val MSE: 0.002491 *** New Best ***
#   Components - Data: 0.0103 | PDE: 0.0009 | Arb: 0.0422
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 4 | Batch 100/2503 | Batch Loss: 0.008188
#   Epoch 4 | Batch 200/2503 | Batch Loss: 0.004688
#   Epoch 4 | Batch 300/2503 | Batch Loss: 0.001490
#   Epoch 4 | Batch 400/2503 | Batch Loss: 0.000245
#   Epoch 4 | Batch 500/2503 | Batch Loss: 0.000515
#   Epoch 4 | Batch 600/2503 | Batch Loss: 0.009208
#   Epoch 4 | Batch 700/2503 | Batch Loss: 0.000457
#   Epoch 4 | Batch 800/2503 | Batch Loss: 0.000604
#   Epoch 4 | Batch 900/2503 | Batch Loss: 0.002639
#   Epoch 4 | Batch 1000/2503 | Batch Loss: 0.000954
#   Epoch 4 | Batch 1100/2503 | Batch Loss: 0.011255
#   Epoch 4 | Batch 1200/2503 | Batch Loss: 0.000676
#   Epoch 4 | Batch 1300/2503 | Batch Loss: 0.003617
#   Epoch 4 | Batch 1400/2503 | Batch Loss: 0.040902
#   Epoch 4 | Batch 1500/2503 | Batch Loss: 0.000883
#   Epoch 4 | Batch 1600/2503 | Batch Loss: 0.019250
#   Epoch 4 | Batch 1700/2503 | Batch Loss: 0.000694
#   Epoch 4 | Batch 1800/2503 | Batch Loss: 0.000576
#   Epoch 4 | Batch 1900/2503 | Batch Loss: 0.329571
#   Epoch 4 | Batch 2000/2503 | Batch Loss: 0.002376
#   Epoch 4 | Batch 2100/2503 | Batch Loss: 0.001101
#   Epoch 4 | Batch 2200/2503 | Batch Loss: 0.000241
#   Epoch 4 | Batch 2300/2503 | Batch Loss: 0.000845
#   Epoch 4 | Batch 2400/2503 | Batch Loss: 0.000321
#   Epoch 4 | Batch 2500/2503 | Batch Loss: 0.002510
#
# Adam Epoch 4/100 | Time: 150.2s | Base LR: 1.00e-03
#   Train Loss: 0.009359 | Val MSE: 0.002885
#   Components - Data: 0.0078 | PDE: 0.0009 | Arb: 0.0494
#   Epochs without improvement: 1/3
# ------------------------------------------------------------
#   Epoch 5 | Batch 100/2503 | Batch Loss: 0.005769
#   Epoch 5 | Batch 200/2503 | Batch Loss: 0.000304
#   Epoch 5 | Batch 300/2503 | Batch Loss: 0.000284
#   Epoch 5 | Batch 400/2503 | Batch Loss: 0.005469
#   Epoch 5 | Batch 500/2503 | Batch Loss: 0.001035
#   Epoch 5 | Batch 600/2503 | Batch Loss: 0.002319
#   Epoch 5 | Batch 700/2503 | Batch Loss: 0.000943
#   Epoch 5 | Batch 800/2503 | Batch Loss: 0.000305
#   Epoch 5 | Batch 900/2503 | Batch Loss: 0.001379
#   Epoch 5 | Batch 1000/2503 | Batch Loss: 0.000508
#   Epoch 5 | Batch 1100/2503 | Batch Loss: 0.065308
#   Epoch 5 | Batch 1200/2503 | Batch Loss: 0.000395
#   Epoch 5 | Batch 1300/2503 | Batch Loss: 0.001426
#   Epoch 5 | Batch 1400/2503 | Batch Loss: 0.001394
#   Epoch 5 | Batch 1500/2503 | Batch Loss: 0.000252
#   Epoch 5 | Batch 1600/2503 | Batch Loss: 0.000490
#   Epoch 5 | Batch 1700/2503 | Batch Loss: 0.023393
#   Epoch 5 | Batch 1800/2503 | Batch Loss: 0.001270
#   Epoch 5 | Batch 1900/2503 | Batch Loss: 0.010320
#   Epoch 5 | Batch 2000/2503 | Batch Loss: 0.000997
#   Epoch 5 | Batch 2100/2503 | Batch Loss: 0.001320
#   Epoch 5 | Batch 2200/2503 | Batch Loss: 0.001724
#   Epoch 5 | Batch 2300/2503 | Batch Loss: 0.000208
#   Epoch 5 | Batch 2400/2503 | Batch Loss: 0.002942
#   Epoch 5 | Batch 2500/2503 | Batch Loss: 0.004960
#
# Adam Epoch 5/100 | Time: 150.4s | Base LR: 1.00e-03
#   Train Loss: 0.005750 | Val MSE: 0.003424
#   Components - Data: 0.0043 | PDE: 0.0008 | Arb: 0.0405
#   Epochs without improvement: 2/3
# ------------------------------------------------------------
#   Epoch 6 | Batch 100/2503 | Batch Loss: 0.000560
#   Epoch 6 | Batch 200/2503 | Batch Loss: 0.001956
#   Epoch 6 | Batch 300/2503 | Batch Loss: 0.000810
#   Epoch 6 | Batch 400/2503 | Batch Loss: 0.000693
#   Epoch 6 | Batch 500/2503 | Batch Loss: 0.008857
#   Epoch 6 | Batch 600/2503 | Batch Loss: 0.000287
#   Epoch 6 | Batch 700/2503 | Batch Loss: 0.000216
#   Epoch 6 | Batch 800/2503 | Batch Loss: 0.001020
#   Epoch 6 | Batch 900/2503 | Batch Loss: 0.000386
#   Epoch 6 | Batch 1000/2503 | Batch Loss: 0.000259
#   Epoch 6 | Batch 1100/2503 | Batch Loss: 0.001149
#   Epoch 6 | Batch 1200/2503 | Batch Loss: 0.000567
#   Epoch 6 | Batch 1300/2503 | Batch Loss: 0.000232
#   Epoch 6 | Batch 1400/2503 | Batch Loss: 0.000296
#   Epoch 6 | Batch 1500/2503 | Batch Loss: 0.006263
#   Epoch 6 | Batch 1600/2503 | Batch Loss: 0.000888
#   Epoch 6 | Batch 1700/2503 | Batch Loss: 0.005930
#   Epoch 6 | Batch 1800/2503 | Batch Loss: 0.000461
#   Epoch 6 | Batch 1900/2503 | Batch Loss: 0.000600
#   Epoch 6 | Batch 2000/2503 | Batch Loss: 0.000351
#   Epoch 6 | Batch 2100/2503 | Batch Loss: 0.000895
#   Epoch 6 | Batch 2200/2503 | Batch Loss: 0.000623
#   Epoch 6 | Batch 2300/2503 | Batch Loss: 0.005610
#   Epoch 6 | Batch 2400/2503 | Batch Loss: 0.000234
#   Epoch 6 | Batch 2500/2503 | Batch Loss: 0.000344
#
# Adam Epoch 6/100 | Time: 150.3s | Base LR: 5.00e-04
#   Train Loss: 0.005043 | Val MSE: 0.005207
#   Components - Data: 0.0039 | PDE: 0.0007 | Arb: 0.0310
#   Epochs without improvement: 3/3
# ------------------------------------------------------------
#
# *** Early stopping triggered at epoch 6 ***
#
# *** Adam Phase Complete. Best Val MSE: 0.002491 ***
# Loading best model from Adam phase for fine-tuning...
#
# ============================================================
# PHASE 2: Fine-tuning with Adam (Low LR, DeepONet Groups)
# ============================================================
#   Epoch 1 | Batch 100/2503 | Batch Loss: 0.008456
#   Epoch 1 | Batch 200/2503 | Batch Loss: 0.003528
#   Epoch 1 | Batch 300/2503 | Batch Loss: 0.000344
#   Epoch 1 | Batch 400/2503 | Batch Loss: 0.002834
#   Epoch 1 | Batch 500/2503 | Batch Loss: 0.007485
#   Epoch 1 | Batch 600/2503 | Batch Loss: 0.000380
#   Epoch 1 | Batch 700/2503 | Batch Loss: 0.000367
#   Epoch 1 | Batch 800/2503 | Batch Loss: 0.000375
#   Epoch 1 | Batch 900/2503 | Batch Loss: 0.000608
#   Epoch 1 | Batch 1000/2503 | Batch Loss: 0.000259
#   Epoch 1 | Batch 1100/2503 | Batch Loss: 0.000246
#   Epoch 1 | Batch 1200/2503 | Batch Loss: 0.005293
#   Epoch 1 | Batch 1300/2503 | Batch Loss: 0.000246
#   Epoch 1 | Batch 1400/2503 | Batch Loss: 0.000283
#   Epoch 1 | Batch 1500/2503 | Batch Loss: 0.000237
#   Epoch 1 | Batch 1600/2503 | Batch Loss: 0.000262
#   Epoch 1 | Batch 1700/2503 | Batch Loss: 0.001264
#   Epoch 1 | Batch 1800/2503 | Batch Loss: 0.000247
#   Epoch 1 | Batch 1900/2503 | Batch Loss: 0.000247
#   Epoch 1 | Batch 2000/2503 | Batch Loss: 0.000279
#   Epoch 1 | Batch 2100/2503 | Batch Loss: 0.000228
#   Epoch 1 | Batch 2200/2503 | Batch Loss: 0.000247
#   Epoch 1 | Batch 2300/2503 | Batch Loss: 0.000251
#   Epoch 1 | Batch 2400/2503 | Batch Loss: 0.000226
#   Epoch 1 | Batch 2500/2503 | Batch Loss: 0.000326
#
# Fine-tune Epoch 1/50 | Time: 150.8s
#   Train Loss: 0.002012 | Val MSE: 0.002730
# ------------------------------------------------------------
#   Epoch 2 | Batch 100/2503 | Batch Loss: 0.002218
#   Epoch 2 | Batch 200/2503 | Batch Loss: 0.008214
#   Epoch 2 | Batch 300/2503 | Batch Loss: 0.000217
#   Epoch 2 | Batch 400/2503 | Batch Loss: 0.000298
#   Epoch 2 | Batch 500/2503 | Batch Loss: 0.000220
#   Epoch 2 | Batch 600/2503 | Batch Loss: 0.000313
#   Epoch 2 | Batch 700/2503 | Batch Loss: 0.000246
#   Epoch 2 | Batch 800/2503 | Batch Loss: 0.000233
#   Epoch 2 | Batch 900/2503 | Batch Loss: 0.000232
#   Epoch 2 | Batch 1000/2503 | Batch Loss: 0.000220
#   Epoch 2 | Batch 1100/2503 | Batch Loss: 0.000282
#   Epoch 2 | Batch 1200/2503 | Batch Loss: 0.000260
#   Epoch 2 | Batch 1300/2503 | Batch Loss: 0.000232
#   Epoch 2 | Batch 1400/2503 | Batch Loss: 0.000210
#   Epoch 2 | Batch 1500/2503 | Batch Loss: 0.011098
#   Epoch 2 | Batch 1600/2503 | Batch Loss: 0.000256
#   Epoch 2 | Batch 1700/2503 | Batch Loss: 0.000201
#   Epoch 2 | Batch 1800/2503 | Batch Loss: 0.000262
#   Epoch 2 | Batch 1900/2503 | Batch Loss: 0.000335
#   Epoch 2 | Batch 2000/2503 | Batch Loss: 0.000194
#   Epoch 2 | Batch 2100/2503 | Batch Loss: 0.007146
#   Epoch 2 | Batch 2200/2503 | Batch Loss: 0.000231
#   Epoch 2 | Batch 2300/2503 | Batch Loss: 0.000238
#   Epoch 2 | Batch 2400/2503 | Batch Loss: 0.000216
#   Epoch 2 | Batch 2500/2503 | Batch Loss: 0.000241
#
# Fine-tune Epoch 2/50 | Time: 150.2s
#   Train Loss: 0.001370 | Val MSE: 0.002131 *** New Best ***
# ------------------------------------------------------------
#   Epoch 3 | Batch 100/2503 | Batch Loss: 0.000269
#   Epoch 3 | Batch 200/2503 | Batch Loss: 0.000512
#   Epoch 3 | Batch 300/2503 | Batch Loss: 0.001588
#   Epoch 3 | Batch 400/2503 | Batch Loss: 0.000180
#   Epoch 3 | Batch 500/2503 | Batch Loss: 0.000234
#   Epoch 3 | Batch 600/2503 | Batch Loss: 0.000219
#   Epoch 3 | Batch 700/2503 | Batch Loss: 0.000339
#   Epoch 3 | Batch 800/2503 | Batch Loss: 0.000222
#   Epoch 3 | Batch 900/2503 | Batch Loss: 0.006042
#   Epoch 3 | Batch 1000/2503 | Batch Loss: 0.001825
#   Epoch 3 | Batch 1100/2503 | Batch Loss: 0.001075
#   Epoch 3 | Batch 1200/2503 | Batch Loss: 0.000258
#   Epoch 3 | Batch 1300/2503 | Batch Loss: 0.000315
#   Epoch 3 | Batch 1400/2503 | Batch Loss: 0.000253
#   Epoch 3 | Batch 1500/2503 | Batch Loss: 0.000706
#   Epoch 3 | Batch 1600/2503 | Batch Loss: 0.000293
#   Epoch 3 | Batch 1700/2503 | Batch Loss: 0.000214
#   Epoch 3 | Batch 1800/2503 | Batch Loss: 0.000186
#   Epoch 3 | Batch 1900/2503 | Batch Loss: 0.000262
#   Epoch 3 | Batch 2000/2503 | Batch Loss: 0.000247
#   Epoch 3 | Batch 2100/2503 | Batch Loss: 0.020639
#   Epoch 3 | Batch 2200/2503 | Batch Loss: 0.000430
#   Epoch 3 | Batch 2300/2503 | Batch Loss: 0.000252
#   Epoch 3 | Batch 2400/2503 | Batch Loss: 0.000738
#   Epoch 3 | Batch 2500/2503 | Batch Loss: 0.000545
#
# Fine-tune Epoch 3/50 | Time: 149.4s
#   Train Loss: 0.001173 | Val MSE: 0.002185
# ------------------------------------------------------------
#   Epoch 4 | Batch 100/2503 | Batch Loss: 0.004039
#   Epoch 4 | Batch 200/2503 | Batch Loss: 0.000212
#   Epoch 4 | Batch 300/2503 | Batch Loss: 0.000175
#   Epoch 4 | Batch 400/2503 | Batch Loss: 0.000285
#   Epoch 4 | Batch 500/2503 | Batch Loss: 0.001436
#   Epoch 4 | Batch 600/2503 | Batch Loss: 0.000198
#   Epoch 4 | Batch 700/2503 | Batch Loss: 0.003500
#   Epoch 4 | Batch 800/2503 | Batch Loss: 0.000221
#   Epoch 4 | Batch 900/2503 | Batch Loss: 0.000232
#   Epoch 4 | Batch 1000/2503 | Batch Loss: 0.000275
#   Epoch 4 | Batch 1100/2503 | Batch Loss: 0.000195
#   Epoch 4 | Batch 1200/2503 | Batch Loss: 0.000309
#   Epoch 4 | Batch 1300/2503 | Batch Loss: 0.000234
#   Epoch 4 | Batch 1400/2503 | Batch Loss: 0.005035
#   Epoch 4 | Batch 1500/2503 | Batch Loss: 0.000955
#   Epoch 4 | Batch 1600/2503 | Batch Loss: 0.014954
#   Epoch 4 | Batch 1700/2503 | Batch Loss: 0.000194
#   Epoch 4 | Batch 1800/2503 | Batch Loss: 0.001736
#   Epoch 4 | Batch 1900/2503 | Batch Loss: 0.000205
#   Epoch 4 | Batch 2000/2503 | Batch Loss: 0.000308
#   Epoch 4 | Batch 2100/2503 | Batch Loss: 0.000238
#   Epoch 4 | Batch 2200/2503 | Batch Loss: 0.000592
#   Epoch 4 | Batch 2300/2503 | Batch Loss: 0.000217
#   Epoch 4 | Batch 2400/2503 | Batch Loss: 0.000222
#   Epoch 4 | Batch 2500/2503 | Batch Loss: 0.000267
#
# Fine-tune Epoch 4/50 | Time: 149.8s
#   Train Loss: 0.001017 | Val MSE: 0.002043 *** New Best ***
# ------------------------------------------------------------
#   Epoch 5 | Batch 100/2503 | Batch Loss: 0.005172
#   Epoch 5 | Batch 200/2503 | Batch Loss: 0.000187
#   Epoch 5 | Batch 300/2503 | Batch Loss: 0.000215
#   Epoch 5 | Batch 400/2503 | Batch Loss: 0.000202
#   Epoch 5 | Batch 500/2503 | Batch Loss: 0.000248
#   Epoch 5 | Batch 600/2503 | Batch Loss: 0.000176
#   Epoch 5 | Batch 700/2503 | Batch Loss: 0.000195
#   Epoch 5 | Batch 800/2503 | Batch Loss: 0.000201
#   Epoch 5 | Batch 900/2503 | Batch Loss: 0.001026
#   Epoch 5 | Batch 1000/2503 | Batch Loss: 0.000354
#   Epoch 5 | Batch 1100/2503 | Batch Loss: 0.001194
#   Epoch 5 | Batch 1200/2503 | Batch Loss: 0.000304
#   Epoch 5 | Batch 1300/2503 | Batch Loss: 0.000229
#   Epoch 5 | Batch 1400/2503 | Batch Loss: 0.000222
#   Epoch 5 | Batch 1500/2503 | Batch Loss: 0.000269
#   Epoch 5 | Batch 1600/2503 | Batch Loss: 0.000248
#   Epoch 5 | Batch 1700/2503 | Batch Loss: 0.000193
#   Epoch 5 | Batch 1800/2503 | Batch Loss: 0.000226
#   Epoch 5 | Batch 1900/2503 | Batch Loss: 0.000212
#   Epoch 5 | Batch 2000/2503 | Batch Loss: 0.000219
#   Epoch 5 | Batch 2100/2503 | Batch Loss: 0.000204
#   Epoch 5 | Batch 2200/2503 | Batch Loss: 0.000192
#   Epoch 5 | Batch 2300/2503 | Batch Loss: 0.000187
#   Epoch 5 | Batch 2400/2503 | Batch Loss: 0.009015
#   Epoch 5 | Batch 2500/2503 | Batch Loss: 0.000208
#
# Fine-tune Epoch 5/50 | Time: 148.9s
#   Train Loss: 0.000910 | Val MSE: 0.002225
# ------------------------------------------------------------
#   Epoch 6 | Batch 100/2503 | Batch Loss: 0.000206
#   Epoch 6 | Batch 200/2503 | Batch Loss: 0.000231
#   Epoch 6 | Batch 300/2503 | Batch Loss: 0.000473
#   Epoch 6 | Batch 400/2503 | Batch Loss: 0.000201
#   Epoch 6 | Batch 500/2503 | Batch Loss: 0.000180
#   Epoch 6 | Batch 600/2503 | Batch Loss: 0.003192
#   Epoch 6 | Batch 700/2503 | Batch Loss: 0.000249
#   Epoch 6 | Batch 800/2503 | Batch Loss: 0.000229
#   Epoch 6 | Batch 900/2503 | Batch Loss: 0.000284
#   Epoch 6 | Batch 1000/2503 | Batch Loss: 0.000220
#   Epoch 6 | Batch 1100/2503 | Batch Loss: 0.000190
#   Epoch 6 | Batch 1200/2503 | Batch Loss: 0.000181
#   Epoch 6 | Batch 1300/2503 | Batch Loss: 0.000198
#   Epoch 6 | Batch 1400/2503 | Batch Loss: 0.003095
#   Epoch 6 | Batch 1500/2503 | Batch Loss: 0.000205
#   Epoch 6 | Batch 1600/2503 | Batch Loss: 0.000236
#   Epoch 6 | Batch 1700/2503 | Batch Loss: 0.000228
#   Epoch 6 | Batch 1800/2503 | Batch Loss: 0.000281
#   Epoch 6 | Batch 1900/2503 | Batch Loss: 0.000218
#   Epoch 6 | Batch 2000/2503 | Batch Loss: 0.000188
#   Epoch 6 | Batch 2100/2503 | Batch Loss: 0.000176
#   Epoch 6 | Batch 2200/2503 | Batch Loss: 0.000175
#   Epoch 6 | Batch 2300/2503 | Batch Loss: 0.000291
#   Epoch 6 | Batch 2400/2503 | Batch Loss: 0.000204
#   Epoch 6 | Batch 2500/2503 | Batch Loss: 0.000189
#
# Fine-tune Epoch 6/50 | Time: 148.4s
#   Train Loss: 0.000800 | Val MSE: 0.001589 *** New Best ***
# ------------------------------------------------------------
#   Epoch 7 | Batch 100/2503 | Batch Loss: 0.000230
#   Epoch 7 | Batch 200/2503 | Batch Loss: 0.000255
#   Epoch 7 | Batch 300/2503 | Batch Loss: 0.000466
#   Epoch 7 | Batch 400/2503 | Batch Loss: 0.004284
#   Epoch 7 | Batch 500/2503 | Batch Loss: 0.000182
#   Epoch 7 | Batch 600/2503 | Batch Loss: 0.000252
#   Epoch 7 | Batch 700/2503 | Batch Loss: 0.000254
#   Epoch 7 | Batch 800/2503 | Batch Loss: 0.004514
#   Epoch 7 | Batch 900/2503 | Batch Loss: 0.000215
#   Epoch 7 | Batch 1000/2503 | Batch Loss: 0.000203
#   Epoch 7 | Batch 1100/2503 | Batch Loss: 0.000212
#   Epoch 7 | Batch 1200/2503 | Batch Loss: 0.011581
#   Epoch 7 | Batch 1300/2503 | Batch Loss: 0.001371
#   Epoch 7 | Batch 1400/2503 | Batch Loss: 0.001147
#   Epoch 7 | Batch 1500/2503 | Batch Loss: 0.000187
#   Epoch 7 | Batch 1600/2503 | Batch Loss: 0.000311
#   Epoch 7 | Batch 1700/2503 | Batch Loss: 0.000197
#   Epoch 7 | Batch 1800/2503 | Batch Loss: 0.000176
#   Epoch 7 | Batch 1900/2503 | Batch Loss: 0.000220
#   Epoch 7 | Batch 2000/2503 | Batch Loss: 0.000183
#   Epoch 7 | Batch 2100/2503 | Batch Loss: 0.000251
#   Epoch 7 | Batch 2200/2503 | Batch Loss: 0.000232
#   Epoch 7 | Batch 2300/2503 | Batch Loss: 0.000200
#   Epoch 7 | Batch 2400/2503 | Batch Loss: 0.000231
#   Epoch 7 | Batch 2500/2503 | Batch Loss: 0.000181
#
# Fine-tune Epoch 7/50 | Time: 147.8s
#   Train Loss: 0.000740 | Val MSE: 0.001932
# ------------------------------------------------------------
#   Epoch 8 | Batch 100/2503 | Batch Loss: 0.000216
#   Epoch 8 | Batch 200/2503 | Batch Loss: 0.000177
#   Epoch 8 | Batch 300/2503 | Batch Loss: 0.000201
#   Epoch 8 | Batch 400/2503 | Batch Loss: 0.000182
#   Epoch 8 | Batch 500/2503 | Batch Loss: 0.000294
#   Epoch 8 | Batch 600/2503 | Batch Loss: 0.000175
#   Epoch 8 | Batch 700/2503 | Batch Loss: 0.000171
#   Epoch 8 | Batch 800/2503 | Batch Loss: 0.000193
#   Epoch 8 | Batch 900/2503 | Batch Loss: 0.000883
#   Epoch 8 | Batch 1000/2503 | Batch Loss: 0.003472
#   Epoch 8 | Batch 1100/2503 | Batch Loss: 0.000186
#   Epoch 8 | Batch 1200/2503 | Batch Loss: 0.000209
#   Epoch 8 | Batch 1300/2503 | Batch Loss: 0.002539
#   Epoch 8 | Batch 1400/2503 | Batch Loss: 0.000242
#   Epoch 8 | Batch 1500/2503 | Batch Loss: 0.000935
#   Epoch 8 | Batch 1600/2503 | Batch Loss: 0.000277
#   Epoch 8 | Batch 1700/2503 | Batch Loss: 0.000219
#   Epoch 8 | Batch 1800/2503 | Batch Loss: 0.000181
#   Epoch 8 | Batch 1900/2503 | Batch Loss: 0.000180
#   Epoch 8 | Batch 2000/2503 | Batch Loss: 0.000184
#   Epoch 8 | Batch 2100/2503 | Batch Loss: 0.000191
#   Epoch 8 | Batch 2200/2503 | Batch Loss: 0.000223
#   Epoch 8 | Batch 2300/2503 | Batch Loss: 0.000217
#   Epoch 8 | Batch 2400/2503 | Batch Loss: 0.000184
#   Epoch 8 | Batch 2500/2503 | Batch Loss: 0.000147
#
# Fine-tune Epoch 8/50 | Time: 148.1s
#   Train Loss: 0.000697 | Val MSE: 0.001531 *** New Best ***
# ------------------------------------------------------------
#   Epoch 9 | Batch 100/2503 | Batch Loss: 0.000234
#   Epoch 9 | Batch 200/2503 | Batch Loss: 0.000196
#   Epoch 9 | Batch 300/2503 | Batch Loss: 0.002978
#   Epoch 9 | Batch 400/2503 | Batch Loss: 0.000208
#   Epoch 9 | Batch 500/2503 | Batch Loss: 0.000193
#   Epoch 9 | Batch 600/2503 | Batch Loss: 0.000159
#   Epoch 9 | Batch 700/2503 | Batch Loss: 0.000180
#   Epoch 9 | Batch 800/2503 | Batch Loss: 0.000226
#   Epoch 9 | Batch 900/2503 | Batch Loss: 0.003638
#   Epoch 9 | Batch 1000/2503 | Batch Loss: 0.000189
#   Epoch 9 | Batch 1100/2503 | Batch Loss: 0.000180
#   Epoch 9 | Batch 1200/2503 | Batch Loss: 0.001314
#   Epoch 9 | Batch 1300/2503 | Batch Loss: 0.000195
#   Epoch 9 | Batch 1400/2503 | Batch Loss: 0.000168
#   Epoch 9 | Batch 1500/2503 | Batch Loss: 0.000191
#   Epoch 9 | Batch 1600/2503 | Batch Loss: 0.000179
#   Epoch 9 | Batch 1700/2503 | Batch Loss: 0.000222
#   Epoch 9 | Batch 1800/2503 | Batch Loss: 0.000217
#   Epoch 9 | Batch 1900/2503 | Batch Loss: 0.000173
#   Epoch 9 | Batch 2000/2503 | Batch Loss: 0.000270
#   Epoch 9 | Batch 2100/2503 | Batch Loss: 0.000304
#   Epoch 9 | Batch 2200/2503 | Batch Loss: 0.000186
#   Epoch 9 | Batch 2300/2503 | Batch Loss: 0.000170
#   Epoch 9 | Batch 2400/2503 | Batch Loss: 0.000168
#   Epoch 9 | Batch 2500/2503 | Batch Loss: 0.000924
#
# Fine-tune Epoch 9/50 | Time: 147.8s
#   Train Loss: 0.000642 | Val MSE: 0.001291 *** New Best ***
# ------------------------------------------------------------
#   Epoch 10 | Batch 100/2503 | Batch Loss: 0.000187
#   Epoch 10 | Batch 200/2503 | Batch Loss: 0.000197
#   Epoch 10 | Batch 300/2503 | Batch Loss: 0.000190
#   Epoch 10 | Batch 400/2503 | Batch Loss: 0.000199
#   Epoch 10 | Batch 500/2503 | Batch Loss: 0.000212
#   Epoch 10 | Batch 600/2503 | Batch Loss: 0.000157
#   Epoch 10 | Batch 700/2503 | Batch Loss: 0.000324
#   Epoch 10 | Batch 800/2503 | Batch Loss: 0.000183
#   Epoch 10 | Batch 900/2503 | Batch Loss: 0.000235
#   Epoch 10 | Batch 1000/2503 | Batch Loss: 0.000181
#   Epoch 10 | Batch 1100/2503 | Batch Loss: 0.000145
#   Epoch 10 | Batch 1200/2503 | Batch Loss: 0.000175
#   Epoch 10 | Batch 1300/2503 | Batch Loss: 0.000192
#   Epoch 10 | Batch 1400/2503 | Batch Loss: 0.000196
#   Epoch 10 | Batch 1500/2503 | Batch Loss: 0.000231
#   Epoch 10 | Batch 1600/2503 | Batch Loss: 0.000170
#   Epoch 10 | Batch 1700/2503 | Batch Loss: 0.001924
#   Epoch 10 | Batch 1800/2503 | Batch Loss: 0.000174
#   Epoch 10 | Batch 1900/2503 | Batch Loss: 0.000238
#   Epoch 10 | Batch 2000/2503 | Batch Loss: 0.000166
#   Epoch 10 | Batch 2100/2503 | Batch Loss: 0.000199
#   Epoch 10 | Batch 2200/2503 | Batch Loss: 0.000163
#   Epoch 10 | Batch 2300/2503 | Batch Loss: 0.000191
#   Epoch 10 | Batch 2400/2503 | Batch Loss: 0.000180
#   Epoch 10 | Batch 2500/2503 | Batch Loss: 0.003188
#
# Fine-tune Epoch 10/50 | Time: 147.8s
#   Train Loss: 0.000586 | Val MSE: 0.001251 *** New Best ***
# ------------------------------------------------------------
#   Epoch 11 | Batch 100/2503 | Batch Loss: 0.000170
#   Epoch 11 | Batch 200/2503 | Batch Loss: 0.000174
#   Epoch 11 | Batch 300/2503 | Batch Loss: 0.000185
#   Epoch 11 | Batch 400/2503 | Batch Loss: 0.004302
#   Epoch 11 | Batch 500/2503 | Batch Loss: 0.000164
#   Epoch 11 | Batch 600/2503 | Batch Loss: 0.001161
#   Epoch 11 | Batch 700/2503 | Batch Loss: 0.000180
#   Epoch 11 | Batch 800/2503 | Batch Loss: 0.000170
#   Epoch 11 | Batch 900/2503 | Batch Loss: 0.000252
#   Epoch 11 | Batch 1000/2503 | Batch Loss: 0.000188
#   Epoch 11 | Batch 1100/2503 | Batch Loss: 0.000175
#   Epoch 11 | Batch 1200/2503 | Batch Loss: 0.000173
#   Epoch 11 | Batch 1300/2503 | Batch Loss: 0.000167
#   Epoch 11 | Batch 1400/2503 | Batch Loss: 0.000181
#   Epoch 11 | Batch 1500/2503 | Batch Loss: 0.000216
#   Epoch 11 | Batch 1600/2503 | Batch Loss: 0.000182
#   Epoch 11 | Batch 1700/2503 | Batch Loss: 0.000173
#   Epoch 11 | Batch 1800/2503 | Batch Loss: 0.000162
#   Epoch 11 | Batch 1900/2503 | Batch Loss: 0.000171
#   Epoch 11 | Batch 2000/2503 | Batch Loss: 0.000174
#   Epoch 11 | Batch 2100/2503 | Batch Loss: 0.000151
#   Epoch 11 | Batch 2200/2503 | Batch Loss: 0.000209
#   Epoch 11 | Batch 2300/2503 | Batch Loss: 0.000169
#   Epoch 11 | Batch 2400/2503 | Batch Loss: 0.000177
#   Epoch 11 | Batch 2500/2503 | Batch Loss: 0.000206
#
# Fine-tune Epoch 11/50 | Time: 148.2s
#   Train Loss: 0.000554 | Val MSE: 0.001268
# ------------------------------------------------------------
#   Epoch 12 | Batch 100/2503 | Batch Loss: 0.000202
#   Epoch 12 | Batch 200/2503 | Batch Loss: 0.000153
#   Epoch 12 | Batch 300/2503 | Batch Loss: 0.000149
#   Epoch 12 | Batch 400/2503 | Batch Loss: 0.000192
#   Epoch 12 | Batch 500/2503 | Batch Loss: 0.000183
#   Epoch 12 | Batch 600/2503 | Batch Loss: 0.000152
#   Epoch 12 | Batch 700/2503 | Batch Loss: 0.000280
#   Epoch 12 | Batch 800/2503 | Batch Loss: 0.000182
#   Epoch 12 | Batch 900/2503 | Batch Loss: 0.000167
#   Epoch 12 | Batch 1000/2503 | Batch Loss: 0.001113
#   Epoch 12 | Batch 1100/2503 | Batch Loss: 0.000168
#   Epoch 12 | Batch 1200/2503 | Batch Loss: 0.000196
#   Epoch 12 | Batch 1300/2503 | Batch Loss: 0.000169
#   Epoch 12 | Batch 1400/2503 | Batch Loss: 0.000199
#   Epoch 12 | Batch 1500/2503 | Batch Loss: 0.000167
#   Epoch 12 | Batch 1600/2503 | Batch Loss: 0.000156
#   Epoch 12 | Batch 1700/2503 | Batch Loss: 0.000171
#   Epoch 12 | Batch 1800/2503 | Batch Loss: 0.000163
#   Epoch 12 | Batch 1900/2503 | Batch Loss: 0.000143
#   Epoch 12 | Batch 2000/2503 | Batch Loss: 0.000168
#   Epoch 12 | Batch 2100/2503 | Batch Loss: 0.000224
#   Epoch 12 | Batch 2200/2503 | Batch Loss: 0.000154
#   Epoch 12 | Batch 2300/2503 | Batch Loss: 0.000137
#   Epoch 12 | Batch 2400/2503 | Batch Loss: 0.000178
#   Epoch 12 | Batch 2500/2503 | Batch Loss: 0.000197
#
# Fine-tune Epoch 12/50 | Time: 147.6s
#   Train Loss: 0.000537 | Val MSE: 0.001123 *** New Best ***
# ------------------------------------------------------------
#   Epoch 13 | Batch 100/2503 | Batch Loss: 0.000235
#   Epoch 13 | Batch 200/2503 | Batch Loss: 0.000196
#   Epoch 13 | Batch 300/2503 | Batch Loss: 0.002198
#   Epoch 13 | Batch 400/2503 | Batch Loss: 0.003872
#   Epoch 13 | Batch 500/2503 | Batch Loss: 0.000181
#   Epoch 13 | Batch 600/2503 | Batch Loss: 0.000231
#   Epoch 13 | Batch 700/2503 | Batch Loss: 0.000160
#   Epoch 13 | Batch 800/2503 | Batch Loss: 0.000170
#   Epoch 13 | Batch 900/2503 | Batch Loss: 0.000244
#   Epoch 13 | Batch 1000/2503 | Batch Loss: 0.000167
#   Epoch 13 | Batch 1100/2503 | Batch Loss: 0.000210
#   Epoch 13 | Batch 1200/2503 | Batch Loss: 0.000152
#   Epoch 13 | Batch 1300/2503 | Batch Loss: 0.000266
#   Epoch 13 | Batch 1400/2503 | Batch Loss: 0.000164
#   Epoch 13 | Batch 1500/2503 | Batch Loss: 0.000157
#   Epoch 13 | Batch 1600/2503 | Batch Loss: 0.000200
#   Epoch 13 | Batch 1700/2503 | Batch Loss: 0.000149
#   Epoch 13 | Batch 1800/2503 | Batch Loss: 0.000153
#   Epoch 13 | Batch 1900/2503 | Batch Loss: 0.001665
#   Epoch 13 | Batch 2000/2503 | Batch Loss: 0.000280
#   Epoch 13 | Batch 2100/2503 | Batch Loss: 0.000209
#   Epoch 13 | Batch 2200/2503 | Batch Loss: 0.000147
#   Epoch 13 | Batch 2300/2503 | Batch Loss: 0.000244
#   Epoch 13 | Batch 2400/2503 | Batch Loss: 0.000172
#   Epoch 13 | Batch 2500/2503 | Batch Loss: 0.000179
#
# Fine-tune Epoch 13/50 | Time: 147.6s
#   Train Loss: 0.000504 | Val MSE: 0.001197
# ------------------------------------------------------------
#   Epoch 14 | Batch 100/2503 | Batch Loss: 0.000153
#   Epoch 14 | Batch 200/2503 | Batch Loss: 0.000174
#   Epoch 14 | Batch 300/2503 | Batch Loss: 0.000157
#   Epoch 14 | Batch 400/2503 | Batch Loss: 0.000150
#   Epoch 14 | Batch 500/2503 | Batch Loss: 0.000585
#   Epoch 14 | Batch 600/2503 | Batch Loss: 0.000162
#   Epoch 14 | Batch 700/2503 | Batch Loss: 0.000204
#   Epoch 14 | Batch 800/2503 | Batch Loss: 0.000837
#   Epoch 14 | Batch 900/2503 | Batch Loss: 0.000172
#   Epoch 14 | Batch 1000/2503 | Batch Loss: 0.000145
#   Epoch 14 | Batch 1100/2503 | Batch Loss: 0.000159
#   Epoch 14 | Batch 1200/2503 | Batch Loss: 0.002584
#   Epoch 14 | Batch 1300/2503 | Batch Loss: 0.000162
#   Epoch 14 | Batch 1400/2503 | Batch Loss: 0.000315
#   Epoch 14 | Batch 1500/2503 | Batch Loss: 0.000147
#   Epoch 14 | Batch 1600/2503 | Batch Loss: 0.000166
#   Epoch 14 | Batch 1700/2503 | Batch Loss: 0.000148
#   Epoch 14 | Batch 1800/2503 | Batch Loss: 0.000163
#   Epoch 14 | Batch 1900/2503 | Batch Loss: 0.000838
#   Epoch 14 | Batch 2000/2503 | Batch Loss: 0.000143
#   Epoch 14 | Batch 2100/2503 | Batch Loss: 0.000188
#   Epoch 14 | Batch 2200/2503 | Batch Loss: 0.000155
#   Epoch 14 | Batch 2300/2503 | Batch Loss: 0.001053
#   Epoch 14 | Batch 2400/2503 | Batch Loss: 0.000160
#   Epoch 14 | Batch 2500/2503 | Batch Loss: 0.000152
#
# Fine-tune Epoch 14/50 | Time: 147.3s
#   Train Loss: 0.000475 | Val MSE: 0.001264
# ------------------------------------------------------------
#   Epoch 15 | Batch 100/2503 | Batch Loss: 0.000158
#   Epoch 15 | Batch 200/2503 | Batch Loss: 0.000147
#   Epoch 15 | Batch 300/2503 | Batch Loss: 0.000147
#   Epoch 15 | Batch 400/2503 | Batch Loss: 0.000140
#   Epoch 15 | Batch 500/2503 | Batch Loss: 0.000149
#   Epoch 15 | Batch 600/2503 | Batch Loss: 0.000168
#   Epoch 15 | Batch 700/2503 | Batch Loss: 0.001267
#   Epoch 15 | Batch 800/2503 | Batch Loss: 0.000141
#   Epoch 15 | Batch 900/2503 | Batch Loss: 0.000167
#   Epoch 15 | Batch 1000/2503 | Batch Loss: 0.000214
#   Epoch 15 | Batch 1100/2503 | Batch Loss: 0.000162
#   Epoch 15 | Batch 1200/2503 | Batch Loss: 0.003443
#   Epoch 15 | Batch 1300/2503 | Batch Loss: 0.000168
#   Epoch 15 | Batch 1400/2503 | Batch Loss: 0.000146
#   Epoch 15 | Batch 1500/2503 | Batch Loss: 0.000151
#   Epoch 15 | Batch 1600/2503 | Batch Loss: 0.000152
#   Epoch 15 | Batch 1700/2503 | Batch Loss: 0.000170
#   Epoch 15 | Batch 1800/2503 | Batch Loss: 0.000145
#   Epoch 15 | Batch 1900/2503 | Batch Loss: 0.000180
#   Epoch 15 | Batch 2000/2503 | Batch Loss: 0.000128
#   Epoch 15 | Batch 2100/2503 | Batch Loss: 0.000155
#   Epoch 15 | Batch 2200/2503 | Batch Loss: 0.001750
#   Epoch 15 | Batch 2300/2503 | Batch Loss: 0.000146
#   Epoch 15 | Batch 2400/2503 | Batch Loss: 0.000146
#   Epoch 15 | Batch 2500/2503 | Batch Loss: 0.000142
#
# Fine-tune Epoch 15/50 | Time: 147.1s
#   Train Loss: 0.000450 | Val MSE: 0.001018 *** New Best ***
# ------------------------------------------------------------
#   Epoch 16 | Batch 100/2503 | Batch Loss: 0.000150
#   Epoch 16 | Batch 200/2503 | Batch Loss: 0.000134
#   Epoch 16 | Batch 300/2503 | Batch Loss: 0.002462
#   Epoch 16 | Batch 400/2503 | Batch Loss: 0.000125
#   Epoch 16 | Batch 500/2503 | Batch Loss: 0.000130
#   Epoch 16 | Batch 600/2503 | Batch Loss: 0.000140
#   Epoch 16 | Batch 700/2503 | Batch Loss: 0.000141
#   Epoch 16 | Batch 800/2503 | Batch Loss: 0.000723
#   Epoch 16 | Batch 900/2503 | Batch Loss: 0.000155
#   Epoch 16 | Batch 1000/2503 | Batch Loss: 0.000161
#   Epoch 16 | Batch 1100/2503 | Batch Loss: 0.000191
#   Epoch 16 | Batch 1200/2503 | Batch Loss: 0.000169
#   Epoch 16 | Batch 1300/2503 | Batch Loss: 0.000144
#   Epoch 16 | Batch 1400/2503 | Batch Loss: 0.000199
#   Epoch 16 | Batch 1500/2503 | Batch Loss: 0.000603
#   Epoch 16 | Batch 1600/2503 | Batch Loss: 0.000148
#   Epoch 16 | Batch 1700/2503 | Batch Loss: 0.001441
#   Epoch 16 | Batch 1800/2503 | Batch Loss: 0.000125
#   Epoch 16 | Batch 1900/2503 | Batch Loss: 0.000163
#   Epoch 16 | Batch 2000/2503 | Batch Loss: 0.000133
#   Epoch 16 | Batch 2100/2503 | Batch Loss: 0.000138
#   Epoch 16 | Batch 2200/2503 | Batch Loss: 0.000149
#   Epoch 16 | Batch 2300/2503 | Batch Loss: 0.000168
#   Epoch 16 | Batch 2400/2503 | Batch Loss: 0.000134
#   Epoch 16 | Batch 2500/2503 | Batch Loss: 0.000126
#
# Fine-tune Epoch 16/50 | Time: 147.8s
#   Train Loss: 0.000435 | Val MSE: 0.001121
# ------------------------------------------------------------
#   Epoch 17 | Batch 100/2503 | Batch Loss: 0.000673
#   Epoch 17 | Batch 200/2503 | Batch Loss: 0.000133
#   Epoch 17 | Batch 300/2503 | Batch Loss: 0.000187
#   Epoch 17 | Batch 400/2503 | Batch Loss: 0.000182
#   Epoch 17 | Batch 500/2503 | Batch Loss: 0.000129
#   Epoch 17 | Batch 600/2503 | Batch Loss: 0.001056
#   Epoch 17 | Batch 700/2503 | Batch Loss: 0.000169
#   Epoch 17 | Batch 800/2503 | Batch Loss: 0.001338
#   Epoch 17 | Batch 900/2503 | Batch Loss: 0.000137
#   Epoch 17 | Batch 1000/2503 | Batch Loss: 0.000443
#   Epoch 17 | Batch 1100/2503 | Batch Loss: 0.001168
#   Epoch 17 | Batch 1200/2503 | Batch Loss: 0.000149
#   Epoch 17 | Batch 1300/2503 | Batch Loss: 0.000149
#   Epoch 17 | Batch 1400/2503 | Batch Loss: 0.000265
#   Epoch 17 | Batch 1500/2503 | Batch Loss: 0.003613
#   Epoch 17 | Batch 1600/2503 | Batch Loss: 0.000128
#   Epoch 17 | Batch 1700/2503 | Batch Loss: 0.000135
#   Epoch 17 | Batch 1800/2503 | Batch Loss: 0.000155
#   Epoch 17 | Batch 1900/2503 | Batch Loss: 0.000139
#   Epoch 17 | Batch 2000/2503 | Batch Loss: 0.000137
#   Epoch 17 | Batch 2100/2503 | Batch Loss: 0.000474
#   Epoch 17 | Batch 2200/2503 | Batch Loss: 0.000136
#   Epoch 17 | Batch 2300/2503 | Batch Loss: 0.000138
#   Epoch 17 | Batch 2400/2503 | Batch Loss: 0.000530
#   Epoch 17 | Batch 2500/2503 | Batch Loss: 0.000143
#
# Fine-tune Epoch 17/50 | Time: 148.2s
#   Train Loss: 0.000421 | Val MSE: 0.000803 *** New Best ***
# ------------------------------------------------------------
#   Epoch 18 | Batch 100/2503 | Batch Loss: 0.000140
#   Epoch 18 | Batch 200/2503 | Batch Loss: 0.000129
#   Epoch 18 | Batch 300/2503 | Batch Loss: 0.000216
#   Epoch 18 | Batch 400/2503 | Batch Loss: 0.000139
#   Epoch 18 | Batch 500/2503 | Batch Loss: 0.000138
#   Epoch 18 | Batch 600/2503 | Batch Loss: 0.000144
#   Epoch 18 | Batch 700/2503 | Batch Loss: 0.001810
#   Epoch 18 | Batch 800/2503 | Batch Loss: 0.000143
#   Epoch 18 | Batch 900/2503 | Batch Loss: 0.001412
#   Epoch 18 | Batch 1000/2503 | Batch Loss: 0.000128
#   Epoch 18 | Batch 1100/2503 | Batch Loss: 0.000135
#   Epoch 18 | Batch 1200/2503 | Batch Loss: 0.000148
#   Epoch 18 | Batch 1300/2503 | Batch Loss: 0.000153
#   Epoch 18 | Batch 1400/2503 | Batch Loss: 0.000135
#   Epoch 18 | Batch 1500/2503 | Batch Loss: 0.000165
#   Epoch 18 | Batch 1600/2503 | Batch Loss: 0.000478
#   Epoch 18 | Batch 1700/2503 | Batch Loss: 0.000178
#   Epoch 18 | Batch 1800/2503 | Batch Loss: 0.000161
#   Epoch 18 | Batch 1900/2503 | Batch Loss: 0.000130
#   Epoch 18 | Batch 2000/2503 | Batch Loss: 0.001067
#   Epoch 18 | Batch 2100/2503 | Batch Loss: 0.000119
#   Epoch 18 | Batch 2200/2503 | Batch Loss: 0.000119
#   Epoch 18 | Batch 2300/2503 | Batch Loss: 0.000134
#   Epoch 18 | Batch 2400/2503 | Batch Loss: 0.002132
#   Epoch 18 | Batch 2500/2503 | Batch Loss: 0.004322
#
# Fine-tune Epoch 18/50 | Time: 147.4s
#   Train Loss: 0.000398 | Val MSE: 0.001180
# ------------------------------------------------------------
#   Epoch 19 | Batch 100/2503 | Batch Loss: 0.000199
#   Epoch 19 | Batch 200/2503 | Batch Loss: 0.000155
#   Epoch 19 | Batch 300/2503 | Batch Loss: 0.000117
#   Epoch 19 | Batch 400/2503 | Batch Loss: 0.000131
#   Epoch 19 | Batch 500/2503 | Batch Loss: 0.000130
#   Epoch 19 | Batch 600/2503 | Batch Loss: 0.000134
#   Epoch 19 | Batch 700/2503 | Batch Loss: 0.000137
#   Epoch 19 | Batch 800/2503 | Batch Loss: 0.000117
#   Epoch 19 | Batch 900/2503 | Batch Loss: 0.000121
#   Epoch 19 | Batch 1000/2503 | Batch Loss: 0.000111
#   Epoch 19 | Batch 1100/2503 | Batch Loss: 0.000159
#   Epoch 19 | Batch 1200/2503 | Batch Loss: 0.000134
#   Epoch 19 | Batch 1300/2503 | Batch Loss: 0.000156
#   Epoch 19 | Batch 1400/2503 | Batch Loss: 0.000130
#   Epoch 19 | Batch 1500/2503 | Batch Loss: 0.000122
#   Epoch 19 | Batch 1600/2503 | Batch Loss: 0.000129
#   Epoch 19 | Batch 1700/2503 | Batch Loss: 0.000118
#   Epoch 19 | Batch 1800/2503 | Batch Loss: 0.000121
#   Epoch 19 | Batch 1900/2503 | Batch Loss: 0.000110
#   Epoch 19 | Batch 2000/2503 | Batch Loss: 0.000144
#   Epoch 19 | Batch 2100/2503 | Batch Loss: 0.000144
#   Epoch 19 | Batch 2200/2503 | Batch Loss: 0.000133
#   Epoch 19 | Batch 2300/2503 | Batch Loss: 0.000161
#   Epoch 19 | Batch 2400/2503 | Batch Loss: 0.000131
#   Epoch 19 | Batch 2500/2503 | Batch Loss: 0.000348
#
# Fine-tune Epoch 19/50 | Time: 147.2s
#   Train Loss: 0.000379 | Val MSE: 0.001153
# ------------------------------------------------------------
#   Epoch 20 | Batch 100/2503 | Batch Loss: 0.000139
#   Epoch 20 | Batch 200/2503 | Batch Loss: 0.005253
#   Epoch 20 | Batch 300/2503 | Batch Loss: 0.000121
#   Epoch 20 | Batch 400/2503 | Batch Loss: 0.000276
#   Epoch 20 | Batch 500/2503 | Batch Loss: 0.000132
#   Epoch 20 | Batch 600/2503 | Batch Loss: 0.000134
#   Epoch 20 | Batch 700/2503 | Batch Loss: 0.000132
#   Epoch 20 | Batch 800/2503 | Batch Loss: 0.000136
#   Epoch 20 | Batch 900/2503 | Batch Loss: 0.000112
#   Epoch 20 | Batch 1000/2503 | Batch Loss: 0.000143
#   Epoch 20 | Batch 1100/2503 | Batch Loss: 0.000220
#   Epoch 20 | Batch 1200/2503 | Batch Loss: 0.000132
#   Epoch 20 | Batch 1300/2503 | Batch Loss: 0.000132
#   Epoch 20 | Batch 1400/2503 | Batch Loss: 0.000522
#   Epoch 20 | Batch 1500/2503 | Batch Loss: 0.000137
#   Epoch 20 | Batch 1600/2503 | Batch Loss: 0.000167
#   Epoch 20 | Batch 1700/2503 | Batch Loss: 0.000111
#   Epoch 20 | Batch 1800/2503 | Batch Loss: 0.000318
#   Epoch 20 | Batch 1900/2503 | Batch Loss: 0.000105
#   Epoch 20 | Batch 2000/2503 | Batch Loss: 0.000123
#   Epoch 20 | Batch 2100/2503 | Batch Loss: 0.000132
#   Epoch 20 | Batch 2200/2503 | Batch Loss: 0.000114
#   Epoch 20 | Batch 2300/2503 | Batch Loss: 0.000118
#   Epoch 20 | Batch 2400/2503 | Batch Loss: 0.000117
#   Epoch 20 | Batch 2500/2503 | Batch Loss: 0.000123
#
# Fine-tune Epoch 20/50 | Time: 148.1s
#   Train Loss: 0.000368 | Val MSE: 0.000637 *** New Best ***
# ------------------------------------------------------------
#   Epoch 21 | Batch 100/2503 | Batch Loss: 0.000118
#   Epoch 21 | Batch 200/2503 | Batch Loss: 0.000145
#   Epoch 21 | Batch 300/2503 | Batch Loss: 0.000123
#   Epoch 21 | Batch 400/2503 | Batch Loss: 0.000121
#   Epoch 21 | Batch 500/2503 | Batch Loss: 0.000121
#   Epoch 21 | Batch 600/2503 | Batch Loss: 0.000157
#   Epoch 21 | Batch 700/2503 | Batch Loss: 0.000678
#   Epoch 21 | Batch 800/2503 | Batch Loss: 0.000127
#   Epoch 21 | Batch 900/2503 | Batch Loss: 0.000126
#   Epoch 21 | Batch 1000/2503 | Batch Loss: 0.000116
#   Epoch 21 | Batch 1100/2503 | Batch Loss: 0.002165
#   Epoch 21 | Batch 1200/2503 | Batch Loss: 0.000109
#   Epoch 21 | Batch 1300/2503 | Batch Loss: 0.000104
#   Epoch 21 | Batch 1400/2503 | Batch Loss: 0.000127
#   Epoch 21 | Batch 1500/2503 | Batch Loss: 0.000129
#   Epoch 21 | Batch 1600/2503 | Batch Loss: 0.000106
#   Epoch 21 | Batch 1700/2503 | Batch Loss: 0.000219
#   Epoch 21 | Batch 1800/2503 | Batch Loss: 0.000132
#   Epoch 21 | Batch 1900/2503 | Batch Loss: 0.000315
#   Epoch 21 | Batch 2000/2503 | Batch Loss: 0.000113
#   Epoch 21 | Batch 2100/2503 | Batch Loss: 0.000139
#   Epoch 21 | Batch 2200/2503 | Batch Loss: 0.000111
#   Epoch 21 | Batch 2300/2503 | Batch Loss: 0.000129
#   Epoch 21 | Batch 2400/2503 | Batch Loss: 0.000126
#   Epoch 21 | Batch 2500/2503 | Batch Loss: 0.000134
#
# Fine-tune Epoch 21/50 | Time: 147.7s
#   Train Loss: 0.000359 | Val MSE: 0.000855
# ------------------------------------------------------------
#   Epoch 22 | Batch 100/2503 | Batch Loss: 0.000145
#   Epoch 22 | Batch 200/2503 | Batch Loss: 0.000119
#   Epoch 22 | Batch 300/2503 | Batch Loss: 0.000097
#   Epoch 22 | Batch 400/2503 | Batch Loss: 0.000121
#   Epoch 22 | Batch 500/2503 | Batch Loss: 0.000134
#   Epoch 22 | Batch 600/2503 | Batch Loss: 0.000114
#   Epoch 22 | Batch 700/2503 | Batch Loss: 0.000130
#   Epoch 22 | Batch 800/2503 | Batch Loss: 0.002440
#   Epoch 22 | Batch 900/2503 | Batch Loss: 0.000127
#   Epoch 22 | Batch 1000/2503 | Batch Loss: 0.000119
#   Epoch 22 | Batch 1100/2503 | Batch Loss: 0.000346
#   Epoch 22 | Batch 1200/2503 | Batch Loss: 0.000132
#   Epoch 22 | Batch 1300/2503 | Batch Loss: 0.000892
#   Epoch 22 | Batch 1400/2503 | Batch Loss: 0.000119
#   Epoch 22 | Batch 1500/2503 | Batch Loss: 0.000100
#   Epoch 22 | Batch 1600/2503 | Batch Loss: 0.000128
#   Epoch 22 | Batch 1700/2503 | Batch Loss: 0.000123
#   Epoch 22 | Batch 1800/2503 | Batch Loss: 0.000133
#   Epoch 22 | Batch 1900/2503 | Batch Loss: 0.000139
#   Epoch 22 | Batch 2000/2503 | Batch Loss: 0.000529
#   Epoch 22 | Batch 2100/2503 | Batch Loss: 0.000166
#   Epoch 22 | Batch 2200/2503 | Batch Loss: 0.000120
#   Epoch 22 | Batch 2300/2503 | Batch Loss: 0.000108
#   Epoch 22 | Batch 2400/2503 | Batch Loss: 0.000260
#   Epoch 22 | Batch 2500/2503 | Batch Loss: 0.000147
#
# Fine-tune Epoch 22/50 | Time: 146.9s
#   Train Loss: 0.000350 | Val MSE: 0.001032
# ------------------------------------------------------------
#   Epoch 23 | Batch 100/2503 | Batch Loss: 0.000117
#   Epoch 23 | Batch 200/2503 | Batch Loss: 0.000141
#   Epoch 23 | Batch 300/2503 | Batch Loss: 0.000129
#   Epoch 23 | Batch 400/2503 | Batch Loss: 0.000109
#   Epoch 23 | Batch 500/2503 | Batch Loss: 0.000124
#   Epoch 23 | Batch 600/2503 | Batch Loss: 0.000262
#   Epoch 23 | Batch 700/2503 | Batch Loss: 0.000189
#   Epoch 23 | Batch 800/2503 | Batch Loss: 0.000109
#   Epoch 23 | Batch 900/2503 | Batch Loss: 0.000116
#   Epoch 23 | Batch 1000/2503 | Batch Loss: 0.006016
#   Epoch 23 | Batch 1100/2503 | Batch Loss: 0.000124
#   Epoch 23 | Batch 1200/2503 | Batch Loss: 0.000139
#   Epoch 23 | Batch 1300/2503 | Batch Loss: 0.000092
#   Epoch 23 | Batch 1400/2503 | Batch Loss: 0.000101
#   Epoch 23 | Batch 1500/2503 | Batch Loss: 0.000118
#   Epoch 23 | Batch 1600/2503 | Batch Loss: 0.000138
#   Epoch 23 | Batch 1700/2503 | Batch Loss: 0.000135
#   Epoch 23 | Batch 1800/2503 | Batch Loss: 0.000130
#   Epoch 23 | Batch 1900/2503 | Batch Loss: 0.000115
#   Epoch 23 | Batch 2000/2503 | Batch Loss: 0.000095
#   Epoch 23 | Batch 2100/2503 | Batch Loss: 0.000109
#   Epoch 23 | Batch 2200/2503 | Batch Loss: 0.000144
#   Epoch 23 | Batch 2300/2503 | Batch Loss: 0.000104
#   Epoch 23 | Batch 2400/2503 | Batch Loss: 0.000140
#   Epoch 23 | Batch 2500/2503 | Batch Loss: 0.000131
#
# Fine-tune Epoch 23/50 | Time: 147.3s
#   Train Loss: 0.000340 | Val MSE: 0.000939
# ------------------------------------------------------------
#
# *** Early stopping triggered at epoch 23 ***
#
# ============================================================
# TRAINING COMPLETE!
# Best Validation MSE: 0.000637
# ============================================================
# Models saved: 'best_model.pth' and 'final_model.pth'
#
# ============================================================
# RUNNING FINAL TEST SET EVALUATION
# ============================================================
# Final Test MSE: 0.001935
#
# Saving loss history to 'loss_history.txt'...
# Generating loss curve plot 'loss_plot.png'...
# Execution Finished.
