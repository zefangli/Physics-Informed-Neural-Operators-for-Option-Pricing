# %%
"""
DeepONet Black-Scholes Solver
Optimized for high-dimensional branch data (u) and continuous trunk coordinates (M, tau)
"""

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
import h5py
import numpy as np
import time
import matplotlib.pyplot as plt  # <-- Added for plotting

# ==========================================
# NETWORK ARCHITECTURE (DeepONet)
# ==========================================

class PINN_MLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim, is_positive=True):
        super().__init__()
        layers = []
        
        layers.append(nn.Linear(input_dim, hidden_dim))
        layers.append(nn.LayerNorm(hidden_dim))
        layers.append(nn.Tanh())
        
        for _ in range(num_layers - 1):
            layers.append(nn.Linear(hidden_dim, hidden_dim))
            layers.append(nn.LayerNorm(hidden_dim))
            layers.append(nn.Tanh())
            
        layers.append(nn.Linear(hidden_dim, output_dim))
        
        if is_positive:
            layers.append(nn.Softplus())
            
        self.net = nn.Sequential(*layers)
        
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight)
                nn.init.zeros_(m.bias)
                
    def forward(self, x):
        return self.net(x)


class DeepONet(nn.Module):
    def __init__(self, u_dim, hidden_dim, num_layers, p_dim):
        super().__init__()
        # Branch network for the high-dimensional function input 'u'
        self.branch = PINN_MLP(
            input_dim=u_dim, 
            hidden_dim=hidden_dim, 
            num_layers=num_layers, 
            output_dim=p_dim, 
            is_positive=False 
        )
        
        # Trunk network for the continuous variables 'M' and 'tau'
        self.trunk = PINN_MLP(
            input_dim=2, 
            hidden_dim=hidden_dim, 
            num_layers=num_layers, 
            output_dim=p_dim, 
            is_positive=False
        )
        
        # Bias term for the final DeepONet output
        self.bias = nn.Parameter(torch.zeros(1))
        
        # Softplus to ensure the resulting volatility is strictly positive
        self.softplus = nn.Softplus()

    def forward(self, u, M, tau):
        branch_out = self.branch(u)
        
        trunk_input = torch.cat([M, tau], dim=1)
        trunk_out = self.trunk(trunk_input)
        
        # Compute the dot product across the basis dimension (p_dim)
        dot_product = torch.sum(branch_out * trunk_out, dim=1, keepdim=True)
        
        # Add bias and enforce positivity for volatility
        sigma = self.softplus(dot_product + self.bias)
        return sigma


class DeepBS_Solver(nn.Module):
    def __init__(self, u_dim=374, hidden_dim=128, num_layers=4, p_dim=128):
        super().__init__()
        
        # Network 1 is now a DeepONet predicting volatility
        self.nn1 = DeepONet(
            u_dim=u_dim, 
            hidden_dim=hidden_dim, 
            num_layers=num_layers, 
            p_dim=p_dim
        )
        
        # Network 2 remains a standard PINN_MLP predicting option price
        self.nn2 = PINN_MLP(
            input_dim=5, 
            hidden_dim=hidden_dim, 
            num_layers=num_layers, 
            output_dim=1, 
            is_positive=True
        )

    def forward(self, M, tau, u, r, q):
        # 1. Predict volatility (sigma) using the DeepONet
        sigma = self.nn1(u, M, tau)
        
        # 2. Predict option price (v_hat) using the MLP
        nn2_input = torch.cat([M, tau, r, q, sigma], dim=1)
        v_hat = self.nn2(nn2_input)
        
        return sigma, v_hat


# ==========================================
# LOSS FUNCTIONS
# ==========================================

def compute_derivatives(v_hat, M, tau):
    dv_dM = torch.autograd.grad(
        outputs=v_hat, inputs=M, 
        grad_outputs=torch.ones_like(v_hat),
        create_graph=True, retain_graph=True
    )[0]
    
    d2v_dM2 = torch.autograd.grad(
        outputs=dv_dM, inputs=M, 
        grad_outputs=torch.ones_like(dv_dM),
        create_graph=True, retain_graph=True
    )[0]
    
    dv_dtau = torch.autograd.grad(
        outputs=v_hat, inputs=tau, 
        grad_outputs=torch.ones_like(v_hat),
        create_graph=True, retain_graph=True
    )[0]
    
    return dv_dM, d2v_dM2, dv_dtau


def generate_boundary_points(batch_size, u, r, q, device, M_max=3.0, tau_max=5.32):
    indices = torch.randint(0, u.size(0), (batch_size,), device=device)

    # Terminal condition at tau = 0, M ∈ [0, M_max]
    M_term = torch.rand(batch_size, 1, device=device) * M_max
    tau_term = torch.zeros(batch_size, 1, device=device)

    # Lower boundary at M = 0, tau ∈ [0, tau_max]
    M_lower = torch.zeros(batch_size, 1, device=device)
    tau_lower = torch.rand(batch_size, 1, device=device) * tau_max

    # Upper boundary at M = M_max, tau ∈ [0, tau_max]
    M_upper = torch.full((batch_size, 1), M_max, device=device)
    tau_upper = torch.rand(batch_size, 1, device=device) * tau_max

    return {
        'terminal': (M_term, tau_term, u[indices], r[indices], q[indices]),
        'lower': (M_lower, tau_lower, u[indices], r[indices], q[indices]),
        'upper': (M_upper, tau_upper, u[indices], r[indices], q[indices]),
    }


def pinn_loss_fn(
    model, M, tau, u, r, q, v_true, mask, lambdas,
    device, num_boundary=256,
    M_max=3.0, tau_max=5.32
):
    sigma_hat, v_hat = model(M, tau, u, r, q)

    # ----------------
    # Data Loss
    # ----------------
    squared_errors = (v_hat - v_true) ** 2
    loss_data = torch.sum(squared_errors * mask) / (torch.sum(mask) + 1e-8)

    # ----------------
    # PDE Loss (tau is in YEARS; no scaling factor needed for time derivative)
    # ----------------
    dv_dM, d2v_dM2, dv_dtau = compute_derivatives(v_hat, M, tau)

    pde_residual = (
        -dv_dtau
        + 0.5 * (sigma_hat ** 2) * (M ** 2) * d2v_dM2
        + (r - q) * M * dv_dM
        - r * v_hat
    )
    loss_pde = torch.mean(pde_residual ** 2)

    # ----------------
    # Arbitrage Loss
    # ----------------
    loss_arb = torch.mean(F.relu(-dv_dM)) + torch.mean(F.relu(-d2v_dM2))

    # ----------------
    # Boundary Conditions (tau in YEARS)
    # ----------------
    boundaries = generate_boundary_points(
        num_boundary, u, r, q, device, M_max=M_max, tau_max=tau_max
    )

    # Terminal: v(M,0) = max(M-1,0)
    M_t, tau_t, u_t, r_t, q_t = boundaries['terminal']
    M_t.requires_grad_(True)
    tau_t.requires_grad_(True)
    _, v_term = model(M_t, tau_t, u_t, r_t, q_t)
    loss_term = F.mse_loss(v_term, F.relu(M_t - 1.0))

    # Lower: v(0,tau)=0
    M_l, tau_l, u_l, r_l, q_l = boundaries['lower']
    M_l.requires_grad_(True)
    tau_l.requires_grad_(True)
    _, v_lower = model(M_l, tau_l, u_l, r_l, q_l)
    loss_lower = F.mse_loss(v_lower, torch.zeros_like(v_lower))

    # Upper: v(M_max,tau) = M_max*e^{-q tau} - e^{-r tau} 
    M_u, tau_u, u_u, r_u, q_u = boundaries['upper']
    M_u.requires_grad_(True)
    tau_u.requires_grad_(True)
    _, v_upper = model(M_u, tau_u, u_u, r_u, q_u)
    v_upper_true = M_u * torch.exp(-q_u * tau_u) - torch.exp(-r_u * tau_u)
    loss_upper = F.mse_loss(v_upper, v_upper_true)

    # ----------------
    # Total
    # ----------------
    loss_total = (
        lambdas.get('data', 1.0) * loss_data +
        lambdas.get('pde', 0.1) * loss_pde +
        lambdas.get('arb', 0.1) * loss_arb +
        lambdas.get('term', 1.0) * loss_term +
        lambdas.get('lower', 1.0) * loss_lower +
        lambdas.get('upper', 1.0) * loss_upper
    )

    loss_dict = {
        'data': loss_data.item(),
        'pde': loss_pde.item(),
        'arb': loss_arb.item(),
        'term': loss_term.item(),
        'lower': loss_lower.item(),
        'upper': loss_upper.item(),
        'total': loss_total.item()
    }

    return loss_total, loss_dict


# ==========================================
# DATASET
# ==========================================

class ChronologicalOptionDataset(Dataset):
    def __init__(self, h5_path, split='train', load_to_memory=True):
        self.h5_path = h5_path
        self.load_to_memory = load_to_memory
        
        with h5py.File(h5_path, 'r') as f:
            total_rows = f['target_v'].shape[0]
            self.u_dim = f['branch_u'].shape[1]
            
            train_end = int(0.80 * total_rows)
            val_end = int(0.90 * total_rows)
            
            if split == 'train':
                self.start_idx, self.end_idx = 0, train_end
            elif split == 'val':
                self.start_idx, self.end_idx = train_end, val_end
            elif split == 'test':
                self.start_idx, self.end_idx = val_end, total_rows
            else:
                raise ValueError("Split must be 'train', 'val', or 'test'.")
            
            self.length = self.end_idx - self.start_idx
            
            if load_to_memory:
                self.branch_u = f['branch_u'][self.start_idx:self.end_idx]
                self.trunk_y = f['trunk_y'][self.start_idx:self.end_idx]
                self.target_v = f['target_v_normalized'][self.start_idx:self.end_idx]
                
        print(f"Loaded {split}: {self.length} samples")

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        return (
            torch.tensor(self.branch_u[idx], dtype=torch.float32),
            torch.tensor(self.trunk_y[idx], dtype=torch.float32),
            torch.tensor(self.target_v[idx], dtype=torch.float32)
        )
    
    def get_u_dim(self):
        return self.u_dim


# ==========================================
# COLLATE FUNCTION (DeepONet Optimized)
# ==========================================

def create_pinn_collate_fn(colloc_ratio=0.2, M_max=3.0, tau_max=5.32, points_per_u=10):
    """
    Pairs a smaller set of unique functional inputs (u) with multiple continuous 
    evaluation coordinates (M, tau) to learn the operator mapping efficiently.
    """
    def collate_fn(batch):
        u_true = torch.stack([item[0] for item in batch])
        y_true = torch.stack([item[1] for item in batch])
        v_true = torch.stack([item[2] for item in batch])

        if v_true.dim() == 1:
            v_true = v_true.unsqueeze(1)

        M_true = y_true[:, 0:1]
        tau_true = y_true[:, 1:2]
        r_true = y_true[:, 2:3]
        q_true = y_true[:, 3:4]

        num_true = len(batch)

        if colloc_ratio > 0.0:
            target_num_colloc = max(1, int(num_true * (colloc_ratio / (1.0 - colloc_ratio))))
            
            # Determine how many unique market states (u) we should sample
            num_unique_u = max(1, target_num_colloc // points_per_u)
            actual_num_colloc = num_unique_u * points_per_u

            # 1. Randomly select a subset of unique 'u' states
            idx = torch.randint(0, num_true, (num_unique_u,))
            u_base = u_true[idx]
            r_base = r_true[idx]
            q_base = q_true[idx]
            
            # 2. Duplicate each selected 'u' (and r, q) 'points_per_u' times
            u_colloc = u_base.repeat_interleave(points_per_u, dim=0)
            r_colloc = r_base.repeat_interleave(points_per_u, dim=0)
            q_colloc = q_base.repeat_interleave(points_per_u, dim=0)
            
            # 3. Generate independent random (M, tau) coordinates for the duplicated states
            M_colloc = torch.rand(actual_num_colloc, 1) * M_max
            tau_colloc = torch.rand(actual_num_colloc, 1) * tau_max
            v_colloc = torch.zeros(actual_num_colloc, 1)

            M_final = torch.cat([M_true, M_colloc])
            tau_final = torch.cat([tau_true, tau_colloc])
            u_final = torch.cat([u_true, u_colloc])
            r_final = torch.cat([r_true, r_colloc])
            q_final = torch.cat([q_true, q_colloc])
            v_final = torch.cat([v_true, v_colloc])
            mask = torch.cat([torch.ones(num_true, 1), torch.zeros(actual_num_colloc, 1)])
            
        else:
            M_final, tau_final, u_final = M_true, tau_true, u_true
            r_final, q_final, v_final = r_true, q_true, v_true
            mask = torch.ones(num_true, 1)

        return M_final, tau_final, u_final, r_final, q_final, v_final, mask

    return collate_fn

# ==========================================
# TRAINING
# ==========================================

def train_model():
    seed = 42
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) 
    np.random.seed(seed)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Device: {device}")
    
    config = {
        'epochs_adam': 100,      
        'epochs_lbfgs': 50, # Fine-tuning with low-LR Adam
        'batch_size': 256, #changed
        'lr': 1e-3,
        'hidden_dim': 64,
        'num_layers': 4,
        'p_dim': 64,             # Basis dimension for DeepONet projection
        'colloc_ratio': 0.2, 
        'points_per_u': 20,      #changed # Number of coordinate points per branch input
        'num_boundary': 128, 
        'grad_clip': 1.0,
        'M_max': 3.0,
        'tau_max': 5.32,
        'patience_adam': 3,     #changed
        'patience_lbfgs': 3,    #changed
    }
    
    #changed
    lambdas = {'data': 1.0, 'pde': 0.5, 'arb': 0.5, 'term': 0.5, 'lower': 0.5, 'upper': 0.5}
    
    print("Loading datasets...")
    train_ds = ChronologicalOptionDataset('../../wrds_data/deeponet_tensors.h5', 'train')
    val_ds = ChronologicalOptionDataset('../../wrds_data/deeponet_tensors.h5', 'val')
    test_ds = ChronologicalOptionDataset('../../wrds_data/deeponet_tensors.h5', 'test') # Added Test Set
    print(f"Train samples: {len(train_ds)}, Val samples: {len(val_ds)}, Test samples: {len(test_ds)}")
    
    train_loader = DataLoader(
        train_ds,
        config['batch_size'],
        shuffle=True,
        collate_fn=create_pinn_collate_fn(
            colloc_ratio=config['colloc_ratio'],
            M_max=config['M_max'],
            tau_max=config['tau_max'],
            points_per_u=config['points_per_u']
        )
    )
    
    val_loader = DataLoader(
        val_ds,
        config['batch_size'] * 2,
        shuffle=False,
        collate_fn=create_pinn_collate_fn(
            colloc_ratio=0.0,
            M_max=config['M_max'],
            tau_max=config['tau_max']
        )
    )

    test_loader = DataLoader(
        test_ds, config['batch_size'] * 2, shuffle=False,
        collate_fn=create_pinn_collate_fn(colloc_ratio=0.0, M_max=config['M_max'], tau_max=config['tau_max'])
    )
    
    print(f"Train batches: {len(train_loader)}, Val batches: {len(val_loader)}")
    
    # Model
    model = DeepBS_Solver(train_ds.get_u_dim(), config['hidden_dim'], config['num_layers'], config['p_dim']).to(device)
    print(f"Model initialized with u_dim={train_ds.get_u_dim()}, hidden_dim={config['hidden_dim']}, num_layers={config['num_layers']}, p_dim={config['p_dim']}")
    
    # ==========================================
    # OPTIMIZER SETTINGS (DeepONet Groups)
    # ==========================================
    base_lr = config['lr']
    
    # Grouped parameters to pace the fast-learning trunk and regularize the branch
    optimizer_adam = optim.Adam([
        {'params': model.nn1.branch.parameters(), 'lr': base_lr, 'weight_decay': 1e-4},
        {'params': model.nn1.trunk.parameters(), 'lr': base_lr * 0.1, 'weight_decay': 0.0},
        {'params': [model.nn1.bias], 'lr': base_lr},
        {'params': model.nn2.parameters(), 'lr': base_lr, 'weight_decay': 1e-5}
    ])

    #changed
    scheduler = ReduceLROnPlateau(optimizer_adam, 'min', factor=0.5, patience=2)
    
    best_val = float('inf')
    
    # --- Lists to track loss history for plotting ---
    all_train_losses = []
    all_val_losses = []
    
    def evaluate_validation():
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch in val_loader:
                M, tau, u, r, q, v_true, _ = [b.to(device) for b in batch]
                _, v_hat = model(M, tau, u, r, q)
                val_loss += F.mse_loss(v_hat, v_true).item() * M.size(0)
        val_loss /= len(val_ds)
        model.train()
        return val_loss
    
    # ==========================================
    # STAGE 1: ADAM TRAINING
    # ==========================================
    print("\n" + "="*60)
    print("PHASE 1: Adam Optimizer (DeepONet Parameter Groups)")
    print("="*60)
    
    epochs_no_improve = 0
    phase1_epochs_completed = 0
    
    for epoch in range(config['epochs_adam']):
        model.train()
        epoch_start = time.time()
        total_loss = 0
        loss_components = {'data': 0, 'pde': 0, 'arb': 0, 'term': 0, 'lower': 0, 'upper': 0}
        
        for batch_idx, batch in enumerate(train_loader):
            M, tau, u, r, q, v_true, mask = [b.to(device) for b in batch]
            M = M.clone().requires_grad_(True)
            tau = tau.clone().requires_grad_(True)
            
            optimizer_adam.zero_grad()
            loss, loss_dict = pinn_loss_fn(
                model, M, tau, u, r, q, v_true, mask,
                lambdas, device,
                num_boundary=config['num_boundary'],
                M_max=config['M_max'],
                tau_max=config['tau_max'],
            )
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), config['grad_clip'])
            optimizer_adam.step()
            
            total_loss += loss_dict['total']
            for key in loss_components:
                loss_components[key] += loss_dict[key]
            
            if (batch_idx + 1) % 100 == 0:
                print(f"  Epoch {epoch+1} | Batch {batch_idx+1}/{len(train_loader)} | Batch Loss: {loss_dict['total']:.6f}")
        
        val_loss = evaluate_validation()
        scheduler.step(val_loss)
        current_lr = optimizer_adam.param_groups[0]['lr'] # Refers to branch LR
        
        epoch_time = time.time() - epoch_start
        avg_loss = total_loss / len(train_loader)
        
        # Save epoch history
        all_train_losses.append(avg_loss)
        all_val_losses.append(val_loss)
        phase1_epochs_completed += 1
        
        for key in loss_components:
            loss_components[key] /= len(train_loader)
        
        improved = ""
        if val_loss < best_val:
            best_val = val_loss
            torch.save(model.state_dict(), f'best_model_phase1.pth')
            improved = " *** New Best ***"
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
        
        print(f"\nAdam Epoch {epoch+1}/{config['epochs_adam']} | Time: {epoch_time:.1f}s | Base LR: {current_lr:.2e}")
        print(f"  Train Loss: {avg_loss:.6f} | Val MSE: {val_loss:.6f}{improved}")
        print(f"  Components - Data: {loss_components['data']:.4f} | PDE: {loss_components['pde']:.4f} | Arb: {loss_components['arb']:.4f}")
        print(f"  Epochs without improvement: {epochs_no_improve}/{config['patience_adam']}")
        print("-" * 60)
        
        if epochs_no_improve >= config['patience_adam']:
            print(f"\n*** Early stopping triggered at epoch {epoch+1} ***")
            break
            
        torch.cuda.empty_cache()
    
    print(f"\n*** Adam Phase Complete. Best Val MSE: {best_val:.6f} ***")
    
    print("Loading best model from Adam phase for fine-tuning...")
    model.load_state_dict(torch.load('best_model_phase1.pth'))
    
    #changed
    torch.save(model.state_dict(), f'best_model.pth')

    # ==========================================
    # STAGE 2: FINE-TUNING WITH LOW LR ADAM
    # ==========================================
    print("\n" + "="*60)
    print("PHASE 2: Fine-tuning with Adam (Low LR, DeepONet Groups)")
    print("="*60)

    # best_val = 0.000815
    finetune_lr = 1e-5
    optimizer_finetune = optim.Adam([
        {'params': model.nn1.branch.parameters(), 'lr': finetune_lr, 'weight_decay': 1e-5},
        {'params': model.nn1.trunk.parameters(), 'lr': finetune_lr * 0.1, 'weight_decay': 0.0},
        {'params': [model.nn1.bias], 'lr': finetune_lr},
        {'params': model.nn2.parameters(), 'lr': finetune_lr, 'weight_decay': 1e-6}
    ])
    
    epochs_no_improve = 0

    for epoch in range(config['epochs_lbfgs']): 
        model.train()
        epoch_start = time.time()
        total_loss = 0
        loss_components = {'data': 0, 'pde': 0, 'arb': 0, 'term': 0, 'lower': 0, 'upper': 0}
        
        for batch_idx, batch in enumerate(train_loader):
            M, tau, u, r, q, v_true, mask = [b.to(device) for b in batch]
            M = M.clone().requires_grad_(True)
            tau = tau.clone().requires_grad_(True)
            
            optimizer_finetune.zero_grad()
            loss, loss_dict = pinn_loss_fn(
                model, M, tau, u, r, q, v_true, mask,
                lambdas, device,
                num_boundary=config['num_boundary'],
                M_max=config['M_max'],
                tau_max=config['tau_max'],
            )
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), config['grad_clip'])
            optimizer_finetune.step()
            
            total_loss += loss_dict['total']
            for key in loss_components:
                loss_components[key] += loss_dict[key]
            
            if (batch_idx + 1) % 100 == 0:
                print(f"  Epoch {epoch+1} | Batch {batch_idx+1}/{len(train_loader)} | Batch Loss: {loss_dict['total']:.6f}")
        
        val_loss = evaluate_validation()
        epoch_time = time.time() - epoch_start
        avg_loss = total_loss / len(train_loader)
        
        # Save epoch history
        all_train_losses.append(avg_loss)
        all_val_losses.append(val_loss)
        
        for key in loss_components:
            loss_components[key] /= len(train_loader)
        
        improved = ""
        if val_loss < best_val:
            best_val = val_loss
            torch.save(model.state_dict(), 'best_model.pth')
            improved = " *** New Best ***"
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
        
        print(f"\nFine-tune Epoch {epoch+1}/{config['epochs_lbfgs']} | Time: {epoch_time:.1f}s")
        print(f"  Train Loss: {avg_loss:.6f} | Val MSE: {val_loss:.6f}{improved}")
        print("-" * 60)
        
        torch.cuda.empty_cache()
        
        # we allow it to run for at least 10 epochs to give the fine-tuning a chance to improve, then we check for early stopping
        if epoch >= 10 and epochs_no_improve >= config['patience_lbfgs']:
            print(f"\n*** Early stopping triggered at epoch {epoch+1} ***")
            break

    print("\n" + "="*60)
    print("TRAINING COMPLETE!")
    print(f"Best Validation MSE: {best_val:.6f}")
    print("="*60)
    
    torch.save(model.state_dict(), 'final_model.pth')
    print("Models saved: 'best_model.pth' and 'final_model.pth'")
    

    # ==========================================
    # FINAL TEST EVALUATION
    # ==========================================
    print("\n" + "="*60)
    print("RUNNING FINAL TEST SET EVALUATION")
    print("="*60)
    
    # Load the best overall model weights
    model.load_state_dict(torch.load('best_model.pth'))
    model.eval()
    test_loss = 0
    
    with torch.no_grad():
        for batch in test_loader:
            M, tau, u, r, q, v_true, _ = [b.to(device) for b in batch]
            _, v_hat = model(M, tau, u, r, q)
            test_loss += F.mse_loss(v_hat, v_true).item() * M.size(0)
            
    test_loss /= len(test_ds)
    print(f"Final Test MSE: {test_loss:.6f}")
    
    # ==========================================
    # EXPORTING LOGS & PLOTTING
    # ==========================================
    print("\nSaving loss history to 'loss_history.txt'...")
    with open('loss_history.txt', 'w') as f:
        f.write("Epoch\tTrain_Loss\tVal_Loss\n")
        for i, (t_loss, v_loss) in enumerate(zip(all_train_losses, all_val_losses)):
            f.write(f"{i+1}\t{t_loss:.6f}\t{v_loss:.6f}\n")
        f.write(f"\nFinal Test Loss: {test_loss:.6f}\n")

    print("Generating loss curve plot 'loss_plot.png'...")
    plt.figure(figsize=(10, 6))
    plt.plot(all_train_losses, label='Train Loss (Total PINN Loss)')
    plt.plot(all_val_losses, label='Validation Loss (MSE)')
    
    # Indicate where Phase 2 started
    if phase1_epochs_completed < len(all_train_losses):
        plt.axvline(x=phase1_epochs_completed - 1, color='r', linestyle='--', label='Start Phase 2 (Fine-tuning)')
        
    plt.yscale('log')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Training & Validation Loss (Test MSE: {test_loss:.6f})')
    plt.legend()
    plt.grid(True, which="both", ls="--", alpha=0.5)
    plt.tight_layout()
    plt.savefig('loss_plot.png')
    plt.close()
    
    print("Execution Finished.")
    
    return model

if __name__ == "__main__":
    train_model()
# Out:
# Device: cuda
# Loading datasets...
# Loaded train: 640582 samples
# Loaded val: 80073 samples
# Loaded test: 80073 samples
# Train samples: 640582, Val samples: 80073, Test samples: 80073
# Train batches: 2503, Val batches: 157
# Model initialized with u_dim=374, hidden_dim=64, num_layers=4, p_dim=64
#
# ============================================================
# PHASE 1: Adam Optimizer (DeepONet Parameter Groups)
# ============================================================
#   Epoch 1 | Batch 100/2503 | Batch Loss: 0.054012
#   Epoch 1 | Batch 200/2503 | Batch Loss: 0.011747
#   Epoch 1 | Batch 300/2503 | Batch Loss: 0.053067
#   Epoch 1 | Batch 400/2503 | Batch Loss: 0.048326
#   Epoch 1 | Batch 500/2503 | Batch Loss: 0.011684
#   Epoch 1 | Batch 600/2503 | Batch Loss: 0.835999
#   Epoch 1 | Batch 700/2503 | Batch Loss: 0.006030
#   Epoch 1 | Batch 800/2503 | Batch Loss: 0.022473
#   Epoch 1 | Batch 900/2503 | Batch Loss: 0.025916
#   Epoch 1 | Batch 1000/2503 | Batch Loss: 0.521001
#   Epoch 1 | Batch 1100/2503 | Batch Loss: 0.039587
#   Epoch 1 | Batch 1200/2503 | Batch Loss: 0.006726
#   Epoch 1 | Batch 1300/2503 | Batch Loss: 0.347778
#   Epoch 1 | Batch 1400/2503 | Batch Loss: 0.520287
#   Epoch 1 | Batch 1500/2503 | Batch Loss: 0.466593
#   Epoch 1 | Batch 1600/2503 | Batch Loss: 0.002349
#   Epoch 1 | Batch 1700/2503 | Batch Loss: 0.003301
#   Epoch 1 | Batch 1800/2503 | Batch Loss: 0.002088
#   Epoch 1 | Batch 1900/2503 | Batch Loss: 0.037794
#   Epoch 1 | Batch 2000/2503 | Batch Loss: 0.073650
#   Epoch 1 | Batch 2100/2503 | Batch Loss: 0.003130
#   Epoch 1 | Batch 2200/2503 | Batch Loss: 0.007460
#   Epoch 1 | Batch 2300/2503 | Batch Loss: 0.001529
#   Epoch 1 | Batch 2400/2503 | Batch Loss: 0.024038
#   Epoch 1 | Batch 2500/2503 | Batch Loss: 0.015282
#
# Adam Epoch 1/100 | Time: 156.6s | Base LR: 1.00e-03
#   Train Loss: 0.146520 | Val MSE: 0.010837 *** New Best ***
#   Components - Data: 0.1211 | PDE: 0.0026 | Arb: 0.0050
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 2 | Batch 100/2503 | Batch Loss: 0.001209
#   Epoch 2 | Batch 200/2503 | Batch Loss: 0.004186
#   Epoch 2 | Batch 300/2503 | Batch Loss: 0.001638
#   Epoch 2 | Batch 400/2503 | Batch Loss: 0.005369
#   Epoch 2 | Batch 500/2503 | Batch Loss: 0.002044
#   Epoch 2 | Batch 600/2503 | Batch Loss: 0.004811
#   Epoch 2 | Batch 700/2503 | Batch Loss: 0.004884
#   Epoch 2 | Batch 800/2503 | Batch Loss: 0.044183
#   Epoch 2 | Batch 900/2503 | Batch Loss: 0.002768
#   Epoch 2 | Batch 1000/2503 | Batch Loss: 0.005223
#   Epoch 2 | Batch 1100/2503 | Batch Loss: 0.001450
#   Epoch 2 | Batch 1200/2503 | Batch Loss: 0.002464
#   Epoch 2 | Batch 1300/2503 | Batch Loss: 0.000770
#   Epoch 2 | Batch 1400/2503 | Batch Loss: 0.001069
#   Epoch 2 | Batch 1500/2503 | Batch Loss: 0.000971
#   Epoch 2 | Batch 1600/2503 | Batch Loss: 0.008057
#   Epoch 2 | Batch 1700/2503 | Batch Loss: 0.001895
#   Epoch 2 | Batch 1800/2503 | Batch Loss: 0.029677
#   Epoch 2 | Batch 1900/2503 | Batch Loss: 0.000828
#   Epoch 2 | Batch 2000/2503 | Batch Loss: 0.005926
#   Epoch 2 | Batch 2100/2503 | Batch Loss: 0.037064
#   Epoch 2 | Batch 2200/2503 | Batch Loss: 0.001136
#   Epoch 2 | Batch 2300/2503 | Batch Loss: 0.001940
#   Epoch 2 | Batch 2400/2503 | Batch Loss: 0.003486
#   Epoch 2 | Batch 2500/2503 | Batch Loss: 0.000712
#
# Adam Epoch 2/100 | Time: 156.2s | Base LR: 1.00e-03
#   Train Loss: 0.010225 | Val MSE: 0.006182 *** New Best ***
#   Components - Data: 0.0069 | PDE: 0.0009 | Arb: 0.0004
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 3 | Batch 100/2503 | Batch Loss: 0.000981
#   Epoch 3 | Batch 200/2503 | Batch Loss: 0.000670
#   Epoch 3 | Batch 300/2503 | Batch Loss: 0.000684
#   Epoch 3 | Batch 400/2503 | Batch Loss: 0.002694
#   Epoch 3 | Batch 500/2503 | Batch Loss: 0.003308
#   Epoch 3 | Batch 600/2503 | Batch Loss: 0.001194
#   Epoch 3 | Batch 700/2503 | Batch Loss: 0.001947
#   Epoch 3 | Batch 800/2503 | Batch Loss: 0.000807
#   Epoch 3 | Batch 900/2503 | Batch Loss: 0.001565
#   Epoch 3 | Batch 1000/2503 | Batch Loss: 0.000669
#   Epoch 3 | Batch 1100/2503 | Batch Loss: 0.000548
#   Epoch 3 | Batch 1200/2503 | Batch Loss: 0.000822
#   Epoch 3 | Batch 1300/2503 | Batch Loss: 0.001528
#   Epoch 3 | Batch 1400/2503 | Batch Loss: 0.000827
#   Epoch 3 | Batch 1500/2503 | Batch Loss: 0.001027
#   Epoch 3 | Batch 1600/2503 | Batch Loss: 0.000845
#   Epoch 3 | Batch 1700/2503 | Batch Loss: 0.001756
#   Epoch 3 | Batch 1800/2503 | Batch Loss: 0.000715
#   Epoch 3 | Batch 1900/2503 | Batch Loss: 0.006362
#   Epoch 3 | Batch 2000/2503 | Batch Loss: 0.000915
#   Epoch 3 | Batch 2100/2503 | Batch Loss: 0.018499
#   Epoch 3 | Batch 2200/2503 | Batch Loss: 0.000502
#   Epoch 3 | Batch 2300/2503 | Batch Loss: 0.001508
#   Epoch 3 | Batch 2400/2503 | Batch Loss: 0.000925
#   Epoch 3 | Batch 2500/2503 | Batch Loss: 0.000777
#
# Adam Epoch 3/100 | Time: 155.6s | Base LR: 1.00e-03
#   Train Loss: 0.007843 | Val MSE: 0.001941 *** New Best ***
#   Components - Data: 0.0061 | PDE: 0.0009 | Arb: 0.0003
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 4 | Batch 100/2503 | Batch Loss: 0.009644
#   Epoch 4 | Batch 200/2503 | Batch Loss: 0.003454
#   Epoch 4 | Batch 300/2503 | Batch Loss: 0.001234
#   Epoch 4 | Batch 400/2503 | Batch Loss: 0.000496
#   Epoch 4 | Batch 500/2503 | Batch Loss: 0.000914
#   Epoch 4 | Batch 600/2503 | Batch Loss: 0.018139
#   Epoch 4 | Batch 700/2503 | Batch Loss: 0.000987
#   Epoch 4 | Batch 800/2503 | Batch Loss: 0.001031
#   Epoch 4 | Batch 900/2503 | Batch Loss: 0.004080
#   Epoch 4 | Batch 1000/2503 | Batch Loss: 0.000717
#   Epoch 4 | Batch 1100/2503 | Batch Loss: 0.007692
#   Epoch 4 | Batch 1200/2503 | Batch Loss: 0.002056
#   Epoch 4 | Batch 1300/2503 | Batch Loss: 0.000640
#   Epoch 4 | Batch 1400/2503 | Batch Loss: 0.007543
#   Epoch 4 | Batch 1500/2503 | Batch Loss: 0.001181
#   Epoch 4 | Batch 1600/2503 | Batch Loss: 0.010830
#   Epoch 4 | Batch 1700/2503 | Batch Loss: 0.001064
#   Epoch 4 | Batch 1800/2503 | Batch Loss: 0.020390
#   Epoch 4 | Batch 1900/2503 | Batch Loss: 0.003724
#   Epoch 4 | Batch 2000/2503 | Batch Loss: 0.000471
#   Epoch 4 | Batch 2100/2503 | Batch Loss: 0.001488
#   Epoch 4 | Batch 2200/2503 | Batch Loss: 0.000568
#   Epoch 4 | Batch 2300/2503 | Batch Loss: 0.001845
#   Epoch 4 | Batch 2400/2503 | Batch Loss: 0.000996
#   Epoch 4 | Batch 2500/2503 | Batch Loss: 0.000494
#
# Adam Epoch 4/100 | Time: 156.2s | Base LR: 1.00e-03
#   Train Loss: 0.006624 | Val MSE: 0.002167
#   Components - Data: 0.0049 | PDE: 0.0009 | Arb: 0.0003
#   Epochs without improvement: 1/3
# ------------------------------------------------------------
#   Epoch 5 | Batch 100/2503 | Batch Loss: 0.015520
#   Epoch 5 | Batch 200/2503 | Batch Loss: 0.000544
#   Epoch 5 | Batch 300/2503 | Batch Loss: 0.000462
#   Epoch 5 | Batch 400/2503 | Batch Loss: 0.000940
#   Epoch 5 | Batch 500/2503 | Batch Loss: 0.001559
#   Epoch 5 | Batch 600/2503 | Batch Loss: 0.000585
#   Epoch 5 | Batch 700/2503 | Batch Loss: 0.000561
#   Epoch 5 | Batch 800/2503 | Batch Loss: 0.000437
#   Epoch 5 | Batch 900/2503 | Batch Loss: 0.002094
#   Epoch 5 | Batch 1000/2503 | Batch Loss: 0.000484
#   Epoch 5 | Batch 1100/2503 | Batch Loss: 0.085795
#   Epoch 5 | Batch 1200/2503 | Batch Loss: 0.001127
#   Epoch 5 | Batch 1300/2503 | Batch Loss: 0.000811
#   Epoch 5 | Batch 1400/2503 | Batch Loss: 0.001223
#   Epoch 5 | Batch 1500/2503 | Batch Loss: 0.001511
#   Epoch 5 | Batch 1600/2503 | Batch Loss: 0.000347
#   Epoch 5 | Batch 1700/2503 | Batch Loss: 0.000452
#   Epoch 5 | Batch 1800/2503 | Batch Loss: 0.001309
#   Epoch 5 | Batch 1900/2503 | Batch Loss: 0.008507
#   Epoch 5 | Batch 2000/2503 | Batch Loss: 0.000845
#   Epoch 5 | Batch 2100/2503 | Batch Loss: 0.000559
#   Epoch 5 | Batch 2200/2503 | Batch Loss: 0.001341
#   Epoch 5 | Batch 2300/2503 | Batch Loss: 0.000289
#   Epoch 5 | Batch 2400/2503 | Batch Loss: 0.001213
#   Epoch 5 | Batch 2500/2503 | Batch Loss: 0.001697
#
# Adam Epoch 5/100 | Time: 155.9s | Base LR: 1.00e-03
#   Train Loss: 0.004891 | Val MSE: 0.003951
#   Components - Data: 0.0034 | PDE: 0.0008 | Arb: 0.0002
#   Epochs without improvement: 2/3
# ------------------------------------------------------------
#   Epoch 6 | Batch 100/2503 | Batch Loss: 0.000673
#   Epoch 6 | Batch 200/2503 | Batch Loss: 0.002372
#   Epoch 6 | Batch 300/2503 | Batch Loss: 0.000904
#   Epoch 6 | Batch 400/2503 | Batch Loss: 0.001594
#   Epoch 6 | Batch 500/2503 | Batch Loss: 0.010677
#   Epoch 6 | Batch 600/2503 | Batch Loss: 0.000313
#   Epoch 6 | Batch 700/2503 | Batch Loss: 0.000407
#   Epoch 6 | Batch 800/2503 | Batch Loss: 0.000402
#   Epoch 6 | Batch 900/2503 | Batch Loss: 0.000688
#   Epoch 6 | Batch 1000/2503 | Batch Loss: 0.000383
#   Epoch 6 | Batch 1100/2503 | Batch Loss: 0.000578
#   Epoch 6 | Batch 1200/2503 | Batch Loss: 0.000579
#   Epoch 6 | Batch 1300/2503 | Batch Loss: 0.000307
#   Epoch 6 | Batch 1400/2503 | Batch Loss: 0.000325
#   Epoch 6 | Batch 1500/2503 | Batch Loss: 0.001585
#   Epoch 6 | Batch 1600/2503 | Batch Loss: 0.000482
#   Epoch 6 | Batch 1700/2503 | Batch Loss: 0.000345
#   Epoch 6 | Batch 1800/2503 | Batch Loss: 0.000688
#   Epoch 6 | Batch 1900/2503 | Batch Loss: 0.000882
#   Epoch 6 | Batch 2000/2503 | Batch Loss: 0.000361
#   Epoch 6 | Batch 2100/2503 | Batch Loss: 0.000509
#   Epoch 6 | Batch 2200/2503 | Batch Loss: 0.000458
#   Epoch 6 | Batch 2300/2503 | Batch Loss: 0.004450
#   Epoch 6 | Batch 2400/2503 | Batch Loss: 0.000620
#   Epoch 6 | Batch 2500/2503 | Batch Loss: 0.000408
#
# Adam Epoch 6/100 | Time: 155.8s | Base LR: 5.00e-04
#   Train Loss: 0.004280 | Val MSE: 0.007812
#   Components - Data: 0.0032 | PDE: 0.0007 | Arb: 0.0002
#   Epochs without improvement: 3/3
# ------------------------------------------------------------
#
# *** Early stopping triggered at epoch 6 ***
#
# *** Adam Phase Complete. Best Val MSE: 0.001941 ***
# Loading best model from Adam phase for fine-tuning...
#
# ============================================================
# PHASE 2: Fine-tuning with Adam (Low LR, DeepONet Groups)
# ============================================================
#   Epoch 1 | Batch 100/2503 | Batch Loss: 0.003976
#   Epoch 1 | Batch 200/2503 | Batch Loss: 0.002570
#   Epoch 1 | Batch 300/2503 | Batch Loss: 0.000437
#   Epoch 1 | Batch 400/2503 | Batch Loss: 0.001162
#   Epoch 1 | Batch 500/2503 | Batch Loss: 0.005307
#   Epoch 1 | Batch 600/2503 | Batch Loss: 0.000474
#   Epoch 1 | Batch 700/2503 | Batch Loss: 0.000514
#   Epoch 1 | Batch 800/2503 | Batch Loss: 0.000472
#   Epoch 1 | Batch 900/2503 | Batch Loss: 0.000740
#   Epoch 1 | Batch 1000/2503 | Batch Loss: 0.000324
#   Epoch 1 | Batch 1100/2503 | Batch Loss: 0.000325
#   Epoch 1 | Batch 1200/2503 | Batch Loss: 0.003281
#   Epoch 1 | Batch 1300/2503 | Batch Loss: 0.000294
#   Epoch 1 | Batch 1400/2503 | Batch Loss: 0.000337
#   Epoch 1 | Batch 1500/2503 | Batch Loss: 0.000332
#   Epoch 1 | Batch 1600/2503 | Batch Loss: 0.000397
#   Epoch 1 | Batch 1700/2503 | Batch Loss: 0.001447
#   Epoch 1 | Batch 1800/2503 | Batch Loss: 0.000298
#   Epoch 1 | Batch 1900/2503 | Batch Loss: 0.000381
#   Epoch 1 | Batch 2000/2503 | Batch Loss: 0.000473
#   Epoch 1 | Batch 2100/2503 | Batch Loss: 0.000311
#   Epoch 1 | Batch 2200/2503 | Batch Loss: 0.000311
#   Epoch 1 | Batch 2300/2503 | Batch Loss: 0.000500
#   Epoch 1 | Batch 2400/2503 | Batch Loss: 0.000450
#   Epoch 1 | Batch 2500/2503 | Batch Loss: 0.000428
#
# Fine-tune Epoch 1/50 | Time: 155.4s
#   Train Loss: 0.001619 | Val MSE: 0.001883 *** New Best ***
# ------------------------------------------------------------
#   Epoch 2 | Batch 100/2503 | Batch Loss: 0.002193
#   Epoch 2 | Batch 200/2503 | Batch Loss: 0.004162
#   Epoch 2 | Batch 300/2503 | Batch Loss: 0.000280
#   Epoch 2 | Batch 400/2503 | Batch Loss: 0.000491
#   Epoch 2 | Batch 500/2503 | Batch Loss: 0.000295
#   Epoch 2 | Batch 600/2503 | Batch Loss: 0.000481
#   Epoch 2 | Batch 700/2503 | Batch Loss: 0.000429
#   Epoch 2 | Batch 800/2503 | Batch Loss: 0.000362
#   Epoch 2 | Batch 900/2503 | Batch Loss: 0.000394
#   Epoch 2 | Batch 1000/2503 | Batch Loss: 0.000274
#   Epoch 2 | Batch 1100/2503 | Batch Loss: 0.000409
#   Epoch 2 | Batch 1200/2503 | Batch Loss: 0.000444
#   Epoch 2 | Batch 1300/2503 | Batch Loss: 0.000370
#   Epoch 2 | Batch 1400/2503 | Batch Loss: 0.000312
#   Epoch 2 | Batch 1500/2503 | Batch Loss: 0.021788
#   Epoch 2 | Batch 1600/2503 | Batch Loss: 0.000517
#   Epoch 2 | Batch 1700/2503 | Batch Loss: 0.000352
#   Epoch 2 | Batch 1800/2503 | Batch Loss: 0.000426
#   Epoch 2 | Batch 1900/2503 | Batch Loss: 0.000364
#   Epoch 2 | Batch 2000/2503 | Batch Loss: 0.000313
#   Epoch 2 | Batch 2100/2503 | Batch Loss: 0.002949
#   Epoch 2 | Batch 2200/2503 | Batch Loss: 0.000250
#   Epoch 2 | Batch 2300/2503 | Batch Loss: 0.000293
#   Epoch 2 | Batch 2400/2503 | Batch Loss: 0.000327
#   Epoch 2 | Batch 2500/2503 | Batch Loss: 0.000351
#
# Fine-tune Epoch 2/50 | Time: 155.7s
#   Train Loss: 0.001314 | Val MSE: 0.001421 *** New Best ***
# ------------------------------------------------------------
#   Epoch 3 | Batch 100/2503 | Batch Loss: 0.000249
#   Epoch 3 | Batch 200/2503 | Batch Loss: 0.000786
#   Epoch 3 | Batch 300/2503 | Batch Loss: 0.001288
#   Epoch 3 | Batch 400/2503 | Batch Loss: 0.000255
#   Epoch 3 | Batch 500/2503 | Batch Loss: 0.000411
#   Epoch 3 | Batch 600/2503 | Batch Loss: 0.000478
#   Epoch 3 | Batch 700/2503 | Batch Loss: 0.000614
#   Epoch 3 | Batch 800/2503 | Batch Loss: 0.000306
#   Epoch 3 | Batch 900/2503 | Batch Loss: 0.004652
#   Epoch 3 | Batch 1000/2503 | Batch Loss: 0.001340
#   Epoch 3 | Batch 1100/2503 | Batch Loss: 0.006382
#   Epoch 3 | Batch 1200/2503 | Batch Loss: 0.000320
#   Epoch 3 | Batch 1300/2503 | Batch Loss: 0.000461
#   Epoch 3 | Batch 1400/2503 | Batch Loss: 0.000451
#   Epoch 3 | Batch 1500/2503 | Batch Loss: 0.000610
#   Epoch 3 | Batch 1600/2503 | Batch Loss: 0.000359
#   Epoch 3 | Batch 1700/2503 | Batch Loss: 0.000298
#   Epoch 3 | Batch 1800/2503 | Batch Loss: 0.000258
#   Epoch 3 | Batch 1900/2503 | Batch Loss: 0.000282
#   Epoch 3 | Batch 2000/2503 | Batch Loss: 0.000500
#   Epoch 3 | Batch 2100/2503 | Batch Loss: 0.015135
#   Epoch 3 | Batch 2200/2503 | Batch Loss: 0.000737
#   Epoch 3 | Batch 2300/2503 | Batch Loss: 0.000386
#   Epoch 3 | Batch 2400/2503 | Batch Loss: 0.001140
#   Epoch 3 | Batch 2500/2503 | Batch Loss: 0.000825
#
# Fine-tune Epoch 3/50 | Time: 155.6s
#   Train Loss: 0.001126 | Val MSE: 0.001803
# ------------------------------------------------------------
#   Epoch 4 | Batch 100/2503 | Batch Loss: 0.002804
#   Epoch 4 | Batch 200/2503 | Batch Loss: 0.000469
#   Epoch 4 | Batch 300/2503 | Batch Loss: 0.000265
#   Epoch 4 | Batch 400/2503 | Batch Loss: 0.000334
#   Epoch 4 | Batch 500/2503 | Batch Loss: 0.001654
#   Epoch 4 | Batch 600/2503 | Batch Loss: 0.000368
#   Epoch 4 | Batch 700/2503 | Batch Loss: 0.003182
#   Epoch 4 | Batch 800/2503 | Batch Loss: 0.000280
#   Epoch 4 | Batch 900/2503 | Batch Loss: 0.000366
#   Epoch 4 | Batch 1000/2503 | Batch Loss: 0.000385
#   Epoch 4 | Batch 1100/2503 | Batch Loss: 0.000278
#   Epoch 4 | Batch 1200/2503 | Batch Loss: 0.000444
#   Epoch 4 | Batch 1300/2503 | Batch Loss: 0.000275
#   Epoch 4 | Batch 1400/2503 | Batch Loss: 0.003429
#   Epoch 4 | Batch 1500/2503 | Batch Loss: 0.000684
#   Epoch 4 | Batch 1600/2503 | Batch Loss: 0.008167
#   Epoch 4 | Batch 1700/2503 | Batch Loss: 0.000267
#   Epoch 4 | Batch 1800/2503 | Batch Loss: 0.001335
#   Epoch 4 | Batch 1900/2503 | Batch Loss: 0.000301
#   Epoch 4 | Batch 2000/2503 | Batch Loss: 0.000468
#   Epoch 4 | Batch 2100/2503 | Batch Loss: 0.000317
#   Epoch 4 | Batch 2200/2503 | Batch Loss: 0.000605
#   Epoch 4 | Batch 2300/2503 | Batch Loss: 0.000423
#   Epoch 4 | Batch 2400/2503 | Batch Loss: 0.000545
#   Epoch 4 | Batch 2500/2503 | Batch Loss: 0.000293
#
# Fine-tune Epoch 4/50 | Time: 156.2s
#   Train Loss: 0.000991 | Val MSE: 0.001518
# ------------------------------------------------------------
#   Epoch 5 | Batch 100/2503 | Batch Loss: 0.004390
#   Epoch 5 | Batch 200/2503 | Batch Loss: 0.000314
#   Epoch 5 | Batch 300/2503 | Batch Loss: 0.000306
#   Epoch 5 | Batch 400/2503 | Batch Loss: 0.000278
#   Epoch 5 | Batch 500/2503 | Batch Loss: 0.000315
#   Epoch 5 | Batch 600/2503 | Batch Loss: 0.000249
#   Epoch 5 | Batch 700/2503 | Batch Loss: 0.000318
#   Epoch 5 | Batch 800/2503 | Batch Loss: 0.000348
#   Epoch 5 | Batch 900/2503 | Batch Loss: 0.000650
#   Epoch 5 | Batch 1000/2503 | Batch Loss: 0.000378
#   Epoch 5 | Batch 1100/2503 | Batch Loss: 0.000913
#   Epoch 5 | Batch 1200/2503 | Batch Loss: 0.000574
#   Epoch 5 | Batch 1300/2503 | Batch Loss: 0.000279
#   Epoch 5 | Batch 1400/2503 | Batch Loss: 0.000276
#   Epoch 5 | Batch 1500/2503 | Batch Loss: 0.000308
#   Epoch 5 | Batch 1600/2503 | Batch Loss: 0.000390
#   Epoch 5 | Batch 1700/2503 | Batch Loss: 0.000351
#   Epoch 5 | Batch 1800/2503 | Batch Loss: 0.000320
#   Epoch 5 | Batch 1900/2503 | Batch Loss: 0.000456
#   Epoch 5 | Batch 2000/2503 | Batch Loss: 0.000444
#   Epoch 5 | Batch 2100/2503 | Batch Loss: 0.000328
#   Epoch 5 | Batch 2200/2503 | Batch Loss: 0.000261
#   Epoch 5 | Batch 2300/2503 | Batch Loss: 0.000251
#   Epoch 5 | Batch 2400/2503 | Batch Loss: 0.008099
#   Epoch 5 | Batch 2500/2503 | Batch Loss: 0.000425
#
# Fine-tune Epoch 5/50 | Time: 155.5s
#   Train Loss: 0.000917 | Val MSE: 0.001864
# ------------------------------------------------------------
#   Epoch 6 | Batch 100/2503 | Batch Loss: 0.000466
#   Epoch 6 | Batch 200/2503 | Batch Loss: 0.000359
#   Epoch 6 | Batch 300/2503 | Batch Loss: 0.000666
#   Epoch 6 | Batch 400/2503 | Batch Loss: 0.000327
#   Epoch 6 | Batch 500/2503 | Batch Loss: 0.000248
#   Epoch 6 | Batch 600/2503 | Batch Loss: 0.004974
#   Epoch 6 | Batch 700/2503 | Batch Loss: 0.000332
#   Epoch 6 | Batch 800/2503 | Batch Loss: 0.000328
#   Epoch 6 | Batch 900/2503 | Batch Loss: 0.000517
#   Epoch 6 | Batch 1000/2503 | Batch Loss: 0.000286
#   Epoch 6 | Batch 1100/2503 | Batch Loss: 0.000324
#   Epoch 6 | Batch 1200/2503 | Batch Loss: 0.000367
#   Epoch 6 | Batch 1300/2503 | Batch Loss: 0.000258
#   Epoch 6 | Batch 1400/2503 | Batch Loss: 0.002063
#   Epoch 6 | Batch 1500/2503 | Batch Loss: 0.000323
#   Epoch 6 | Batch 1600/2503 | Batch Loss: 0.000318
#   Epoch 6 | Batch 1700/2503 | Batch Loss: 0.000290
#   Epoch 6 | Batch 1800/2503 | Batch Loss: 0.000345
#   Epoch 6 | Batch 1900/2503 | Batch Loss: 0.000341
#   Epoch 6 | Batch 2000/2503 | Batch Loss: 0.000460
#   Epoch 6 | Batch 2100/2503 | Batch Loss: 0.000431
#   Epoch 6 | Batch 2200/2503 | Batch Loss: 0.000242
#   Epoch 6 | Batch 2300/2503 | Batch Loss: 0.000362
#   Epoch 6 | Batch 2400/2503 | Batch Loss: 0.000363
#   Epoch 6 | Batch 2500/2503 | Batch Loss: 0.000265
#
# Fine-tune Epoch 6/50 | Time: 156.5s
#   Train Loss: 0.000838 | Val MSE: 0.001236 *** New Best ***
# ------------------------------------------------------------
#   Epoch 7 | Batch 100/2503 | Batch Loss: 0.000316
#   Epoch 7 | Batch 200/2503 | Batch Loss: 0.000288
#   Epoch 7 | Batch 300/2503 | Batch Loss: 0.001018
#   Epoch 7 | Batch 400/2503 | Batch Loss: 0.004544
#   Epoch 7 | Batch 500/2503 | Batch Loss: 0.000354
#   Epoch 7 | Batch 600/2503 | Batch Loss: 0.000428
#   Epoch 7 | Batch 700/2503 | Batch Loss: 0.000445
#   Epoch 7 | Batch 800/2503 | Batch Loss: 0.004837
#   Epoch 7 | Batch 900/2503 | Batch Loss: 0.000362
#   Epoch 7 | Batch 1000/2503 | Batch Loss: 0.000336
#   Epoch 7 | Batch 1100/2503 | Batch Loss: 0.000285
#   Epoch 7 | Batch 1200/2503 | Batch Loss: 0.007059
#   Epoch 7 | Batch 1300/2503 | Batch Loss: 0.001486
#   Epoch 7 | Batch 1400/2503 | Batch Loss: 0.002105
#   Epoch 7 | Batch 1500/2503 | Batch Loss: 0.000255
#   Epoch 7 | Batch 1600/2503 | Batch Loss: 0.000463
#   Epoch 7 | Batch 1700/2503 | Batch Loss: 0.000284
#   Epoch 7 | Batch 1800/2503 | Batch Loss: 0.000261
#   Epoch 7 | Batch 1900/2503 | Batch Loss: 0.000371
#   Epoch 7 | Batch 2000/2503 | Batch Loss: 0.000233
#   Epoch 7 | Batch 2100/2503 | Batch Loss: 0.000380
#   Epoch 7 | Batch 2200/2503 | Batch Loss: 0.000372
#   Epoch 7 | Batch 2300/2503 | Batch Loss: 0.000296
#   Epoch 7 | Batch 2400/2503 | Batch Loss: 0.000263
#   Epoch 7 | Batch 2500/2503 | Batch Loss: 0.000339
#
# Fine-tune Epoch 7/50 | Time: 157.5s
#   Train Loss: 0.000787 | Val MSE: 0.001551
# ------------------------------------------------------------
#   Epoch 8 | Batch 100/2503 | Batch Loss: 0.000283
#   Epoch 8 | Batch 200/2503 | Batch Loss: 0.000257
#   Epoch 8 | Batch 300/2503 | Batch Loss: 0.000271
#   Epoch 8 | Batch 400/2503 | Batch Loss: 0.000264
#   Epoch 8 | Batch 500/2503 | Batch Loss: 0.000404
#   Epoch 8 | Batch 600/2503 | Batch Loss: 0.000247
#   Epoch 8 | Batch 700/2503 | Batch Loss: 0.000266
#   Epoch 8 | Batch 800/2503 | Batch Loss: 0.000286
#   Epoch 8 | Batch 900/2503 | Batch Loss: 0.000956
#   Epoch 8 | Batch 1000/2503 | Batch Loss: 0.003804
#   Epoch 8 | Batch 1100/2503 | Batch Loss: 0.000336
#   Epoch 8 | Batch 1200/2503 | Batch Loss: 0.000357
#   Epoch 8 | Batch 1300/2503 | Batch Loss: 0.001823
#   Epoch 8 | Batch 1400/2503 | Batch Loss: 0.000329
#   Epoch 8 | Batch 1500/2503 | Batch Loss: 0.001113
#   Epoch 8 | Batch 1600/2503 | Batch Loss: 0.000426
#   Epoch 8 | Batch 1700/2503 | Batch Loss: 0.000287
#   Epoch 8 | Batch 1800/2503 | Batch Loss: 0.000218
#   Epoch 8 | Batch 1900/2503 | Batch Loss: 0.000226
#   Epoch 8 | Batch 2000/2503 | Batch Loss: 0.000380
#   Epoch 8 | Batch 2100/2503 | Batch Loss: 0.000321
#   Epoch 8 | Batch 2200/2503 | Batch Loss: 0.000270
#   Epoch 8 | Batch 2300/2503 | Batch Loss: 0.000275
#   Epoch 8 | Batch 2400/2503 | Batch Loss: 0.000259
#   Epoch 8 | Batch 2500/2503 | Batch Loss: 0.000264
#
# Fine-tune Epoch 8/50 | Time: 156.5s
#   Train Loss: 0.000770 | Val MSE: 0.001146 *** New Best ***
# ------------------------------------------------------------
#   Epoch 9 | Batch 100/2503 | Batch Loss: 0.000273
#   Epoch 9 | Batch 200/2503 | Batch Loss: 0.000324
#   Epoch 9 | Batch 300/2503 | Batch Loss: 0.003337
#   Epoch 9 | Batch 400/2503 | Batch Loss: 0.000325
#   Epoch 9 | Batch 500/2503 | Batch Loss: 0.000278
#   Epoch 9 | Batch 600/2503 | Batch Loss: 0.000229
#   Epoch 9 | Batch 700/2503 | Batch Loss: 0.000274
#   Epoch 9 | Batch 800/2503 | Batch Loss: 0.000340
#   Epoch 9 | Batch 900/2503 | Batch Loss: 0.003338
#   Epoch 9 | Batch 1000/2503 | Batch Loss: 0.000263
#   Epoch 9 | Batch 1100/2503 | Batch Loss: 0.000349
#   Epoch 9 | Batch 1200/2503 | Batch Loss: 0.001270
#   Epoch 9 | Batch 1300/2503 | Batch Loss: 0.000283
#   Epoch 9 | Batch 1400/2503 | Batch Loss: 0.000217
#   Epoch 9 | Batch 1500/2503 | Batch Loss: 0.000327
#   Epoch 9 | Batch 1600/2503 | Batch Loss: 0.000250
#   Epoch 9 | Batch 1700/2503 | Batch Loss: 0.000341
#   Epoch 9 | Batch 1800/2503 | Batch Loss: 0.000262
#   Epoch 9 | Batch 1900/2503 | Batch Loss: 0.000220
#   Epoch 9 | Batch 2000/2503 | Batch Loss: 0.000325
#   Epoch 9 | Batch 2100/2503 | Batch Loss: 0.000491
#   Epoch 9 | Batch 2200/2503 | Batch Loss: 0.000291
#   Epoch 9 | Batch 2300/2503 | Batch Loss: 0.000380
#   Epoch 9 | Batch 2400/2503 | Batch Loss: 0.000265
#   Epoch 9 | Batch 2500/2503 | Batch Loss: 0.001419
#
# Fine-tune Epoch 9/50 | Time: 156.8s
#   Train Loss: 0.000719 | Val MSE: 0.001026 *** New Best ***
# ------------------------------------------------------------
#   Epoch 10 | Batch 100/2503 | Batch Loss: 0.000277
#   Epoch 10 | Batch 200/2503 | Batch Loss: 0.000378
#   Epoch 10 | Batch 300/2503 | Batch Loss: 0.000280
#   Epoch 10 | Batch 400/2503 | Batch Loss: 0.000363
#   Epoch 10 | Batch 500/2503 | Batch Loss: 0.000348
#   Epoch 10 | Batch 600/2503 | Batch Loss: 0.000221
#   Epoch 10 | Batch 700/2503 | Batch Loss: 0.000352
#   Epoch 10 | Batch 800/2503 | Batch Loss: 0.000261
#   Epoch 10 | Batch 900/2503 | Batch Loss: 0.000288
#   Epoch 10 | Batch 1000/2503 | Batch Loss: 0.000339
#   Epoch 10 | Batch 1100/2503 | Batch Loss: 0.000212
#   Epoch 10 | Batch 1200/2503 | Batch Loss: 0.000291
#   Epoch 10 | Batch 1300/2503 | Batch Loss: 0.000373
#   Epoch 10 | Batch 1400/2503 | Batch Loss: 0.000319
#   Epoch 10 | Batch 1500/2503 | Batch Loss: 0.000293
#   Epoch 10 | Batch 1600/2503 | Batch Loss: 0.000304
#   Epoch 10 | Batch 1700/2503 | Batch Loss: 0.001742
#   Epoch 10 | Batch 1800/2503 | Batch Loss: 0.000400
#   Epoch 10 | Batch 1900/2503 | Batch Loss: 0.000523
#   Epoch 10 | Batch 2000/2503 | Batch Loss: 0.000237
#   Epoch 10 | Batch 2100/2503 | Batch Loss: 0.000308
#   Epoch 10 | Batch 2200/2503 | Batch Loss: 0.000228
#   Epoch 10 | Batch 2300/2503 | Batch Loss: 0.000276
#   Epoch 10 | Batch 2400/2503 | Batch Loss: 0.000379
#   Epoch 10 | Batch 2500/2503 | Batch Loss: 0.003543
#
# Fine-tune Epoch 10/50 | Time: 157.3s
#   Train Loss: 0.000678 | Val MSE: 0.000974 *** New Best ***
# ------------------------------------------------------------
#   Epoch 11 | Batch 100/2503 | Batch Loss: 0.000320
#   Epoch 11 | Batch 200/2503 | Batch Loss: 0.000243
#   Epoch 11 | Batch 300/2503 | Batch Loss: 0.000275
#   Epoch 11 | Batch 400/2503 | Batch Loss: 0.002419
#   Epoch 11 | Batch 500/2503 | Batch Loss: 0.000251
#   Epoch 11 | Batch 600/2503 | Batch Loss: 0.001396
#   Epoch 11 | Batch 700/2503 | Batch Loss: 0.000266
#   Epoch 11 | Batch 800/2503 | Batch Loss: 0.000294
#   Epoch 11 | Batch 900/2503 | Batch Loss: 0.000542
#   Epoch 11 | Batch 1000/2503 | Batch Loss: 0.000279
#   Epoch 11 | Batch 1100/2503 | Batch Loss: 0.000336
#   Epoch 11 | Batch 1200/2503 | Batch Loss: 0.000235
#   Epoch 11 | Batch 1300/2503 | Batch Loss: 0.000245
#   Epoch 11 | Batch 1400/2503 | Batch Loss: 0.000280
#   Epoch 11 | Batch 1500/2503 | Batch Loss: 0.000316
#   Epoch 11 | Batch 1600/2503 | Batch Loss: 0.000284
#   Epoch 11 | Batch 1700/2503 | Batch Loss: 0.000298
#   Epoch 11 | Batch 1800/2503 | Batch Loss: 0.000204
#   Epoch 11 | Batch 1900/2503 | Batch Loss: 0.000282
#   Epoch 11 | Batch 2000/2503 | Batch Loss: 0.000226
#   Epoch 11 | Batch 2100/2503 | Batch Loss: 0.000241
#   Epoch 11 | Batch 2200/2503 | Batch Loss: 0.000393
#   Epoch 11 | Batch 2300/2503 | Batch Loss: 0.000246
#   Epoch 11 | Batch 2400/2503 | Batch Loss: 0.000406
#   Epoch 11 | Batch 2500/2503 | Batch Loss: 0.000307
#
# Fine-tune Epoch 11/50 | Time: 157.2s
#   Train Loss: 0.000657 | Val MSE: 0.001055
# ------------------------------------------------------------
#   Epoch 12 | Batch 100/2503 | Batch Loss: 0.000250
#   Epoch 12 | Batch 200/2503 | Batch Loss: 0.000282
#   Epoch 12 | Batch 300/2503 | Batch Loss: 0.000236
#   Epoch 12 | Batch 400/2503 | Batch Loss: 0.000311
#   Epoch 12 | Batch 500/2503 | Batch Loss: 0.000260
#   Epoch 12 | Batch 600/2503 | Batch Loss: 0.000234
#   Epoch 12 | Batch 700/2503 | Batch Loss: 0.000508
#   Epoch 12 | Batch 800/2503 | Batch Loss: 0.000301
#   Epoch 12 | Batch 900/2503 | Batch Loss: 0.000251
#   Epoch 12 | Batch 1000/2503 | Batch Loss: 0.001143
#   Epoch 12 | Batch 1100/2503 | Batch Loss: 0.000341
#   Epoch 12 | Batch 1200/2503 | Batch Loss: 0.000277
#   Epoch 12 | Batch 1300/2503 | Batch Loss: 0.000234
#   Epoch 12 | Batch 1400/2503 | Batch Loss: 0.000308
#   Epoch 12 | Batch 1500/2503 | Batch Loss: 0.000290
#   Epoch 12 | Batch 1600/2503 | Batch Loss: 0.000226
#   Epoch 12 | Batch 1700/2503 | Batch Loss: 0.000280
#   Epoch 12 | Batch 1800/2503 | Batch Loss: 0.000404
#   Epoch 12 | Batch 1900/2503 | Batch Loss: 0.000202
#   Epoch 12 | Batch 2000/2503 | Batch Loss: 0.000327
#   Epoch 12 | Batch 2100/2503 | Batch Loss: 0.000376
#   Epoch 12 | Batch 2200/2503 | Batch Loss: 0.000246
#   Epoch 12 | Batch 2300/2503 | Batch Loss: 0.000213
#   Epoch 12 | Batch 2400/2503 | Batch Loss: 0.000236
#   Epoch 12 | Batch 2500/2503 | Batch Loss: 0.000256
#
# Fine-tune Epoch 12/50 | Time: 157.3s
#   Train Loss: 0.000636 | Val MSE: 0.001149
# ------------------------------------------------------------
#   Epoch 13 | Batch 100/2503 | Batch Loss: 0.000431
#   Epoch 13 | Batch 200/2503 | Batch Loss: 0.000314
#   Epoch 13 | Batch 300/2503 | Batch Loss: 0.001594
#   Epoch 13 | Batch 400/2503 | Batch Loss: 0.004949
#   Epoch 13 | Batch 500/2503 | Batch Loss: 0.000419
#   Epoch 13 | Batch 600/2503 | Batch Loss: 0.000362
#   Epoch 13 | Batch 700/2503 | Batch Loss: 0.000256
#   Epoch 13 | Batch 800/2503 | Batch Loss: 0.000375
#   Epoch 13 | Batch 900/2503 | Batch Loss: 0.000672
#   Epoch 13 | Batch 1000/2503 | Batch Loss: 0.000292
#   Epoch 13 | Batch 1100/2503 | Batch Loss: 0.000301
#   Epoch 13 | Batch 1200/2503 | Batch Loss: 0.000265
#   Epoch 13 | Batch 1300/2503 | Batch Loss: 0.000861
#   Epoch 13 | Batch 1400/2503 | Batch Loss: 0.000294
#   Epoch 13 | Batch 1500/2503 | Batch Loss: 0.000276
#   Epoch 13 | Batch 1600/2503 | Batch Loss: 0.000315
#   Epoch 13 | Batch 1700/2503 | Batch Loss: 0.000228
#   Epoch 13 | Batch 1800/2503 | Batch Loss: 0.000223
#   Epoch 13 | Batch 1900/2503 | Batch Loss: 0.001244
#   Epoch 13 | Batch 2000/2503 | Batch Loss: 0.000432
#   Epoch 13 | Batch 2100/2503 | Batch Loss: 0.000371
#   Epoch 13 | Batch 2200/2503 | Batch Loss: 0.000314
#   Epoch 13 | Batch 2300/2503 | Batch Loss: 0.000538
#   Epoch 13 | Batch 2400/2503 | Batch Loss: 0.000244
#   Epoch 13 | Batch 2500/2503 | Batch Loss: 0.000290
#
# Fine-tune Epoch 13/50 | Time: 156.4s
#   Train Loss: 0.000621 | Val MSE: 0.000896 *** New Best ***
# ------------------------------------------------------------
#   Epoch 14 | Batch 100/2503 | Batch Loss: 0.000273
#   Epoch 14 | Batch 200/2503 | Batch Loss: 0.000227
#   Epoch 14 | Batch 300/2503 | Batch Loss: 0.000252
#   Epoch 14 | Batch 400/2503 | Batch Loss: 0.000236
#   Epoch 14 | Batch 500/2503 | Batch Loss: 0.000652
#   Epoch 14 | Batch 600/2503 | Batch Loss: 0.000312
#   Epoch 14 | Batch 700/2503 | Batch Loss: 0.000315
#   Epoch 14 | Batch 800/2503 | Batch Loss: 0.001070
#   Epoch 14 | Batch 900/2503 | Batch Loss: 0.000289
#   Epoch 14 | Batch 1000/2503 | Batch Loss: 0.000216
#   Epoch 14 | Batch 1100/2503 | Batch Loss: 0.000225
#   Epoch 14 | Batch 1200/2503 | Batch Loss: 0.002334
#   Epoch 14 | Batch 1300/2503 | Batch Loss: 0.000299
#   Epoch 14 | Batch 1400/2503 | Batch Loss: 0.000479
#   Epoch 14 | Batch 1500/2503 | Batch Loss: 0.000218
#   Epoch 14 | Batch 1600/2503 | Batch Loss: 0.000247
#   Epoch 14 | Batch 1700/2503 | Batch Loss: 0.000255
#   Epoch 14 | Batch 1800/2503 | Batch Loss: 0.000251
#   Epoch 14 | Batch 1900/2503 | Batch Loss: 0.001150
#   Epoch 14 | Batch 2000/2503 | Batch Loss: 0.000256
#   Epoch 14 | Batch 2100/2503 | Batch Loss: 0.000324
#   Epoch 14 | Batch 2200/2503 | Batch Loss: 0.000238
#   Epoch 14 | Batch 2300/2503 | Batch Loss: 0.001144
#   Epoch 14 | Batch 2400/2503 | Batch Loss: 0.000307
#   Epoch 14 | Batch 2500/2503 | Batch Loss: 0.000234
#
# Fine-tune Epoch 14/50 | Time: 156.1s
#   Train Loss: 0.000596 | Val MSE: 0.001070
# ------------------------------------------------------------
#   Epoch 15 | Batch 100/2503 | Batch Loss: 0.000337
#   Epoch 15 | Batch 200/2503 | Batch Loss: 0.000231
#   Epoch 15 | Batch 300/2503 | Batch Loss: 0.000269
#   Epoch 15 | Batch 400/2503 | Batch Loss: 0.000209
#   Epoch 15 | Batch 500/2503 | Batch Loss: 0.000267
#   Epoch 15 | Batch 600/2503 | Batch Loss: 0.000237
#   Epoch 15 | Batch 700/2503 | Batch Loss: 0.001345
#   Epoch 15 | Batch 800/2503 | Batch Loss: 0.000282
#   Epoch 15 | Batch 900/2503 | Batch Loss: 0.000304
#   Epoch 15 | Batch 1000/2503 | Batch Loss: 0.000318
#   Epoch 15 | Batch 1100/2503 | Batch Loss: 0.000270
#   Epoch 15 | Batch 1200/2503 | Batch Loss: 0.003687
#   Epoch 15 | Batch 1300/2503 | Batch Loss: 0.000267
#   Epoch 15 | Batch 1400/2503 | Batch Loss: 0.000261
#   Epoch 15 | Batch 1500/2503 | Batch Loss: 0.000253
#   Epoch 15 | Batch 1600/2503 | Batch Loss: 0.000268
#   Epoch 15 | Batch 1700/2503 | Batch Loss: 0.000325
#   Epoch 15 | Batch 1800/2503 | Batch Loss: 0.000260
#   Epoch 15 | Batch 1900/2503 | Batch Loss: 0.000303
#   Epoch 15 | Batch 2000/2503 | Batch Loss: 0.000224
#   Epoch 15 | Batch 2100/2503 | Batch Loss: 0.000263
#   Epoch 15 | Batch 2200/2503 | Batch Loss: 0.001966
#   Epoch 15 | Batch 2300/2503 | Batch Loss: 0.000257
#   Epoch 15 | Batch 2400/2503 | Batch Loss: 0.000278
#   Epoch 15 | Batch 2500/2503 | Batch Loss: 0.000299
#
# Fine-tune Epoch 15/50 | Time: 154.7s
#   Train Loss: 0.000578 | Val MSE: 0.000853 *** New Best ***
# ------------------------------------------------------------
#   Epoch 16 | Batch 100/2503 | Batch Loss: 0.000262
#   Epoch 16 | Batch 200/2503 | Batch Loss: 0.000236
#   Epoch 16 | Batch 300/2503 | Batch Loss: 0.001725
#   Epoch 16 | Batch 400/2503 | Batch Loss: 0.000220
#   Epoch 16 | Batch 500/2503 | Batch Loss: 0.000236
#   Epoch 16 | Batch 600/2503 | Batch Loss: 0.000228
#   Epoch 16 | Batch 700/2503 | Batch Loss: 0.000216
#   Epoch 16 | Batch 800/2503 | Batch Loss: 0.000656
#   Epoch 16 | Batch 900/2503 | Batch Loss: 0.000244
#   Epoch 16 | Batch 1000/2503 | Batch Loss: 0.000286
#   Epoch 16 | Batch 1100/2503 | Batch Loss: 0.000292
#   Epoch 16 | Batch 1200/2503 | Batch Loss: 0.000232
#   Epoch 16 | Batch 1300/2503 | Batch Loss: 0.000254
#   Epoch 16 | Batch 1400/2503 | Batch Loss: 0.000343
#   Epoch 16 | Batch 1500/2503 | Batch Loss: 0.001167
#   Epoch 16 | Batch 1600/2503 | Batch Loss: 0.000246
#   Epoch 16 | Batch 1700/2503 | Batch Loss: 0.001548
#   Epoch 16 | Batch 1800/2503 | Batch Loss: 0.000234
#   Epoch 16 | Batch 1900/2503 | Batch Loss: 0.000300
#   Epoch 16 | Batch 2000/2503 | Batch Loss: 0.000244
#   Epoch 16 | Batch 2100/2503 | Batch Loss: 0.000214
#   Epoch 16 | Batch 2200/2503 | Batch Loss: 0.000319
#   Epoch 16 | Batch 2300/2503 | Batch Loss: 0.000289
#   Epoch 16 | Batch 2400/2503 | Batch Loss: 0.000223
#   Epoch 16 | Batch 2500/2503 | Batch Loss: 0.000224
#
# Fine-tune Epoch 16/50 | Time: 155.2s
#   Train Loss: 0.000567 | Val MSE: 0.001203
# ------------------------------------------------------------
#   Epoch 17 | Batch 100/2503 | Batch Loss: 0.000632
#   Epoch 17 | Batch 200/2503 | Batch Loss: 0.000225
#   Epoch 17 | Batch 300/2503 | Batch Loss: 0.000268
#   Epoch 17 | Batch 400/2503 | Batch Loss: 0.000287
#   Epoch 17 | Batch 500/2503 | Batch Loss: 0.000251
#   Epoch 17 | Batch 600/2503 | Batch Loss: 0.001226
#   Epoch 17 | Batch 700/2503 | Batch Loss: 0.000289
#   Epoch 17 | Batch 800/2503 | Batch Loss: 0.001431
#   Epoch 17 | Batch 900/2503 | Batch Loss: 0.000212
#   Epoch 17 | Batch 1000/2503 | Batch Loss: 0.001000
#   Epoch 17 | Batch 1100/2503 | Batch Loss: 0.000455
#   Epoch 17 | Batch 1200/2503 | Batch Loss: 0.000269
#   Epoch 17 | Batch 1300/2503 | Batch Loss: 0.000303
#   Epoch 17 | Batch 1400/2503 | Batch Loss: 0.000574
#   Epoch 17 | Batch 1500/2503 | Batch Loss: 0.005259
#   Epoch 17 | Batch 1600/2503 | Batch Loss: 0.000227
#   Epoch 17 | Batch 1700/2503 | Batch Loss: 0.000222
#   Epoch 17 | Batch 1800/2503 | Batch Loss: 0.000293
#   Epoch 17 | Batch 1900/2503 | Batch Loss: 0.000293
#   Epoch 17 | Batch 2000/2503 | Batch Loss: 0.000335
#   Epoch 17 | Batch 2100/2503 | Batch Loss: 0.000717
#   Epoch 17 | Batch 2200/2503 | Batch Loss: 0.000240
#   Epoch 17 | Batch 2300/2503 | Batch Loss: 0.000245
#   Epoch 17 | Batch 2400/2503 | Batch Loss: 0.000456
#   Epoch 17 | Batch 2500/2503 | Batch Loss: 0.000203
#
# Fine-tune Epoch 17/50 | Time: 154.7s
#   Train Loss: 0.000552 | Val MSE: 0.000767 *** New Best ***
# ------------------------------------------------------------
#   Epoch 18 | Batch 100/2503 | Batch Loss: 0.000250
#   Epoch 18 | Batch 200/2503 | Batch Loss: 0.000220
#   Epoch 18 | Batch 300/2503 | Batch Loss: 0.000415
#   Epoch 18 | Batch 400/2503 | Batch Loss: 0.000217
#   Epoch 18 | Batch 500/2503 | Batch Loss: 0.000214
#   Epoch 18 | Batch 600/2503 | Batch Loss: 0.000259
#   Epoch 18 | Batch 700/2503 | Batch Loss: 0.002590
#   Epoch 18 | Batch 800/2503 | Batch Loss: 0.000213
#   Epoch 18 | Batch 900/2503 | Batch Loss: 0.002235
#   Epoch 18 | Batch 1000/2503 | Batch Loss: 0.000221
#   Epoch 18 | Batch 1100/2503 | Batch Loss: 0.000227
#   Epoch 18 | Batch 1200/2503 | Batch Loss: 0.000249
#   Epoch 18 | Batch 1300/2503 | Batch Loss: 0.000330
#   Epoch 18 | Batch 1400/2503 | Batch Loss: 0.000265
#   Epoch 18 | Batch 1500/2503 | Batch Loss: 0.000306
#   Epoch 18 | Batch 1600/2503 | Batch Loss: 0.001201
#   Epoch 18 | Batch 1700/2503 | Batch Loss: 0.000268
#   Epoch 18 | Batch 1800/2503 | Batch Loss: 0.000279
#   Epoch 18 | Batch 1900/2503 | Batch Loss: 0.000249
#   Epoch 18 | Batch 2000/2503 | Batch Loss: 0.001440
#   Epoch 18 | Batch 2100/2503 | Batch Loss: 0.000225
#   Epoch 18 | Batch 2200/2503 | Batch Loss: 0.000205
#   Epoch 18 | Batch 2300/2503 | Batch Loss: 0.000252
#   Epoch 18 | Batch 2400/2503 | Batch Loss: 0.002059
#   Epoch 18 | Batch 2500/2503 | Batch Loss: 0.003711
#
# Fine-tune Epoch 18/50 | Time: 154.3s
#   Train Loss: 0.000538 | Val MSE: 0.000906
# ------------------------------------------------------------
#   Epoch 19 | Batch 100/2503 | Batch Loss: 0.000700
#   Epoch 19 | Batch 200/2503 | Batch Loss: 0.000244
#   Epoch 19 | Batch 300/2503 | Batch Loss: 0.000272
#   Epoch 19 | Batch 400/2503 | Batch Loss: 0.000257
#   Epoch 19 | Batch 500/2503 | Batch Loss: 0.000260
#   Epoch 19 | Batch 600/2503 | Batch Loss: 0.000230
#   Epoch 19 | Batch 700/2503 | Batch Loss: 0.000217
#   Epoch 19 | Batch 800/2503 | Batch Loss: 0.000203
#   Epoch 19 | Batch 900/2503 | Batch Loss: 0.000233
#   Epoch 19 | Batch 1000/2503 | Batch Loss: 0.000204
#   Epoch 19 | Batch 1100/2503 | Batch Loss: 0.000285
#   Epoch 19 | Batch 1200/2503 | Batch Loss: 0.000239
#   Epoch 19 | Batch 1300/2503 | Batch Loss: 0.000242
#   Epoch 19 | Batch 1400/2503 | Batch Loss: 0.000259
#   Epoch 19 | Batch 1500/2503 | Batch Loss: 0.000199
#   Epoch 19 | Batch 1600/2503 | Batch Loss: 0.000260
#   Epoch 19 | Batch 1700/2503 | Batch Loss: 0.000253
#   Epoch 19 | Batch 1800/2503 | Batch Loss: 0.000200
#   Epoch 19 | Batch 1900/2503 | Batch Loss: 0.000208
#   Epoch 19 | Batch 2000/2503 | Batch Loss: 0.000314
#   Epoch 19 | Batch 2100/2503 | Batch Loss: 0.000260
#   Epoch 19 | Batch 2200/2503 | Batch Loss: 0.000243
#   Epoch 19 | Batch 2300/2503 | Batch Loss: 0.000232
#   Epoch 19 | Batch 2400/2503 | Batch Loss: 0.000218
#   Epoch 19 | Batch 2500/2503 | Batch Loss: 0.000398
#
# Fine-tune Epoch 19/50 | Time: 154.9s
#   Train Loss: 0.000524 | Val MSE: 0.001453
# ------------------------------------------------------------
#   Epoch 20 | Batch 100/2503 | Batch Loss: 0.000273
#   Epoch 20 | Batch 200/2503 | Batch Loss: 0.004155
#   Epoch 20 | Batch 300/2503 | Batch Loss: 0.000216
#   Epoch 20 | Batch 400/2503 | Batch Loss: 0.000456
#   Epoch 20 | Batch 500/2503 | Batch Loss: 0.000251
#   Epoch 20 | Batch 600/2503 | Batch Loss: 0.000245
#   Epoch 20 | Batch 700/2503 | Batch Loss: 0.000230
#   Epoch 20 | Batch 800/2503 | Batch Loss: 0.000266
#   Epoch 20 | Batch 900/2503 | Batch Loss: 0.000249
#   Epoch 20 | Batch 1000/2503 | Batch Loss: 0.000277
#   Epoch 20 | Batch 1100/2503 | Batch Loss: 0.000328
#   Epoch 20 | Batch 1200/2503 | Batch Loss: 0.000241
#   Epoch 20 | Batch 1300/2503 | Batch Loss: 0.000231
#   Epoch 20 | Batch 1400/2503 | Batch Loss: 0.000657
#   Epoch 20 | Batch 1500/2503 | Batch Loss: 0.000343
#   Epoch 20 | Batch 1600/2503 | Batch Loss: 0.000334
#   Epoch 20 | Batch 1700/2503 | Batch Loss: 0.000229
#   Epoch 20 | Batch 1800/2503 | Batch Loss: 0.000501
#   Epoch 20 | Batch 1900/2503 | Batch Loss: 0.000199
#   Epoch 20 | Batch 2000/2503 | Batch Loss: 0.000206
#   Epoch 20 | Batch 2100/2503 | Batch Loss: 0.000232
#   Epoch 20 | Batch 2200/2503 | Batch Loss: 0.000201
#   Epoch 20 | Batch 2300/2503 | Batch Loss: 0.000187
#   Epoch 20 | Batch 2400/2503 | Batch Loss: 0.000202
#   Epoch 20 | Batch 2500/2503 | Batch Loss: 0.000207
#
# Fine-tune Epoch 20/50 | Time: 154.2s
#   Train Loss: 0.000511 | Val MSE: 0.000610 *** New Best ***
# ------------------------------------------------------------
#   Epoch 21 | Batch 100/2503 | Batch Loss: 0.000208
#   Epoch 21 | Batch 200/2503 | Batch Loss: 0.000250
#   Epoch 21 | Batch 300/2503 | Batch Loss: 0.000232
#   Epoch 21 | Batch 400/2503 | Batch Loss: 0.000218
#   Epoch 21 | Batch 500/2503 | Batch Loss: 0.000224
#   Epoch 21 | Batch 600/2503 | Batch Loss: 0.000234
#   Epoch 21 | Batch 700/2503 | Batch Loss: 0.000438
#   Epoch 21 | Batch 800/2503 | Batch Loss: 0.000254
#   Epoch 21 | Batch 900/2503 | Batch Loss: 0.000203
#   Epoch 21 | Batch 1000/2503 | Batch Loss: 0.000242
#   Epoch 21 | Batch 1100/2503 | Batch Loss: 0.001367
#   Epoch 21 | Batch 1200/2503 | Batch Loss: 0.000215
#   Epoch 21 | Batch 1300/2503 | Batch Loss: 0.000204
#   Epoch 21 | Batch 1400/2503 | Batch Loss: 0.000229
#   Epoch 21 | Batch 1500/2503 | Batch Loss: 0.000238
#   Epoch 21 | Batch 1600/2503 | Batch Loss: 0.000195
#   Epoch 21 | Batch 1700/2503 | Batch Loss: 0.000391
#   Epoch 21 | Batch 1800/2503 | Batch Loss: 0.000239
#   Epoch 21 | Batch 1900/2503 | Batch Loss: 0.000480
#   Epoch 21 | Batch 2000/2503 | Batch Loss: 0.000235
#   Epoch 21 | Batch 2100/2503 | Batch Loss: 0.000241
#   Epoch 21 | Batch 2200/2503 | Batch Loss: 0.000243
#   Epoch 21 | Batch 2300/2503 | Batch Loss: 0.000219
#   Epoch 21 | Batch 2400/2503 | Batch Loss: 0.000233
#   Epoch 21 | Batch 2500/2503 | Batch Loss: 0.000214
#
# Fine-tune Epoch 21/50 | Time: 154.7s
#   Train Loss: 0.000500 | Val MSE: 0.000721
# ------------------------------------------------------------
#   Epoch 22 | Batch 100/2503 | Batch Loss: 0.000214
#   Epoch 22 | Batch 200/2503 | Batch Loss: 0.000229
#   Epoch 22 | Batch 300/2503 | Batch Loss: 0.000179
#   Epoch 22 | Batch 400/2503 | Batch Loss: 0.000209
#   Epoch 22 | Batch 500/2503 | Batch Loss: 0.000290
#   Epoch 22 | Batch 600/2503 | Batch Loss: 0.000229
#   Epoch 22 | Batch 700/2503 | Batch Loss: 0.000243
#   Epoch 22 | Batch 800/2503 | Batch Loss: 0.003520
#   Epoch 22 | Batch 900/2503 | Batch Loss: 0.000218
#   Epoch 22 | Batch 1000/2503 | Batch Loss: 0.000243
#   Epoch 22 | Batch 1100/2503 | Batch Loss: 0.000751
#   Epoch 22 | Batch 1200/2503 | Batch Loss: 0.000240
#   Epoch 22 | Batch 1300/2503 | Batch Loss: 0.000793
#   Epoch 22 | Batch 1400/2503 | Batch Loss: 0.000222
#   Epoch 22 | Batch 1500/2503 | Batch Loss: 0.000171
#   Epoch 22 | Batch 1600/2503 | Batch Loss: 0.000217
#   Epoch 22 | Batch 1700/2503 | Batch Loss: 0.000240
#   Epoch 22 | Batch 1800/2503 | Batch Loss: 0.000232
#   Epoch 22 | Batch 1900/2503 | Batch Loss: 0.000269
#   Epoch 22 | Batch 2000/2503 | Batch Loss: 0.000637
#   Epoch 22 | Batch 2100/2503 | Batch Loss: 0.000256
#   Epoch 22 | Batch 2200/2503 | Batch Loss: 0.000258
#   Epoch 22 | Batch 2300/2503 | Batch Loss: 0.000195
#   Epoch 22 | Batch 2400/2503 | Batch Loss: 0.000508
#   Epoch 22 | Batch 2500/2503 | Batch Loss: 0.000218
#
# Fine-tune Epoch 22/50 | Time: 154.2s
#   Train Loss: 0.000493 | Val MSE: 0.000877
# ------------------------------------------------------------
#   Epoch 23 | Batch 100/2503 | Batch Loss: 0.000217
#   Epoch 23 | Batch 200/2503 | Batch Loss: 0.000259
#   Epoch 23 | Batch 300/2503 | Batch Loss: 0.000258
#   Epoch 23 | Batch 400/2503 | Batch Loss: 0.000206
#   Epoch 23 | Batch 500/2503 | Batch Loss: 0.000276
#   Epoch 23 | Batch 600/2503 | Batch Loss: 0.000366
#   Epoch 23 | Batch 700/2503 | Batch Loss: 0.000341
#   Epoch 23 | Batch 800/2503 | Batch Loss: 0.000257
#   Epoch 23 | Batch 900/2503 | Batch Loss: 0.000222
#   Epoch 23 | Batch 1000/2503 | Batch Loss: 0.005479
#   Epoch 23 | Batch 1100/2503 | Batch Loss: 0.000268
#   Epoch 23 | Batch 1200/2503 | Batch Loss: 0.000738
#   Epoch 23 | Batch 1300/2503 | Batch Loss: 0.000161
#   Epoch 23 | Batch 1400/2503 | Batch Loss: 0.000206
#   Epoch 23 | Batch 1500/2503 | Batch Loss: 0.000197
#   Epoch 23 | Batch 1600/2503 | Batch Loss: 0.000211
#   Epoch 23 | Batch 1700/2503 | Batch Loss: 0.000242
#   Epoch 23 | Batch 1800/2503 | Batch Loss: 0.000218
#   Epoch 23 | Batch 1900/2503 | Batch Loss: 0.000235
#   Epoch 23 | Batch 2000/2503 | Batch Loss: 0.000174
#   Epoch 23 | Batch 2100/2503 | Batch Loss: 0.000215
#   Epoch 23 | Batch 2200/2503 | Batch Loss: 0.000215
#   Epoch 23 | Batch 2300/2503 | Batch Loss: 0.000192
#   Epoch 23 | Batch 2400/2503 | Batch Loss: 0.000230
#   Epoch 23 | Batch 2500/2503 | Batch Loss: 0.000248
#
# Fine-tune Epoch 23/50 | Time: 154.8s
#   Train Loss: 0.000484 | Val MSE: 0.000758
# ------------------------------------------------------------
#
# *** Early stopping triggered at epoch 23 ***
#
# ============================================================
# TRAINING COMPLETE!
# Best Validation MSE: 0.000610
# ============================================================
# Models saved: 'best_model.pth' and 'final_model.pth'
#
# ============================================================
# RUNNING FINAL TEST SET EVALUATION
# ============================================================
# Final Test MSE: 0.001631
#
# Saving loss history to 'loss_history.txt'...
# Generating loss curve plot 'loss_plot.png'...
# Execution Finished.
